# %% [markdown]
# # AUTOSCOUT CAPSTONE PROJECT

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# **Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %%
# !jupyter nbconvert --to webpdf --allow-chromium-download AutoScout_Ismail-1.ipynb
# Out:
# [NbConvertApp] Converting notebook AutoScout_Ismail-1.ipynb to webpdf
# [INFO] Starting Chromium download.
#
#   0%|          | 0.00/137M [00:00<?, ?b/s]
#   0%|          | 41.0k/137M [00:00<05:47, 394kb/s]
#   0%|          | 102k/137M [00:00<04:52, 468kb/s]
#   0%|          | 246k/137M [00:00<02:39, 857kb/s]
#   0%|          | 399k/137M [00:00<02:03, 1.11Mb/s]
#   0%|          | 532k/137M [00:00<01:56, 1.17Mb/s]
#   1%|          | 737k/137M [00:00<01:33, 1.46Mb/s]
#   1%|          | 922k/137M [00:00<01:27, 1.55Mb/s]
#   1%|          | 1.15M/137M [00:00<01:16, 1.77Mb/s]
#   1%|1         | 1.54M/137M [00:00<00:56, 2.41Mb/s]
#   1%|1         | 1.87M/137M [00:01<00:50, 2.69Mb/s]
#   2%|1         | 2.31M/137M [00:01<00:42, 3.20Mb/s]
#   2%|2         | 2.78M/137M [00:01<00:37, 3.60Mb/s]
#   2%|2         | 3.14M/137M [00:01<00:38, 3.43Mb/s]
#   3%|2         | 3.49M/137M [00:01<00:39, 3.34Mb/s]
#   3%|2         | 3.83M/137M [00:01<00:45, 2.93Mb/s]
#   3%|3         | 4.14M/137M [00:01<00:49, 2.67Mb/s]
#   3%|3         | 4.53M/137M [00:01<00:44, 2.95Mb/s]
#   4%|3         | 4.85M/137M [00:01<00:43, 3.01Mb/s]
#   4%|3         | 5.17M/137M [00:02<00:43, 3.04Mb/s]
#   4%|4         | 5.54M/137M [00:02<00:41, 3.19Mb/s]
#   4%|4         | 5.92M/137M [00:02<00:39, 3.35Mb/s]
#   5%|4         | 6.27M/137M [00:02<00:41, 3.17Mb/s]
#   5%|4         | 6.63M/137M [00:02<00:39, 3.26Mb/s]
#   5%|5         | 6.96M/137M [00:02<00:41, 3.17Mb/s]
#   5%|5         | 7.29M/137M [00:02<00:43, 2.97Mb/s]
#   6%|5         | 7.60M/137M [00:02<00:44, 2.89Mb/s]
#   6%|5         | 7.90M/137M [00:02<00:45, 2.83Mb/s]
#   6%|5         | 8.18M/137M [00:03<00:54, 2.35Mb/s]
#   6%|6         | 8.72M/137M [00:03<00:41, 3.09Mb/s]
#   7%|6         | 9.06M/137M [00:03<00:51, 2.48Mb/s]
#   7%|6         | 9.55M/137M [00:03<00:42, 3.00Mb/s]
#   7%|7         | 9.90M/137M [00:03<00:44, 2.85Mb/s]
# 100%|#########9| 136M/137M [00:39<00:00, 2.01Mb/s]
# 100%|#########9| 137M/137M [00:39<00:00, 2.17Mb/s]
# 100%|##########| 137M/137M [00:39<00:00, 3.46Mb/s]
# [INFO] Beginning extraction
# [INFO] Chromium extracted to: C:\Users\LENOVO\AppData\Local\pyppeteer\pyppeteer\local-chromium\588429
# [NbConvertApp] Writing 1190622 bytes to AutoScout_Ismail-1.pdf

# %% [markdown]
# ## Understanding Big Picture

# %%
#Import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import datetime
import plotly
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff


from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
#from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["figure.figsize"] = (12, 8)
pd.set_option('display.max_columns', None)
sns.set_theme(font_scale=1.2, style="darkgrid")
#pd.set_option('display.float_format', lambda x: '%.3' % x)

# %%
# Reading file from json
df_origin = pd.read_json('scout_car.json', lines=True)
df = df_origin.copy()
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner NaN   66 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 3  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 4  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection                      Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]               [\nYes\n, \nEuro 6\n]
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN  [\nYes\n, \n109 g CO2/km (comb)\n]
#
#                            Warranty                      Full Service  \
# 0           [\n, \n, \n4 (Green)\n]                          [\n, \n]
# 1                               NaN                               NaN
# 2  [\n, \n, \n99 g CO2/km (comb)\n]                               NaN
# 3                               NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 4              [\n, \n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
#
#     Non-smoking Vehicle null      Make         Model     Offer Number  \
# 0              [\n, \n]   []  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]
# 1                   NaN   []  \nAudi\n  [\n, A1, \n]              NaN
# 2                   NaN   []  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]
# 3  [\n, \n, \nEuro 6\n]   []  \nAudi\n  [\n, A1, \n]              NaN
# 4              [\n, \n]   []  \nAudi\n  [\n, A1, \n]      [\nC1626\n]
#
#   First Registration       Body Color      Paint Type  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN
# 2     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 3     [\n, 2016, \n]  [\n, Brown, \n]  [\nMetallic\n]
# 4     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
#
#             Body Color Original          Upholstery              Body  \
# 0           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
# 2  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 3                           NaN                 NaN  [\n, Sedans, \n]
# 4  [\nMythosschwarz Metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
# 2      [\n4\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 3      [\n3\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 4      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
# 2  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]
# 3  [\n1,422 cc\n]   [\n3\n]  [\n1,195 kg\n]          NaN
# 4  [\n1,422 cc\n]   [\n3\n]             NaN  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
# 2  [\n, Diesel (Particulate Filter), \n]
# 3  [\n, Diesel (Particulate Filter), \n]
# 4  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4  [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 3   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 4  [\n109 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
# 3  [Air suspension, Armrest, Auxiliary heating, E...
# 4  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
# 3  [Bluetooth, CD player, Hands-free equipment, M...
# 4  [Bluetooth, CD player, Hands-free equipment, M...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
# 3         [Alloy wheels, Sport seats, Voice Control]
# 4  [Alloy wheels, Sport package, Sport suspension...
#
#                                \nSafety & Security\n  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
# 3  [ABS, Alarm system, Central door lock with rem...
# 4  [ABS, Central door lock, Driver-side airbag, E...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3  [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4  [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
# 2      NaN             NaN                     NaN               NaN
# 3  [\n6\n]             NaN                     NaN               NaN
# 4      NaN   [\nGermany\n]                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN
# 3              NaN          NaN                           NaN            NaN
# 4              NaN          NaN                           NaN            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.head().T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n2\n
# Next Inspection                            [\n06/2021\n, \n99 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                     [\nLR-062483\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nMythosschwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDF\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,220 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Voice Cont...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Sicherheit:,  , Deaktivierung für Beifahr...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                1  \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                                 1.8 TFSI sport
# body_type                                                                 Sedans
# price                                                                      14500
# vat                                                             Price negotiable
# km                                                                     80,000 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        141 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                        [\n0588/BCY\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,798 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,255 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                           [\n129 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Sport seats, Sport suspension, ...
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\nLangstreckenfahrzeug daher die hohe Kilomet...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                2  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# body_type                                                                 Sedans
# price                                                                      14640
# vat                                                               VAT deductible
# km                                                                     83,450 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                        [\n, \n, \n99 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                      [\nAM-95365\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nmythosschwarz metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                               [MP3, On-board computer]
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                3  \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                        1.4 TDi Design S tronic
# body_type                                                                 Sedans
# price                                                                      14500
# vat                                                                         None
# km                                                                     73,000 km
# registration                                                             08/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                    [\n, \n, \n99 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Brown, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,195 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air suspension, Armrest, Auxiliary heating, E...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                            [Alloy wheels, Sport seats, Voice Control]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock with rem...
# description                    [\nAudi A1: , - 1e eigenaar , - Perfecte staat...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                4
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# body_type                                                                 Sedans
# price                                                                      16790
# vat                                                                         None
# km                                                                     16,200 km
# registration                                                             05/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n109 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                         [\nC1626\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nMythosschwarz Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDF\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                     [Alloy wheels, Sport package, Sport suspension...
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\n, Technik & Sicherheit:, Xenon plus, Klimaa...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %% [markdown]
# ## Preparation

# %%
#df = clean_columns(df) normally it is done with skimpy
df.columns = ['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
       'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
       'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
       'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
       'offer_number', 'first_registration', 'body_color', 'paint_type',
       'body_color_original', 'upholstery', 'body', 'nr_of_doors',
       'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
       'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
       'co_2_emission', 'emission_class', 'comfort_&_convenience',
       'entertainment_&_media', 'extras', 'safety_&_security', 'description',
       'emission_label', 'gears', 'country_version', 'electricity_consumption',
       'last_service_date', 'other_fuel_types', 'availability',
       'last_timing_belt_service_date', 'available_from']

# %%
#Function to look variables to analyze
def first_look(col):
    print('column name : ', col)
    print("--"*20)
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Number of Nulls  : ', df[col].isnull().sum())
    print('Number of Uniques: ', df[col].nunique())
    print('Type of columns: ', df[col].dtype)
    print("--"*20)
    print('Unique values of columns: ', df[col].unique())
    print("--"*20)
    print(df[col].value_counts(dropna = False).sort_index())
    print("--"*20)
    print(df[col].value_counts(dropna = False))
    print("##"*40)
    print()

# %%
# Changing some columns value type from list to str
df = df.applymap(lambda x: ','.join(map(str,x)) if type(x) == list else x)
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  k_w      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners  NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None  NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner  NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner  NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner  NaN   66 kW
#
#                                  type previous_owners  \
# 0  ,Used,,Diesel (Particulate Filter)           \n2\n
# 1                     ,Used,,Gasoline             NaN
# 2  ,Used,,Diesel (Particulate Filter)           \n1\n
# 3  ,Used,,Diesel (Particulate Filter)           \n1\n
# 4  ,Used,,Diesel (Particulate Filter)           \n1\n
#
#                       next_inspection                   inspection_new  \
# 0  \n06/2021\n,\n99 g CO2/km (comb)\n               \nYes\n,\nEuro 6\n
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN  \nYes\n,\n109 g CO2/km (comb)\n
#
#                        warranty                  full_service  \
# 0           \n,\n,\n4 (Green)\n                         \n,\n
# 1                           NaN                           NaN
# 2  \n,\n,\n99 g CO2/km (comb)\n                           NaN
# 3                           NaN  \n,\n,\n99 g CO2/km (comb)\n
# 4              \n,\n,\nEuro 6\n           \n,\n,\n4 (Green)\n
#
#   non_smoking_vehicle null      make     model   offer_number  \
# 0               \n,\n       \nAudi\n  \n,A1,\n  \nLR-062483\n
# 1                 NaN       \nAudi\n  \n,A1,\n            NaN
# 2                 NaN       \nAudi\n  \n,A1,\n   \nAM-95365\n
# 3    \n,\n,\nEuro 6\n       \nAudi\n  \n,A1,\n            NaN
# 4               \n,\n       \nAudi\n  \n,A1,\n      \nC1626\n
#
#   first_registration   body_color    paint_type         body_color_original  \
# 0         \n,2016,\n  \n,Black,\n  \nMetallic\n           \nMythosschwarz\n
# 1         \n,2017,\n    \n,Red,\n           NaN                         NaN
# 2         \n,2016,\n  \n,Black,\n  \nMetallic\n  \nmythosschwarz metallic\n
# 3         \n,2016,\n  \n,Brown,\n  \nMetallic\n                         NaN
# 4         \n,2016,\n  \n,Black,\n  \nMetallic\n  \nMythosschwarz Metallic\n
#
#          upholstery          body nr_of_doors nr_of_seats    model_code  \
# 0  \nCloth, Black\n  \n,Sedans,\n       \n5\n       \n5\n  \n0588/BDF\n
# 1   \nCloth, Grey\n  \n,Sedans,\n       \n3\n       \n4\n  \n0588/BCY\n
# 2  \nCloth, Black\n  \n,Sedans,\n       \n4\n       \n4\n           NaN
# 3               NaN  \n,Sedans,\n       \n3\n       \n4\n           NaN
# 4  \nCloth, Black\n  \n,Sedans,\n       \n5\n       \n5\n  \n0588/BDF\n
#
#       gearing_type  displacement cylinders        weight drive_chain  \
# 0  \n,Automatic,\n  \n1,422 cc\n     \n3\n  \n1,220 kg\n   \nfront\n
# 1  \n,Automatic,\n  \n1,798 cc\n     \n4\n  \n1,255 kg\n   \nfront\n
# 2  \n,Automatic,\n  \n1,598 cc\n       NaN           NaN   \nfront\n
# 3  \n,Automatic,\n  \n1,422 cc\n     \n3\n  \n1,195 kg\n         NaN
# 4  \n,Automatic,\n  \n1,422 cc\n     \n3\n           NaN   \nfront\n
#
#                                 fuel  \
# 0  \n,Diesel (Particulate Filter),\n
# 1                     \n,Gasoline,\n
# 2  \n,Diesel (Particulate Filter),\n
# 3  \n,Diesel (Particulate Filter),\n
# 4  \n,Diesel (Particulate Filter),\n
#
#                                          consumption            co_2_emission  \
# 0  ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...   \n99 g CO2/km (comb)\n
# 1  ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'...  \n129 g CO2/km (comb)\n
# 2  ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'...   \n99 g CO2/km (comb)\n
# 3  ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...   \n99 g CO2/km (comb)\n
# 4  ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'...  \n109 g CO2/km (comb)\n
#
#   emission_class                              comfort_&_convenience  \
# 0     \nEuro 6\n  Air conditioning,Armrest,Automatic climate con...
# 1     \nEuro 6\n  Air conditioning,Automatic climate control,Hil...
# 2     \nEuro 6\n  Air conditioning,Cruise control,Electrical sid...
# 3     \nEuro 6\n  Air suspension,Armrest,Auxiliary heating,Elect...
# 4     \nEuro 6\n  Air conditioning,Armrest,Automatic climate con...
#
#                                entertainment_&_media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                    safety_&_security  \
# 0  ABS,Central door lock,Daytime running lights,D...
# 1  ABS,Central door lock,Central door lock with r...
# 2  ABS,Central door lock,Daytime running lights,D...
# 3  ABS,Alarm system,Central door lock with remote...
# 4  ABS,Central door lock,Driver-side airbag,Elect...
#
#                                          description emission_label  gears  \
# 0  \n,Sicherheit:, ,Deaktivierung für Beifahrer-A...            NaN    NaN
# 1  \nLangstreckenfahrzeug daher die hohe Kilomete...  \n4 (Green)\n  \n7\n
# 2  \n,Fahrzeug-Nummer: AM-95365, ,Ehem. UPE 24.64...  \n4 (Green)\n    NaN
# 3  \nAudi A1: ,- 1e eigenaar ,- Perfecte staat: s...            NaN  \n6\n
# 4  \n,Technik & Sicherheit:,Xenon plus,Klimaautom...            NaN    NaN
#
#   country_version electricity_consumption last_service_date other_fuel_types  \
# 0             NaN                     NaN               NaN              NaN
# 1             NaN                     NaN               NaN              NaN
# 2             NaN                     NaN               NaN              NaN
# 3             NaN                     NaN               NaN              NaN
# 4     \nGermany\n                     NaN               NaN              NaN
#
#   availability last_timing_belt_service_date available_from
# 0          NaN                           NaN            NaN
# 1          NaN                           NaN            NaN
# 2          NaN                           NaN            NaN
# 3          NaN                           NaN            NaN
# 4          NaN                           NaN            NaN

# %%
for i in df.select_dtypes(include="O"):
    first_look(i)
# Out:
# column name :  url
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  15919
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  

# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-1c94c7a2-67b5-49ca-ae42-42a6800fb3f5                       1
# https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481          1
# Name: url, Length: 15919, dtype: int64
# ################################################################################
#
# column name :  make_model
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Audi A1' 'Audi A2' 'Audi A3' 'Opel Astra' 'Opel Corsa' 'Opel Insignia'
#  'Renault Clio' 'Renault Duster' 'Renault Espace']
# ----------------------------------------
# Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ----------------------------------------
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
# ################################################################################
#
# column name :  short_description
# ----------------------------------------
# Per_of_Nulls   :  % 0.29
# Number of Nulls  :  46
# Number of Uniques:  10001
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Sportback 1.4 TDI S-tronic Xenon Navi Klima' '1.8 TFSI sport'
#  'Sportback 1.6 TDI S tronic Einparkhilfe plus+music' ...
#  'ELYSEE ENERGY dCi 160 EDC' 'INITIALE Paris TCe 225 EDC GPF ACC EU6'
#  'TCe 225 EDC GPF LIM Deluxe Pano,RFK']
# ----------------------------------------
#  1,6 CDTI**NAVI*Klimaaut*Tempomat*EURO6*TÜV NEU     1
#  1.4 75 cv5 porte b-color                           1
#  1.4 TFSI Attraction (125 CV)                       6
#  1.4 Turbo S&S Excellence (125 CV)                  2
#  1.6 CDTi Dynamic (110 CV)                          4
#                                                    ..
# van 1.5 dci 75cv S S E6                             1
# van 1.5 dci 75cv S&S E6                            24
# zoé life                                            1
# Österr. Edition 16.CDTI                             1
# NaN                                                46
# Name: short_description, Length: 10002, dtype: int64
# ----------------------------------------
# SPB 1.6 TDI 116 CV S tronic Sport                 64
# NaN                                               46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10002, dtype: int64
# ################################################################################
#
# column name :  body_type
# ----------------------------------------
# Per_of_Nulls   :  % 0.38
# Number of Nulls  :  60
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Sedans' 'Station wagon' 'Compact' 'Other' 'Coupe' 'Van' 'Off-Road'
#  'Convertible' None 'Transporter']
# ----------------------------------------
# Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ----------------------------------------
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# ################################################################################
#
# column name :  vat
# ----------------------------------------
# Per_of_Nulls   :  % 28.35
# Number of Nulls  :  4513
# Number of Uniques:  2
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['VAT deductible' 'Price negotiable' None]
# ----------------------------------------
# Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ----------------------------------------
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
# ################################################################################
#
# column name :  km
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  6690
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['56,013 km' '80,000 km' '83,450 km' ... '2,864 km' '1,506 km' '57 km']
# ----------------------------------------
# - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ----------------------------------------
# 10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
# ################################################################################
#
# column name :  registration
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  48
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['01/2016' '03/2017' '02/2016' '08/2016' '05/2016' '03/2016' '06/2017'
#  '05/2018' '09/2016' '06/2016' '10/2016' '04/2016' '06/2018' '11/2017'
#  '07/2016' '12/2016' '09/2018' '04/2018' '07/2017' '02/2017' '11/2016'
#  '01/2018' '05/2017' '04/2017' '07/2018' '01/2017' '02/2018' '03/2018'
#  '-/-' '08/2017' '10/2017' '08/2018' '09/2017' '12/2017' '04/2019'
#  '12/2018' '03/2019' '06/2019' '05/2019' '02/2019' '01/2019' '10/2018'
#  '11/2018' '09/2019' '07/2019' '08/2019' '11/2019' '12/2019']
# ----------------------------------------
# -/-        1597
# 01/2016     376
# 01/2017     306
# 01/2018     511
# 01/2019     541
# 02/2016     472
# 02/2017     368
# 02/2018     539
# 02/2019     585
# 03/2016     536
# 03/2017     471
# 03/2018     695
# 03/2019     543
# 04/2016     532
# 04/2017     380
# 04/2018     541
# 04/2019     506
# 05/2016     459
# 05/2017     404
# 05/2018     572
# 05/2019     440
# 06/2016     452
# 06/2017     409
# 06/2018     532
# 06/2019     224
# 07/2016     176
# 07/2017     215
# 07/2018     396
# 07/2019       6
# 08/2016      94
# 08/2017     114
# 08/2018     285
# 08/2019       1
# 09/2016     141
# 09/2017     149
# 09/2018     141
# 09/2019       5
# 10/2016     160
# 10/2017     154
# 10/2018      97
# 11/2016     142
# 11/2017     180
# 11/2018     110
# 11/2019       1
# 12/2016     134
# 12/2017     123
# 12/2018     103
# 12/2019       1
# Name: registration, dtype: int64
# ----------------------------------------
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64
# ################################################################################
#
# column name :  prev_owner
# ----------------------------------------
# Per_of_Nulls   :  % 42.89
# Number of Nulls  :  6828
# Number of Uniques:  4
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['2 previous owners' None '1 previous owner' '3 previous owners'
#  '4 previous owners']
# ----------------------------------------
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ----------------------------------------
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
# ################################################################################
#
# column name :  hp
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  81
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['66 kW' '141 kW' '85 kW' '70 kW' '92 kW' '112 kW' '60 kW' '71 kW' '67 kW'
#  '110 kW' '93 kW' '147 kW' '86 kW' '140 kW' '87 kW' '- kW' '81 kW' '82 kW'
#  '135 kW' '132 kW' '100 kW' '96 kW' '162 kW' '150 kW' '294 kW' '228 kW'
#  '270 kW' '137 kW' '9 kW' '133 kW' '77 kW' '101 kW' '78 kW' '103 kW'
#  '1 kW' '74 kW' '118 kW' '84 kW' '88 kW' '80 kW' '76 kW' '149 kW' '44 kW'
#  '51 kW' '55 kW' '52 kW' '63 kW' '40 kW' '65 kW' '75 kW' '125 kW' '120 kW'
#  '184 kW' '239 kW' '121 kW' '143 kW' '191 kW' '89 kW' '195 kW' '127 kW'
#  '122 kW' '154 kW' '155 kW' '104 kW' '123 kW' '146 kW' '90 kW' '53 kW'
#  '54 kW' '56 kW' '164 kW' '4 kW' '163 kW' '57 kW' '119 kW' '165 kW'
#  '117 kW' '115 kW' '98 kW' '168 kW' '167 kW']
# ----------------------------------------
# - kW        88
# 1 kW        20
# 100 kW    1308
# 101 kW      47
# 103 kW     253
#           ...
# 90 kW        4
# 92 kW      466
# 93 kW        3
# 96 kW       72
# 98 kW        3
# Name: hp, Length: 81, dtype: int64
# ----------------------------------------
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
#           ...
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 9 kW         1
# Name: hp, Length: 81, dtype: int64
# ################################################################################
#
# column name :  type
# ----------------------------------------
# Per_of_Nulls   :  % 0.01
# Number of Nulls  :  2
# Number of Uniques:  169
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [',Used,,Diesel (Particulate Filter)' ',Used,,Gasoline' ',Used,,Super 95'
#  ',Used,,Regular/Benzine 91'
#  ",Employee's car,,Diesel (Particulate Filter)" ',Used,,Diesel'
#  ',Used,,Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98'
#  ",Employee's car,,Regular/Benzine 91" ",Employee's car,,Diesel"
#  ",Employee's car,,Super E10 95" ',New,,Super 95 (Particulate Filter)'
#  ',Used,,Super 95 / Regular/Benzine 91' ",Employee's car,,Super 95"
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Super E10 95 / Super 95' ',Used,,Super E10 95'
#  ',Used,,Super 95 / Regular/Benzine 91 / Super Plus 98'
#  ',Demonstration,,Super 95'
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95'
#  ',Used,,Super 95 / Super Plus 98' ",Employee's car,,Gasoline"
#  ',Used,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  ',Pre-registered,,Gasoline' ',New,,Gasoline' ',Used,,Others'
#  ',Demonstration,,Super 95 / Super E10 95' ',Demonstration,,Gasoline'
#  ',New,,Super 95' ',Pre-registered,,Diesel (Particulate Filter)'
#  ',Pre-registered,,Diesel' ',Used,,Super 95 / Super E10 95'
#  ',Demonstration,,Diesel (Particulate Filter)' ',Pre-registered,,Super 95'
#  ',New,,Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91' ',Demonstration,,Diesel'
#  ',Used,,Gasoline (Particulate Filter)'
#  ',Used,,Regular/Benzine E10 91 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 (Particulate Filter)'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98 (Particulate Filter)'
#  ',Demonstration,,Super 95 (Particulate Filter)'
#  ',New,,Regular/Benzine E10 91' ',Demonstration,,Super E10 95'
#  ",Employee's car,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95"
#  ',New,,Regular/Benzine 91 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine 91 (Particulate Filter)'
#  ',New,,Super E10 95' ',New,,Super E10 95 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine 91'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ",Employee's car,,Regular/Benzine 91 (Particulate Filter)"
#  ',New,,Super Plus 98' ',Pre-registered,,Regular/Benzine 91'
#  ",Employee's car,,Gasoline (Particulate Filter)" ',New,,Diesel'
#  ',New,,Super E10 95 / Super 95' ',New,,Super 95 / Regular/Benzine 91'
#  ',New,,Super 95 / Super E10 95' ',New,,Diesel (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98'
#  ',Demonstration,,Super E10 95 / Super 95' ',Used,,CNG'
#  ',Used,,Super 95 (Particulate Filter)' nan ',New,,CNG'
#  ',Used,,Electric/Gasoline' ',Used,,CNG (Particulate Filter)'
#  ',Pre-registered,,Gasoline (Particulate Filter)'
#  ',Used,,Others (Particulate Filter)'
#  ',Pre-registered,,Regular/Benzine 91 (Particulate Filter)'
#  ',Used,,Super Plus 98' ',Pre-registered,,Super E10 95'
#  ',Pre-registered,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',New,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',Used,,Regular/Benzine 91 (Particulate Filter)'
#  ',Demonstration,,Super E10 95 (Particulate Filter)'
#  ',New,,Gasoline (Particulate Filter)' ',Pre-registered,,Biogas'
#  ',Pre-registered,,CNG (Particulate Filter)'
#  ',New,,CNG (Particulate Filter)' ',New,,Super 95 / Biodiesel'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',Used,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 (Particulate Filter)'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Super E10 95 (Particulate Filter)'
#  ',Used,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Domestic gas H'
#  ',Used,,Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  ",Employee's car,,Super 95 / Regular/Benzine 91"
#  ",Employee's car,,Super 95 (Particulate Filter)"
#  ',Pre-registered,,Regular/Benzine 91 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super 95 / Regular/Benzine 91'
#  ',Used,,Regular/Benzine E10 91'
#  ',Used,,Super E10 95 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98'
#  ',Used,,Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95'
#  ',New,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',Pre-registered,,Super Plus 98'
#  ',Demonstration,,Super Plus 98 / Super 95 / Super E10 95'
#  ',Demonstration,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95' ',New,,Super Plus E10 98'
#  ',Used,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',Demonstration,,Super Plus 98'
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',New,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super Plus 98 / Super E10 95'
#  ',Pre-registered,,Super 95 / Super E10 95'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98'
#  ',Pre-registered,,CNG'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',New,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',Used,,Super 95 / Super E10 95 (Particulate Filter)'
#  ",Employee's car,,Super E10 95 (Particulate Filter)"
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95' ',Used,,LPG'
#  ',Used,,Liquid petroleum gas (LPG)'
#  ",Employee's car,,Super 95 / Super E10 95"
#  ',Used,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  ",Employee's car,,LPG"
#  ',Used,,Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Super 95 / Regular/Benzine 91'
#  ",Employee's car,,Super E10 95 / Super 95"
#  ",Employee's car,,Regular/Benzine 91 / Super 95 / Super E10 95"
#  ',Used,,Super 95 / Regular/Benzine E10 91 / Super E10 95'
#  ',Pre-registered,,Regular/Benzine E10 91'
#  ',Pre-registered,,Super 95 / Super Plus 98'
#  ',Used,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95'
#  ',Demonstration,,Super 95 / Super Plus 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super E10 95 / Regular/Benzine E10 91'
#  ',Demonstration,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',Used,,Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91'
#  ',New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',Pre-registered,,Liquid petroleum gas (LPG)' ',Pre-registered,,Others'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98'
#  ',Pre-registered,,Super E10 95 / Regular/Benzine 91 / Regular/Benzine E10 91 / Super 95'
#  ',New,,LPG' ',Used,,Super 95 / Regular/Benzine E10 91'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super E10 95 / Super 95'
#  ',Used,,Super 95 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  ',Demonstration,,Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95 / Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super Plus 98 / Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 (Particulate Filter)'
#  ',Pre-registered,,Super 95 / Super E10 95 / Regular/Benzine 91'
#  ',Used,,Super 95 / Super E10 95 / Super Plus 98' ',Used,,Electric'
#  ',Pre-registered,,LPG'
#  ',Demonstration,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95'
#  ",Employee's car,,Super E10 95 / Super 95 / Super Plus 98"
#  ',Demonstration,,Gasoline (Particulate Filter)'
#  ',Used,,Super E10 95 / Regular/Benzine 91'
#  ',Used,,Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',Pre-registered,,Super Plus 98 / Super 95 / Super Plus E10 98'
#  ",Employee's car,,Others"
#  ',Pre-registered,,Super E10 95 / Regular/Benzine 91'
#  ',Pre-registered,,Super E10 95 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine E10 91']
# ----------------------------------------
# ,Demonstration,,Diesel                                                 45
# ,Demonstration,,Diesel (Particulate Filter)                           129
# ,Demonstration,,Gasoline                                              158
# ,Demonstration,,Gasoline (Particulate Filter)                           1
# ,Demonstration,,Regular/Benzine 91                                     36
#                                                                      ...
# ,Used,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98      8
# ,Used,,Super E10 95 / Super Plus E10 98                                 4
# ,Used,,Super Plus 98                                                    2
# ,Used,,Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95      1
# NaN                                                                     2
# Name: type, Length: 170, dtype: int64
# ----------------------------------------
# ,Used,,Diesel (Particulate Filter)                                                                                 3475
# ,Used,,Diesel                                                                                                      2516
# ,Used,,Gasoline                                                                                                    2367
# ,Used,,Super 95                                                                                                    1818
# ,Pre-registered,,Super 95                                                                                           500
#                                                                                                                    ...
# ,New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95       1
# ,Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)                               1
# ,Demonstration,,Super Plus 98                                                                                         1
# ,New,,Super Plus E10 98                                                                                               1
# ,Demonstration,,Regular/Benzine E10 91                                                                                1
# Name: type, Length: 170, dtype: int64
# ################################################################################
#
# column name :  previous_owners
# ----------------------------------------
# Per_of_Nulls   :  % 41.71
# Number of Nulls  :  6640
# Number of Uniques:  101
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['\n2\n' nan '\n1\n' '\n0\n' '\n3\n' '\n4\n'
#  '\n1\n,\n102 g CO2/km (comb)\n' '\n1\n,\n105 g CO2/km (comb)\n'
#  '\n1\n,\n110 g CO2/km (comb)\n' '\n1\n,\n116 g CO2/km (comb)\n'
#  '\n1\n,\n,4.8 l/100 km (comb),\n,5.9 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\n0\n,\n0 kWh/100 km (comb)\n' '\n0\n,\n105 g CO2/km (comb)\n'
#  '\n0\n,\n106 g CO2/km (comb)\n'
#  '\n0\n,\n,4.6 l/100 km (comb),\n,5.8 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\n0\n,\n104 g CO2/km (comb)\n' '\n1\n,\n111 g CO2/km (comb)\n'
#  '\n1\n,\n,4.9 l/100 km (comb),\n,6 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\n2\n,\n127 g CO2/km (comb)\n' '\n1\n,\n99 g CO2/km (comb)\n'
#  '\n2\n,\n122 g CO2/km (comb)\n' '\n1\n,\n114 g CO2/km (comb)\n'
#  '\n1\n,\n109 g CO2/km (comb)\n' '\n1\n,\n107 g CO2/km (comb)\n'
#  '\n1\n,\n,5.2 l/100 km (comb),\n,6 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\n0\n,\n117 g CO2/km (comb)\n' '\n0\n,\n107 g CO2/km (comb)\n'
#  '\n0\n,\n114 g CO2/km (comb)\n' '\n2\n,\n124 g CO2/km (comb)\n'
#  '\n1\n,\n125 g CO2/km (comb)\n' '\n2\n,\n119 g CO2/km (comb)\n'
#  '\n1\n,\n,6.3 l/100 km (comb),\n,8.6 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\n1\n,\n128 g CO2/km (comb)\n' '\n1\n,\n119 g CO2/km (comb)\n'
#  '\n1\n,\n124 g CO2/km (comb)\n' '\n1\n,\n127 g CO2/km (comb)\n'
#  '\n1\n,\n96 g CO2/km (comb)\n' '\n1\n,\n104 g CO2/km (comb)\n'
#  '\n1\n,\n,5.7 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\n1\n,\n134 g CO2/km (comb)\n'
#  '\n1\n,\n,6.5 l/100 km (comb),\n,8.5 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\n1\n,\n,5.4 l/100 km (comb),\n,7.1 l/100 km (city),\n,4.4 l/100 km (country),\n'
#  '\n1\n,\n,5.9 l/100 km (comb),\n,7.4 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\n1\n,\n129 g CO2/km (comb)\n'
#  '\n0\n,\n,5.4 l/100 km (comb),\n,7.1 l/100 km (city),\n,4.4 l/100 km (country),\n'
#  '\n1\n,\n,5 l/100 km (comb),\n,5.9 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\n1\n,\n,6 l/100 km (comb),\n,7.8 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\n1\n,\n133 g CO2/km (comb)\n' '\n1\n,\n0 g CO2/km (comb)\n'
#  '\n1\n,\n137 g CO2/km (comb)\n' '\n2\n,\n137 g CO2/km (comb)\n'
#  '\n1\n,\n142 g CO2/km (comb)\n' '\n1\n,\n84 g CO2/km (comb)\n'
#  '\n1\n,\n140 g CO2/km (comb)\n'
#  '\n2\n,\n,5.6 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\n2\n,\n129 g CO2/km (comb)\n'
#  '\n1\n,\n,5.9 l/100 km (comb),\n,7.5 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\n1\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.7 l/100 km (country),\n'
#  '\n1\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\n1\n,\n,6 l/100 km (comb),\n,8 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\n1\n,\n,5.9 l/100 km (comb),\n,7.9 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\n1\n,\n,6.3 l/100 km (comb),\n,7.8 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\n1\n,\n,6.2 l/100 km (comb),\n,7.9 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\n1\n,\n149 g CO2/km (comb)\n' '\n1\n,\nEuro 6\n'
#  '\n0\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.7 l/100 km (country),\n'
#  '\n1\n,\n,6.6 l/100 km (comb),\n,8.1 l/100 km (city),\n,5.7 l/100 km (country),\n'
#  '\n0\n,\n126 g CO2/km (comb)\n' '\n0\n,\n120 g CO2/km (comb)\n'
#  '\n1\n,\n,5.6 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\n1\n,\n159 g CO2/km (comb)\n' '\n1\n,\n145 g CO2/km (comb)\n'
#  '\n1\n,\n126 g CO2/km (comb)\n'
#  '\n1\n,\n,6 l/100 km (comb),\n,7.7 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\n1\n,\n147 g CO2/km (comb)\n' '\n1\n,\n150 g CO2/km (comb)\n'
#  '\n1\n,\n141 g CO2/km (comb)\n' '\n0\n,\n136 g CO2/km (comb)\n'
#  '\n1\n,\n136 g CO2/km (comb)\n'
#  '\n1\n,\n,5.8 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\n1\n,\n181 g CO2/km (comb)\n'
#  '\n1\n,\n,6.1 l/100 km (comb),\n,7.7 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\n1\n,\n,6.7 l/100 km (comb),\n,8.6 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\n1\n,\n,5.9 l/100 km (comb),\n,7.6 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\n0\n,\n187 g CO2/km (comb)\n' '\n0\n,\n139 g CO2/km (comb)\n'
#  '\n1\n,\n188 g CO2/km (comb)\n' '\n1\n,\n187 g CO2/km (comb)\n'
#  '\n1\n,\n120 g CO2/km (comb)\n' '\n1\n,\n85 g CO2/km (comb)\n'
#  '\n1\n,\n,5.9 l/100 km (comb),\n,7.6 l/100 km (city),\n,5.1 l/100 km (country),\n'
#  '\n1\n,\n135 g CO2/km (comb)\n'
#  '\n1\n,\n,5 l/100 km (comb),\n,6.3 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\n1\n,\n113 g CO2/km (comb)\n' '\n2\n,\n123 g CO2/km (comb)\n'
#  '\n2\n,\n125 g CO2/km (comb)\n' '\n1\n,\n139 g CO2/km (comb)\n'
#  '\n1\n,\n,6.8 l/100 km (comb),\n,8.7 l/100 km (city),\n,5.7 l/100 km (country),\n'
#  '\n1\n,\n153 g CO2/km (comb)\n' '\n1\n,\n168 g CO2/km (comb)\n'
#  '\n1\n,\n,7.4 l/100 km (comb),\n,9.2 l/100 km (city),\n,6.3 l/100 km (country),\n'
#  '\n1\n,\n123 g CO2/km (comb)\n']
# ----------------------------------------
# \n0\n                                                                                163
# \n0\n,\n,4.6 l/100 km (comb),\n,5.8 l/100 km (city),\n,3.9 l/100 km (country),\n       1
# \n0\n,\n,5.4 l/100 km (comb),\n,7.1 l/100 km (city),\n,4.4 l/100 km (country),\n       2
# \n0\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.7 l/100 km (country),\n       1
# \n0\n,\n0 kWh/100 km (comb)\n                                                          2
#                                                                                     ...
# \n2\n,\n129 g CO2/km (comb)\n                                                          2
# \n2\n,\n137 g CO2/km (comb)\n                                                          1
# \n3\n                                                                                 17
# \n4\n                                                                                  2
# NaN                                                                                 6640
# Name: previous_owners, Length: 102, dtype: int64
# ----------------------------------------
# \n1\n                                                                               8103
# NaN                                                                                 6640
# \n2\n                                                                                766
# \n0\n                                                                                163
# \n3\n                                                                                 17
#                                                                                     ...
# \n1\n,\n111 g CO2/km (comb)\n                                                          1
# \n1\n,\nEuro 6\n                                                                       1
# \n2\n,\n119 g CO2/km (comb)\n                                                          1
# \n1\n,\n,6.6 l/100 km (comb),\n,8.1 l/100 km (city),\n,5.7 l/100 km (country),\n       1
# \n1\n,\n142 g CO2/km (comb)\n                                                          1
# Name: previous_owners, Length: 102, dtype: int64
# ################################################################################
#
# column name :  next_inspection
# ----------------------------------------
# Per_of_Nulls   :  % 77.79
# Number of Nulls  :  12384
# Number of Uniques:  1384
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['\n06/2021\n,\n99 g CO2/km (comb)\n' nan
#  '\n02/2020\n,\n97 g CO2/km (comb)\n' ...
#  '\n02/2022\n,\n153 g CO2/km (comb)\n'
#  '\n06/2021\n,\n,7.4 l/100 km (comb),\n,9.2 l/100 km (city),\n,6.3 l/100 km (country),\n'
#  '\n01/2022\n,\n168 g CO2/km (comb)\n']
# ----------------------------------------
# \n01/1921\n,\n120 g CO2/km (comb)\n        1
# \n01/1955\n                                1
# \n01/1999\n                                1
# \n01/2001\n,\n120 g CO2/km (comb)\n        1
# \n01/2001\n,\n122 g CO2/km (comb)\n        2
#                                        ...
# \n12/2021\n,\n153 g CO2/km (comb)\n        4
# \n12/2021\n,\n167 g CO2/km (comb)\n        1
# \n12/2021\n,\nEuro 6\n                     1
# \n12/2022\n                                1
# NaN                                    12384
# Name: next_inspection, Length: 1385, dtype: int64
# ----------------------------------------
# NaN                                    12384
# \n04/2022\n                               62
# \n06/2021\n                               47
# \n03/2021\n                               39
# \n03/2022\n                               36
#                                        ...
# \n06/2021\n,\n121 g CO2/km (comb)\n        1
# \n02/2020\n,\n139 g CO2/km (comb)\n        1
# \n10/2021\n,\n136 g CO2/km (comb)\n        1
# \n06/2019\n,\n139 g CO2/km (comb)\n        1
# \n01/2022\n,\n168 g CO2/km (comb)\n        1
# Name: next_inspection, Length: 1385, dtype: int64
# ################################################################################
#
# column name :  inspection_new
# ----------------------------------------
# Per_of_Nulls   :  % 75.3
# Number of Nulls  :  11987
# Number of Uniques:  201
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['\nYes\n,\nEuro 6\n' nan '\nYes\n,\n109 g CO2/km (comb)\n'
#  '\nYes\n,\n98 g CO2/km (comb)\n' '\nYes\n,\n97 g CO2/km (comb)\n'
#  '\nYes\n,\n112 g CO2/km (comb)\n' '\nYes\n,\n0 kWh/100 km (comb)\n'
#  '\nYes\n,\n104 g CO2/km (comb)\n' '\nYes\n,\n102 g CO2/km (comb)\n'
#  '\nYes\n,\n91 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.2 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\nYes\n,\n99 g CO2/km (comb)\n' '\nYes\n'
#  '\nYes\n,\n92 g CO2/km (comb)\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,6.2 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n103 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.9 l/100 km (comb),\n,6.2 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n107 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.4 l/100 km (city),\n,3.8 l/100 km (country),\n'
#  '\nYes\n,\n,4.6 l/100 km (comb),\n,5.6 l/100 km (city),\n,4 l/100 km (country),\n'
#  '\nYes\n,\n121 g CO2/km (comb)\n' '\nYes\n,\n123 g CO2/km (comb)\n'
#  '\nYes\n,\n113 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,5.8 l/100 km (city),\n,4.1 l/100 km (country),\n'
#  '\nYes\n,\n106 g CO2/km (comb)\n' '\nYes\n,\n117 g CO2/km (comb)\n'
#  '\nYes\n,\n118 g CO2/km (comb)\n' '\nYes\n,\nEuro 4\n'
#  '\nYes\n,\n,4.2 l/100 km (comb),\n,5 l/100 km (city),\n,3.7 l/100 km (country),\n'
#  '\nYes\n,\n115 g CO2/km (comb)\n' '\nYes\n,\n4 (Green)\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7.1 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\nYes\n,\n,4.5 l/100 km (comb),\n,5.5 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\nYes\n,\n111 g CO2/km (comb)\n' '\nYes\n,\n114 g CO2/km (comb)\n'
#  '\nYes\n,\n90 g CO2/km (comb)\n' '\nYes\n,\n108 g CO2/km (comb)\n'
#  '\nYes\n,\n105 g CO2/km (comb)\n' '\nYes\n,\n129 g CO2/km (comb)\n'
#  '\nYes\n,\n134 g CO2/km (comb)\n' '\nYes\n,\n110 g CO2/km (comb)\n'
#  '\nYes\n,\nEuro 6d-TEMP\n' '\nYes\n,\n122 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.8 l/100 km (comb),\n,5.9 l/100 km (city),\n,4.1 l/100 km (country),\n'
#  '\nYes\n,\n116 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.9 l/100 km (comb),\n,5.9 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n136 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,5.9 l/100 km (city),\n,4 l/100 km (country),\n'
#  '\nYes\n,\n,4.9 l/100 km (comb),\n,6 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n120 g CO2/km (comb)\n' '\nYes\n,\n119 g CO2/km (comb)\n'
#  '\nYes\n,\n127 g CO2/km (comb)\n' '\nYes\n,\n130 g CO2/km (comb)\n'
#  '\nYes\n,\n101 g CO2/km (comb)\n' '\nYes\n,\n89 g CO2/km (comb)\n'
#  '\nYes\n,\n85 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.5 l/100 km (comb),\n,5.4 l/100 km (city),\n,4 l/100 km (country),\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,5.7 l/100 km (city),\n,4.1 l/100 km (country),\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.5 l/100 km (city),\n,3.8 l/100 km (country),\n'
#  '\nYes\n,\n88 g CO2/km (comb)\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,5.8 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\n125 g CO2/km (comb)\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,5.5 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\nYes\n,\n124 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.4 l/100 km (comb),\n,7.1 l/100 km (city),\n,4.4 l/100 km (country),\n'
#  '\nYes\n,\n,4.5 l/100 km (comb),\n,5.7 l/100 km (city),\n,3.8 l/100 km (country),\n'
#  '\nYes\n,\n,5.1 l/100 km (comb),\n,6.3 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n128 g CO2/km (comb)\n' '\nYes\n,\n158 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.6 l/100 km (comb),\n,8.5 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\nYes\n,\n126 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.4 l/100 km (comb),\n,8.3 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\nYes\n,\n,5.5 l/100 km (comb),\n,7.2 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\n152 g CO2/km (comb)\n' '\nYes\n,\nEuro 5\n'
#  '\nYes\n,\n174 g CO2/km (comb)\n' '\nYes\n,\n95 g CO2/km (comb)\n'
#  '\nYes\n,\n154 g CO2/km (comb)\n' '\nYes\n,\n93 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.4 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\nYes\n,\n145 g CO2/km (comb)\n' '\nYes\n,\n96 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.6 l/100 km (country),\n'
#  '\nYes\n,\n149 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.4 l/100 km (comb),\n,8.4 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,6.3 l/100 km (comb),\n,8.3 l/100 km (city),\n,5.1 l/100 km (country),\n'
#  '\nYes\n,\n,4.3 l/100 km (comb),\n,5.1 l/100 km (city),\n,3.8 l/100 km (country),\n'
#  '\nYes\n,\n12,087 g CO2/km (comb)\n' '\nYes\n,\n148 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.7 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\n,5.9 l/100 km (comb),\n,7.4 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\nYes\n,\n94 g CO2/km (comb)\n' '\nYes\n,\n131 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.2 l/100 km (comb),\n,6.6 l/100 km (city),\n,4.4 l/100 km (country),\n'
#  '\nYes\n,\n,5.5 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\nEuro 6d\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,5.4 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n,4.3 l/100 km (comb),\n,5.2 l/100 km (city),\n,3.9 l/100 km (country),\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.7 l/100 km (city),\n,3.7 l/100 km (country),\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,5.9 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\n151 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.7 l/100 km (comb),\n,8.7 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\nYes\n,\n,6.6 l/100 km (comb),\n,8.5 l/100 km (city),\n,5.5 l/100 km (country),\n'
#  '\nYes\n,\n141 g CO2/km (comb)\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,7.5 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.5 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n138 g CO2/km (comb)\n' '\nYes\n,\n139 g CO2/km (comb)\n'
#  '\nYes\n,\n135 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.1 l/100 km (comb),\n,7.5 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,5.5 l/100 km (comb),\n,6.8 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\nYes\n,\n,4.4 l/100 km (comb),\n,5.4 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\nYes\n,\n,4.8 l/100 km (comb),\n,5.7 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n,4.6 l/100 km (comb),\n,5.4 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n,5.5 l/100 km (comb),\n,6.4 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,5.9 l/100 km (comb),\n,7.8 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n,5.8 l/100 km (comb),\n,7.6 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n159 g CO2/km (comb)\n' '\nYes\n,\n143 g CO2/km (comb)\n'
#  '\nYes\n,\n140 g CO2/km (comb)\n' '\nYes\n,\n137 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,5.8 l/100 km (city),\n,4 l/100 km (country),\n'
#  '\nYes\n,\n,5.9 l/100 km (comb),\n,7.9 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\nYes\n,\n,4.9 l/100 km (comb),\n,\n,\n'
#  '\nYes\n,\n142 g CO2/km (comb)\n'
#  '\nYes\n,\n,4.7 l/100 km (comb),\n,\n,\n'
#  '\nYes\n,\n,5.8 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,5.4 l/100 km (comb),\n,6.7 l/100 km (city),\n,4.6 l/100 km (country),\n'
#  '\nYes\n,\nEuro 6c\n' '\nYes\n,\n,6.3 l/100 km (comb),\n,\n,\n'
#  '\nYes\n,\n,5.1 l/100 km (comb),\n,6.4 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n132 g CO2/km (comb)\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,7.8 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n100 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.2 l/100 km (comb),\n,6.7 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n,5.4 l/100 km (comb),\n,\n,\n'
#  '\nYes\n,\n,5.7 l/100 km (comb),\n,7.2 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n,5.3 l/100 km (comb),\n,6.6 l/100 km (city),\n,4.5 l/100 km (country),\n'
#  '\nYes\n,\n150 g CO2/km (comb)\n' '\nYes\n,\n1 (No sticker)\n'
#  '\nYes\n,\n156 g CO2/km (comb)\n' '\nYes\n,\n146 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.2 l/100 km (comb),\n,6.6 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n,5.7 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,6.9 l/100 km (comb),\n,8.6 l/100 km (city),\n,6 l/100 km (country),\n'
#  '\nYes\n,\n,6.6 l/100 km (comb),\n,8.2 l/100 km (city),\n,5.7 l/100 km (country),\n'
#  '\nYes\n,\n,5.2 l/100 km (comb),\n,6.8 l/100 km (city),\n,4.3 l/100 km (country),\n'
#  '\nYes\n,\n,6.3 l/100 km (comb),\n,7.8 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\nYes\n,\n,6.8 l/100 km (comb),\n,8.5 l/100 km (city),\n,6.1 l/100 km (country),\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,8 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,6.2 l/100 km (comb),\n,7.8 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\nYes\n,\n,4.8 l/100 km (comb),\n,5.8 l/100 km (city),\n,4.1 l/100 km (country),\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7.2 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n133 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7.3 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\nYes\n,\n170 g CO2/km (comb)\n' '\nYes\n,\n194 g CO2/km (comb)\n'
#  '\nYes\n,\n164 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.2 l/100 km (comb),\n,7.7 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\nYes\n,\n144 g CO2/km (comb)\n' '\nYes\n,\n147 g CO2/km (comb)\n'
#  '\nYes\n,\n169 g CO2/km (comb)\n'
#  '\nYes\n,\n,7 l/100 km (comb),\n,9.5 l/100 km (city),\n,5.5 l/100 km (country),\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,7.3 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,7.7 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,5.9 l/100 km (comb),\n,7.5 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.5 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\nYes\n,\n,6.2 l/100 km (comb),\n,7.6 l/100 km (city),\n,5.4 l/100 km (country),\n'
#  '\nYes\n,\n,5.8 l/100 km (comb),\n,\n,\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.7 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,5.8 l/100 km (comb),\n,7.5 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,6 l/100 km (comb),\n,7.6 l/100 km (city),\n,5 l/100 km (country),\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.6 l/100 km (city),\n,5.2 l/100 km (country),\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,6.9 l/100 km (city),\n,4.8 l/100 km (country),\n'
#  '\nYes\n,\n187 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.6 l/100 km (comb),\n,8.3 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\nYes\n,\n186 g CO2/km (comb)\n' '\nYes\n,\n166 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.8 l/100 km (city),\n,5.1 l/100 km (country),\n'
#  '\nYes\n,\n177 g CO2/km (comb)\n' '\nYes\n,\n180 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.7 l/100 km (comb),\n,8.6 l/100 km (city),\n,5.6 l/100 km (country),\n'
#  '\nYes\n,\n,8.6 l/100 km (comb),\n,11.5 l/100 km (city),\n,7 l/100 km (country),\n'
#  '\nYes\n,\n188 g CO2/km (comb)\n'
#  '\nYes\n,\n,6.3 l/100 km (comb),\n,8 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\nYes\n,\n155 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.6 l/100 km (comb),\n,7 l/100 km (city),\n,4.6 l/100 km (country),\n'
#  '\nYes\n,\n,6.1 l/100 km (comb),\n,7.7 l/100 km (city),\n,5.1 l/100 km (country),\n'
#  '\nYes\n,\n183 g CO2/km (comb)\n' '\nYes\n,\n87 g CO2/km (comb)\n'
#  '\nYes\n,\n,5.7 l/100 km (comb),\n,7.2 l/100 km (city),\n,4.9 l/100 km (country),\n'
#  '\nYes\n,\n,5.9 l/100 km (comb),\n,7.6 l/100 km (city),\n,5.1 l/100 km (country),\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,6.3 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n,5 l/100 km (comb),\n,6.4 l/100 km (city),\n,4.2 l/100 km (country),\n'
#  '\nYes\n,\n,6.2 l/100 km (comb),\n,7.8 l/100 km (city),\n,5.3 l/100 km (country),\n'
#  '\nYes\n,\n168 g CO2/km (comb)\n' '\nYes\n,\n161 g CO2/km (comb)\n'
#  '\nYes\n,\n153 g CO2/km (comb)\n' '\nYes\n,\n191 g CO2/km (comb)\n'
#  '\nYes\n,\n172 g CO2/km (comb)\n']
# ----------------------------------------
# \nYes\n                                                                                 442
# ...
#  '\n04/2016\n,\n99 g CO2/km (comb)\n' '\n05/2018\n,\n99 g CO2/km (comb)\n'
#  '\n12/2018\n,\n102 g CO2/km (comb)\n'
#  '\n01/2019\n,\n99 g CO2/km (comb)\n' '\n03/2018\n,\n4 (Green)\n'
#  '\n01/2018\n,\nEuro 6\n' '\n06/2019\n,\n94 g CO2/km (comb)\n'
#  '\n01/2019\n,\n118 g CO2/km (comb)\n'
#  '\n03/2019\n,\n119 g CO2/km (comb)\n'
#  '\n06/2017\n,\n114 g CO2/km (comb)\n'
#  '\n05/2019\n,\n103 g CO2/km (comb)\n' '\n04/2018\n' '\n07/2018\n'
#  '\n08/2018\n' '\n03/2019\n,\n104 g CO2/km (comb)\n'
#  '\n05/2019\n,\n99 g CO2/km (comb)\n' '\n10/2018\n,\n99 g CO2/km (comb)\n'
#  '\n04/2019\n' '\n07/2018\n,\n114 g CO2/km (comb)\n'
#  '\n12/2018\n,\n128 g CO2/km (comb)\n'
#  '\n01/2019\n,\n115 g CO2/km (comb)\n'
#  '\n06/2019\n,\n119 g CO2/km (comb)\n'
#  '\n02/2019\n,\n103 g CO2/km (comb)\n' '\n06/2018\n'
#  '\n06/2018\n,\n99 g CO2/km (comb)\n'
#  '\n10/2017\n,\n102 g CO2/km (comb)\n'
#  '\n01/2019\n,\n114 g CO2/km (comb)\n'
#  '\n01/2017\n,\n102 g CO2/km (comb)\n'
#  '\n02/2019\n,\n116 g CO2/km (comb)\n'
#  '\n09/2018\n,\n99 g CO2/km (comb)\n'
#  '\n01/2019\n,\n106 g CO2/km (comb)\n'
#  '\n01/2019\n,\n127 g CO2/km (comb)\n'
#  '\n06/2019\n,\n102 g CO2/km (comb)\n'
#  '\n12/2017\n,\n105 g CO2/km (comb)\n'
#  '\n01/2017\n,\n107 g CO2/km (comb)\n' '\n01/2018\n' '\n05/2018\n'
#  '\n02/2018\n,\nEuro 6\n' '\n06/2019\n,\n99 g CO2/km (comb)\n'
#  '\n01/2019\n,\n107 g CO2/km (comb)\n'
#  '\n06/2018\n,\n108 g CO2/km (comb)\n'
#  '\n12/2018\n,\n111 g CO2/km (comb)\n'
#  '\n04/2018\n,\n103 g CO2/km (comb)\n'
#  '\n05/2019\n,\n106 g CO2/km (comb)\n'
#  '\n11/2018\n,\n106 g CO2/km (comb)\n'
#  '\n01/2019\n,\n124 g CO2/km (comb)\n'
#  '\n04/2019\n,\n119 g CO2/km (comb)\n'
#  '\n05/2019\n,\n119 g CO2/km (comb)\n' '\n09/2019\n,\nEuro 6\n'
#  '\n12/2018\n,\n119 g CO2/km (comb)\n'
#  '\n01/2018\n,\n95 g CO2/km (comb)\n' '\n09/2017\n'
#  '\n03/2019\n,\n112 g CO2/km (comb)\n'
#  '\n11/2018\n,\n97 g CO2/km (comb)\n'
#  '\n06/2019\n,\n107 g CO2/km (comb)\n' '\n08/2019\n,\nEuro 6\n'
#  '\n06/2016\n,\n92 g CO2/km (comb)\n'
#  '\n04/2019\n,\n104 g CO2/km (comb)\n'
#  '\n01/2017\n,\n95 g CO2/km (comb)\n' '\n06/2019\n,\n87 g CO2/km (comb)\n'
#  '\n03/2018\n,\nEuro 6\n' '\n10/2018\n,\n100 g CO2/km (comb)\n'
#  '\n02/2018\n,\n97 g CO2/km (comb)\n'
#  '\n06/2018\n,\n104 g CO2/km (comb)\n'
#  '\n07/2018\n,\n107 g CO2/km (comb)\n'
#  '\n01/2019\n,\n104 g CO2/km (comb)\n'
#  '\n04/2019\n,\n130 g CO2/km (comb)\n'
#  '\n10/2018\n,\n124 g CO2/km (comb)\n'
#  '\n06/2017\n,\n92 g CO2/km (comb)\n' '\n01/2019\n'
#  '\n12/2018\n,\n97 g CO2/km (comb)\n' '\n05/2019\n,\n93 g CO2/km (comb)\n'
#  '\n02/2019\n,\n102 g CO2/km (comb)\n' '\n05/2019\n,\n4 (Green)\n'
#  '\n03/2019\n,\n92 g CO2/km (comb)\n'
#  '\n06/2019\n,\n121 g CO2/km (comb)\n'
#  '\n05/2019\n,\n89 g CO2/km (comb)\n'
#  '\n02/2018\n,\n128 g CO2/km (comb)\n'
#  '\n02/2019\n,\n128 g CO2/km (comb)\n'
#  '\n06/2018\n,\n149 g CO2/km (comb)\n'
#  '\n03/2019\n,\n,4.8 l/100 km (comb),\n,5.8 l/100 km (city),\n,4.1 l/100 km (country),\n'
#  '\n10/2018\n,\n149 g CO2/km (comb)\n' '\n08/2018\n,\nEuro 6d-TEMP\n'
#  '\n10/2017\n,\nEuro 6\n' '\n03/2019\n,\n139 g CO2/km (comb)\n'
#  '\n04/2018\n,\n123 g CO2/km (comb)\n'
#  '\n04/2018\n,\n110 g CO2/km (comb)\n'
#  '\n05/2018\n,\n124 g CO2/km (comb)\n'
#  '\n04/2019\n,\n124 g CO2/km (comb)\n'
#  '\n03/2019\n,\n129 g CO2/km (comb)\n' '\n01/2019\n,\nEuro 6d-TEMP\n'
#  '\n07/2018\n,\nEuro 6d-TEMP\n' '\n02/2019\n,\nEuro 6d-TEMP\n'
#  '\n12/2018\n,\n5 (Blue)\n' '\n11/2017\n,\nEuro 6d-TEMP\n'
#  '\n04/2019\n,\n107 g CO2/km (comb)\n' '\n05/2018\n,\nEuro 6d-TEMP\n'
#  '\n06/2019\n,\n120 g CO2/km (comb)\n' '\n06/2019\n,\nEuro 6d-TEMP\n'
#  '\n03/2019\n,\nEuro 6d-TEMP\n' '\n04/2018\n,\n124 g CO2/km (comb)\n'
#  '\n06/2019\n,\n110 g CO2/km (comb)\n'
#  '\n03/2019\n,\n110 g CO2/km (comb)\n'
#  '\n04/2019\n,\n112 g CO2/km (comb)\n'
#  '\n02/2019\n,\n110 g CO2/km (comb)\n' '\n04/2018\n,\n4 (Green)\n'
#  '\n05/2019\n,\n126 g CO2/km (comb)\n' '\n08/2018\n,\n4 (Green)\n'
#  '\n05/2019\n,\n120 g CO2/km (comb)\n'
#  '\n05/2019\n,\n124 g CO2/km (comb)\n'
#  '\n03/2019\n,\n128 g CO2/km (comb)\n'
#  '\n06/2018\n,\n124 g CO2/km (comb)\n'
#  '\n05/2018\n,\n130 g CO2/km (comb)\n'
#  '\n06/2019\n,\n124 g CO2/km (comb)\n'
#  '\n02/2019\n,\n137 g CO2/km (comb)\n'
#  '\n06/2018\n,\n131 g CO2/km (comb)\n'
#  '\n05/2019\n,\n118 g CO2/km (comb)\n'
#  '\n03/2019\n,\n126 g CO2/km (comb)\n' '\n04/2019\n,\nEuro 6d-TEMP\n'
#  '\n05/2019\n,\nEuro 6d-TEMP\n' '\n05/2019\n,\n134 g CO2/km (comb)\n'
#  '\n04/2019\n,\n4 (Green)\n' '\n06/2019\n,\n129 g CO2/km (comb)\n'
#  '\n05/2019\n,\n169 g CO2/km (comb)\n'
#  '\n06/2016\n,\n149 g CO2/km (comb)\n' '\n02/2019\n,\nEuro 4\n'
#  '\n06/2019\n,\n134 g CO2/km (comb)\n'
#  '\n01/2019\n,\n119 g CO2/km (comb)\n'
#  '\n05/2017\n,\n118 g CO2/km (comb)\n'
#  '\n04/2019\n,\n109 g CO2/km (comb)\n'
#  '\n05/2018\n,\n104 g CO2/km (comb)\n'
#  '\n03/2018\n,\n114 g CO2/km (comb)\n'
#  '\n06/2018\n,\n109 g CO2/km (comb)\n'
#  '\n11/2018\n,\n104 g CO2/km (comb)\n'
#  '\n06/2019\n,\n104 g CO2/km (comb)\n' '\n07/2017\n,\nEuro 6\n'
#  '\n02/2019\n,\nEuro 6d\n' '\n01/2018\n,\n118 g CO2/km (comb)\n'
#  '\n07/2018\n,\nEuro 6c\n' '\n08/2018\n,\n138 g CO2/km (comb)\n'
#  '\n03/2019\n,\n145 g CO2/km (comb)\n'
#  '\n05/2019\n,\n133 g CO2/km (comb)\n' '\n09/2018\n,\nEuro 6d-TEMP\n'
#  '\n01/2019\n,\n133 g CO2/km (comb)\n'
#  '\n04/2018\n,\n133 g CO2/km (comb)\n' '\n03/2019\n,\nEuro 6c\n'
#  '\n06/2019\n,\n128 g CO2/km (comb)\n'
#  '\n10/2019\n,\n120 g CO2/km (comb)\n'
#  '\n01/2019\n,\n92 g CO2/km (comb)\n' '\n06/2019\n,\n85 g CO2/km (comb)\n'
#  '\n04/2019\n,\n,5.6 l/100 km (comb),\n,7.2 l/100 km (city),\n,4.7 l/100 km (country),\n'
#  '\n05/2019\n,\n85 g CO2/km (comb)\n'
#  '\n05/2019\n,\n127 g CO2/km (comb)\n'
#  '\n02/2019\n,\n127 g CO2/km (comb)\n'
#  '\n02/2019\n,\n92 g CO2/km (comb)\n'
#  '\n08/2018\n,\n127 g CO2/km (comb)\n'
#  '\n10/2018\n,\n127 g CO2/km (comb)\n'
#  '\n04/2019\n,\n135 g CO2/km (comb)\n'
#  '\n03/2019\n,\n135 g CO2/km (comb)\n'
#  '\n05/2019\n,\n135 g CO2/km (comb)\n'
#  '\n07/2018\n,\n92 g CO2/km (comb)\n' '\n04/2019\n,\n85 g CO2/km (comb)\n'
#  '\n09/2018\n,\n92 g CO2/km (comb)\n' '\n11/2019\n,\nEuro 6\n'
#  '\n06/2019\n,\n127 g CO2/km (comb)\n'
#  '\n07/2018\n,\n127 g CO2/km (comb)\n'
#  '\n01/2019\n,\n120 g CO2/km (comb)\n'
#  '\n04/2019\n,\n127 g CO2/km (comb)\n'
#  '\n12/2018\n,\n104 g CO2/km (comb)\n'
#  '\n04/2019\n,\n92 g CO2/km (comb)\n' '\n01/2019\n,\n85 g CO2/km (comb)\n'
#  '\n06/2018\n,\n135 g CO2/km (comb)\n'
#  '\n03/2019\n,\n85 g CO2/km (comb)\n'
#  '\n10/2018\n,\n135 g CO2/km (comb)\n'
#  '\n02/2019\n,\n135 g CO2/km (comb)\n'
#  '\n02/2019\n,\n114 g CO2/km (comb)\n'
#  '\n03/2019\n,\n127 g CO2/km (comb)\n'
#  '\n03/2018\n,\n104 g CO2/km (comb)\n'
#  '\n04/2019\n,\n120 g CO2/km (comb)\n'
#  '\n03/2019\n,\n140 g CO2/km (comb)\n'
#  '\n06/2018\n,\n120 g CO2/km (comb)\n'
#  '\n02/2019\n,\n120 g CO2/km (comb)\n'
#  '\n03/2018\n,\n140 g CO2/km (comb)\n'
#  '\n12/2017\n,\n120 g CO2/km (comb)\n' '\n03/2019\n,\nEuro 5\n'
#  '\n07/2017\n' '\n07/2019\n' '\n11/2017\n,\nEuro 6\n'
#  '\n04/2017\n,\n120 g CO2/km (comb)\n' '\n07/2018\n,\nEuro 6d\n'
#  '\n05/2018\n,\n116 g CO2/km (comb)\n' '\n04/2016\n,\nEuro 6\n'
#  '\n03/2019\n,\n120 g CO2/km (comb)\n']
# ----------------------------------------
# \n01/2017\n,\n102 g CO2/km (comb)\n        1
# \n01/2017\n,\n107 g CO2/km (comb)\n        1
# \n01/2017\n,\n95 g CO2/km (comb)\n         1
# \n01/2018\n                                1
# \n01/2018\n,\n114 g CO2/km (comb)\n        1
#                                        ...
# \n12/2018\n,\n5 (Blue)\n                   1
# \n12/2018\n,\n97 g CO2/km (comb)\n         1
# \n12/2018\n,\n99 g CO2/km (comb)\n         2
# \n12/2018\n,\nEuro 6\n                    11
# NaN                                    15353
# Name: last_service_date, Length: 256, dtype: int64
# ----------------------------------------
# NaN                                    15353
# \n02/2019\n,\nEuro 6\n                    23
# \n05/2019\n,\nEuro 6\n                    16
# \n01/2018\n,\n118 g CO2/km (comb)\n       15
# \n03/2019\n,\nEuro 6\n                    15
#                                        ...
# \n01/2017\n,\n95 g CO2/km (comb)\n         1
# \n06/2019\n,\n87 g CO2/km (comb)\n         1
# \n10/2018\n,\n100 g CO2/km (comb)\n        1
# \n02/2018\n,\n97 g CO2/km (comb)\n         1
# \n03/2019\n,\n120 g CO2/km (comb)\n        1
# Name: last_service_date, Length: 256, dtype: int64
# ################################################################################
#
# column name :  other_fuel_types
# ----------------------------------------
# Per_of_Nulls   :  % 94.47
# Number of Nulls  :  15039
# Number of Uniques:  1
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '[],[],[]']
# ----------------------------------------
# [],[],[]      880
# NaN         15039
# Name: other_fuel_types, dtype: int64
# ----------------------------------------
# NaN         15039
# [],[],[]      880
# Name: other_fuel_types, dtype: int64
# ################################################################################
#
# column name :  availability
# ----------------------------------------
# Per_of_Nulls   :  % 96.01
# Number of Nulls  :  15284
# Number of Uniques:  15
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '\nin 90 days from ordering\n' '\nin 180 days from ordering\n'
#  '\nin 150 days from ordering\n' '\nin 14 days from ordering\n'
#  '\nin 7 days from ordering\n' '\nin 1 day from ordering\n'
#  '\nin 21 days from ordering\n' '\nin 5 days from ordering\n'
#  '\nin 60 days from ordering\n' '\nin 120 days from ordering\n'
#  '\nin 3 days from ordering\n' '\nin 4 days from ordering\n'
#  '\nin 42 days from ordering\n' '\nin 2 days from ordering\n'
#  '\nin 6 days from ordering\n']
# ----------------------------------------
# \nin 1 day from ordering\n          51
# \nin 120 days from ordering\n      182
# \nin 14 days from ordering\n        24
# \nin 150 days from ordering\n       18
# \nin 180 days from ordering\n       24
# \nin 2 days from ordering\n         16
# \nin 21 days from ordering\n         8
# \nin 3 days from ordering\n         35
# \nin 4 days from ordering\n          2
# \nin 42 days from ordering\n        10
# \nin 5 days from ordering\n         35
# \nin 6 days from ordering\n          1
# \nin 60 days from ordering\n        13
# \nin 7 days from ordering\n         20
# \nin 90 days from ordering\n       196
# NaN                              15284
# Name: availability, dtype: int64
# ----------------------------------------
# NaN                              15284
# \nin 90 days from ordering\n       196
# \nin 120 days from ordering\n      182
# \nin 1 day from ordering\n          51
# \nin 5 days from ordering\n         35
# \nin 3 days from ordering\n         35
# \nin 180 days from ordering\n       24
# \nin 14 days from ordering\n        24
# \nin 7 days from ordering\n         20
# \nin 150 days from ordering\n       18
# \nin 2 days from ordering\n         16
# \nin 60 days from ordering\n        13
# \nin 42 days from ordering\n        10
# \nin 21 days from ordering\n         8
# \nin 4 days from ordering\n          2
# \nin 6 days from ordering\n          1
# Name: availability, dtype: int64
# ################################################################################
#
# column name :  last_timing_belt_service_date
# ----------------------------------------
# Per_of_Nulls   :  % 99.9
# Number of Nulls  :  15903
# Number of Uniques:  15
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '\n12/1900\n' '\n07/2018\n' '\n01/1900\n' '\n05/2019\n' '\n09/2018\n'
#  '\n05/2018\n,\nEuro 6\n' '\n06/2017\n' '\n01/2019\n' '\n02/2019\n'
#  '\n02/2018\n' '\n04/2016\n' '\n06/2019\n' '\n01/2018\n' '\n04/2019\n'
#  '\n01/1970\n']
# ----------------------------------------
# \n01/1900\n                   1
# \n01/1970\n                   1
# \n01/2018\n                   1
# \n01/2019\n                   1
# \n02/2018\n                   1
# \n02/2019\n                   1
# \n04/2016\n                   2
# \n04/2019\n                   1
# \n05/2018\n,\nEuro 6\n        1
# \n05/2019\n                   1
# \n06/2017\n                   1
# \n06/2019\n                   1
# \n07/2018\n                   1
# \n09/2018\n                   1
# \n12/1900\n                   1
# NaN                       15903
# Name: last_timing_belt_service_date, dtype: int64
# ----------------------------------------
# NaN                       15903
# \n04/2016\n                   2
# \n12/1900\n                   1
# \n07/2018\n                   1
# \n01/1900\n                   1
# \n05/2019\n                   1
# \n09/2018\n                   1
# \n05/2018\n,\nEuro 6\n        1
# \n06/2017\n                   1
# \n01/2019\n                   1
# \n02/2019\n                   1
# \n02/2018\n                   1
# \n06/2019\n                   1
# \n01/2018\n                   1
# \n04/2019\n                   1
# \n01/1970\n                   1
# Name: last_timing_belt_service_date, dtype: int64
# ################################################################################
#
# column name :  available_from
# ----------------------------------------
# Per_of_Nulls   :  % 98.29
# Number of Nulls  :  15647
# Number of Uniques:  46
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [n
# \n16/07/19\n        2
# \n20/07/19\n        2
# \n05/07/19\n        2
# \n30/06/19\n        2
# \n30/09/19\n        1
# \n31/10/19\n        1
# \n27/07/19\n        1
# \n02/07/19\n        1
# \n10/07/19\n        1
# \n19/07/19\n        1
# \n24/07/19\n        1
# \n29/07/19\n        1
# \n29/09/19\n        1
# \n18/08/19\n        1
# \n14/09/19\n        1
# \n18/07/19\n        1
# \n16/08/19\n        1
# \n24/09/19\n        1
# \n17/08/19\n        1
# \n10/10/19\n        1
# \n06/12/19\n        1
# \n03/12/19\n        1
# \n05/12/19\n        1
# \n11/08/19\n        1
# \n10/12/19\n        1
# \n01/09/19\n        1
# \n03/08/19\n        1
# Name: available_from, dtype: int64
# ################################################################################

# %%
#Dropping null and k_W columns. There is no data in that columns. And also description because of Deutch
df.drop(columns=["null","k_w","description"], inplace=True)

# %%
#Changing consumption column
df["consumption"] = df["consumption"].str.replace("\n,?","")

# %%
# Controlling consumption columns
print("Total value of comb in consumption column = ", df["consumption"].str.contains("comb").value_counts().head(1).values)
print("Total value of city in consumption column = ", df["consumption"].str.contains("city").value_counts().head(1).values)
print("Total value of country in consumption column = ", df["consumption"].str.contains("country").value_counts().head(1).values)
# Out:
# Total value of comb in consumption column =  [13886]
# Total value of city in consumption column =  [13483]
# Total value of country in consumption column =  [13543]

# %%
#Split consumption column into 3 parts (Comb, City, Country)
df["consumption_comb"] = df["consumption"].str.split(",",expand=True)[0].str.extract("(\d.*)\s\w+.*/100 km\s\(comb")
df["consumption_city"] = df["consumption"].str.split(",",expand=True)[1].str.extract("(\d.*)\s\w+.*/100 km\s\(city")
df["consumption_country"] = df["consumption"].str.split(",",expand=True)[2].str.extract("(\d.*)\s\w+.*/100 km\s\(country")
print("Total of non-null value in consumption_comb column = ", len(df["consumption_comb"]) - df["consumption_comb"].isnull().sum())
print("Total of non-null value in consumption_city column = ", len(df["consumption_city"]) - df["consumption_city"].isnull().sum())
print("Total of non-null value in consumption_country column = ", len(df["consumption_country"]) - df["consumption_country"].isnull().sum())
# Out:
# Total of non-null value in consumption_comb column =  13886
# Total of non-null value in consumption_city column =  13483
# Total of non-null value in consumption_country column =  13543

# %%
#Changing column, replace unappropriate values
for i in df.select_dtypes(include="O"):
    df[i] = df[i].str.replace(",?\n,?","")

# %%
df.head().T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# hp                                                                         66 kW
# type                                          ,Used,,Diesel (Particulate Filter)
# previous_owners                                                                2
# next_inspection                                        06/202199 g CO2/km (comb)
# inspection_new                                                         YesEuro 6
# warranty                                                               4 (Green)
# full_service
# non_smoking_vehicle
# make                                                                        Audi
# model                                                                         A1
# offer_number                                                           LR-062483
# first_registration                                                          2016
# body_color                                                                 Black
# paint_type                                                              Metallic
# body_color_original                                                Mythosschwarz
# upholstery                                                          Cloth, Black
# body                                                                      Sedans
# nr_of_doors                                                                    5
# nr_of_seats                                                                    5
# model_code                                                              0588/BDF
# gearing_type                                                           Automatic
# displacement                                                            1,422 cc
# cylinders                                                                      3
# weight                                                                  1,220 kg
# drive_chain                                                                front
# fuel                                                 Diesel (Particulate Filter)
# consumption                    ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# co_2_emission                                                 99 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media          Bluetooth,Hands-free equipment,On-board comput...
# extras                            Alloy wheels,Catalytic Converter,Voice Control
# safety_&_security              ABS,Central door lock,Daytime running lights,D...
# emission_label                                                               NaN
# gears                                                                        NaN
# country_version                                                              NaN
# electricity_consumption                                                      NaN
# last_service_date                                                            NaN
# other_fuel_types                                                             NaN
# availability                                                                 NaN
# last_timing_belt_service_date                                                NaN
# available_from                                                               NaN
# consumption_comb                                                             3.8
# consumption_city                                                             4.3
# consumption_country                                                          3.5
#
#                                                                                1  \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                                 1.8 TFSI sport
# body_type                                                                 Sedans
# price                                                                      14500
# vat                                                             Price negotiable
# km                                                                     80,000 km
# registration                                                             03/2017
# prev_owner                                                                  None
# hp                                                                        141 kW
# type                                                             ,Used,,Gasoline
# previous_owners                                                              NaN
# next_inspection                                                              NaN
# inspection_new                                                               NaN
# warranty                                                                     NaN
# full_service                                                                 NaN
# non_smoking_vehicle                                                          NaN
# make                                                                        Audi
# model                                                                         A1
# offer_number                                                                 NaN
# first_registration                                                          2017
# body_color                                                                   Red
# paint_type                                                                   NaN
# body_color_original                                                          NaN
# upholstery                                                           Cloth, Grey
# body                                                                      Sedans
# nr_of_doors                                                                    3
# nr_of_seats                                                                    4
# model_code                                                              0588/BCY
# gearing_type                                                           Automatic
# displacement                                                            1,798 cc
# cylinders                                                                      4
# weight                                                                  1,255 kg
# drive_chain                                                                front
# fuel                                                                    Gasoline
# consumption                    ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'...
# co_2_emission                                                129 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air conditioning,Automatic climate control,Hil...
# entertainment_&_media          Bluetooth,Hands-free equipment,On-board comput...
# extras                         Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_&_security              ABS,Central door lock,Central door lock with r...
# emission_label                                                         4 (Green)
# gears                                                                          7
# country_version                                                              NaN
# electricity_consumption                                                      NaN
# last_service_date                                                            NaN
# other_fuel_types                                                             NaN
# availability                                                                 NaN
# last_timing_belt_service_date                                                NaN
# available_from                                                               NaN
# consumption_comb                                                             5.6
# consumption_city                                                             7.1
# consumption_country                                                          4.7
#
#                                                                                2  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# body_type                                                                 Sedans
# price                                                                      14640
# vat                                                               VAT deductible
# km                                                                     83,450 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# hp                                                                         85 kW
# type                                          ,Used,,Diesel (Particulate Filter)
# previous_owners                                                                1
# next_inspection                                                              NaN
# inspection_new                                                               NaN
# warranty                                                      99 g CO2/km (comb)
# full_service                                                                 NaN
# non_smoking_vehicle                                                          NaN
# make                                                                        Audi
# model                                                                         A1
# offer_number                                                            AM-95365
# first_registration                                                          2016
# body_color                                                                 Black
# paint_type                                                              Metallic
# body_color_original                                       mythosschwarz metallic
# upholstery                                                          Cloth, Black
# body                                                                      Sedans
# nr_of_doors                                                                    4
# nr_of_seats                                                                    4
# model_code                                                                   NaN
# gearing_type                                                           Automatic
# displacement                                                            1,598 cc
# cylinders                                                                    NaN
# weight                                                                       NaN
# drive_chain                                                                front
# fuel                                                 Diesel (Particulate Filter)
# consumption                    ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'...
# co_2_emission                                                 99 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air conditioning,Cruise control,Electrical sid...
# entertainment_&_media                                      MP3,On-board computer
# extras                                                Alloy wheels,Voice Control
# safety_&_security              ABS,Central door lock,Daytime running lights,D...
# emission_label                                                         4 (Green)
# gears                                                                        NaN
# country_version                                                              NaN
# electricity_consumption                                                      NaN
# last_service_date                                                            NaN
# other_fuel_types                                                             NaN
# availability                                                                 NaN
# last_timing_belt_service_date                                                NaN
# available_from                                                               NaN
# consumption_comb                                                             3.8
# consumption_city                                                             4.4
# consumption_country                                                          3.4
#
#                                                                                3  \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                        1.4 TDi Design S tronic
# body_type                                                                 Sedans
# price                                                                      14500
# vat                                                                         None
# km                                                                     73,000 km
# registration                                                             08/2016
# prev_owner                                                      1 previous owner
# hp                                                                         66 kW
# type                                          ,Used,,Diesel (Particulate Filter)
# previous_owners                                                                1
# next_inspection                                                              NaN
# inspection_new                                                               NaN
# warranty                                                                     NaN
# full_service                                                  99 g CO2/km (comb)
# non_smoking_vehicle                                                       Euro 6
# make                                                                        Audi
# model                                                                         A1
# offer_number                                                                 NaN
# first_registration                                                          2016
# body_color                                                                 Brown
# paint_type                                                              Metallic
# body_color_original                                                          NaN
# upholstery                                                                   NaN
# body                                                                      Sedans
# nr_of_doors                                                                    3
# nr_of_seats                                                                    4
# model_code                                                                   NaN
# gearing_type                                                           Automatic
# displacement                                                            1,422 cc
# cylinders                                                                      3
# weight                                                                  1,195 kg
# drive_chain                                                                  NaN
# fuel                                                 Diesel (Particulate Filter)
# consumption                    ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# co_2_emission                                                 99 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air suspension,Armrest,Auxiliary heating,Elect...
# entertainment_&_media          Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                                    Alloy wheels,Sport seats,Voice Control
# safety_&_security              ABS,Alarm system,Central door lock with remote...
# emission_label                                                               NaN
# gears                                                                          6
# country_version                                                              NaN
# electricity_consumption                                                      NaN
# last_service_date                                                            NaN
# other_fuel_types                                                             NaN
# availability                                                                 NaN
# last_timing_belt_service_date                                                NaN
# available_from                                                               NaN
# consumption_comb                                                             3.8
# consumption_city                                                             4.3
# consumption_country                                                          3.5
#
#                                                                                4
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# body_type                                                                 Sedans
# price                                                                      16790
# vat                                                                         None
# km                                                                     16,200 km
# registration                                                             05/2016
# prev_owner                                                      1 previous owner
# hp                                                                         66 kW
# type                                          ,Used,,Diesel (Particulate Filter)
# previous_owners                                                                1
# next_inspection                                                              NaN
# inspection_new                                            Yes109 g CO2/km (comb)
# warranty                                                                  Euro 6
# full_service                                                           4 (Green)
# non_smoking_vehicle
# make                                                                        Audi
# model                                                                         A1
# offer_number                                                               C1626
# first_registration                                                          2016
# body_color                                                                 Black
# paint_type                                                              Metallic
# body_color_original                                       Mythosschwarz Metallic
# upholstery                                                          Cloth, Black
# body                                                                      Sedans
# nr_of_doors                                                                    5
# nr_of_seats                                                                    5
# model_code                                                              0588/BDF
# gearing_type                                                           Automatic
# displacement                                                            1,422 cc
# cylinders                                                                      3
# weight                                                                       NaN
# drive_chain                                                                front
# fuel                                                 Diesel (Particulate Filter)
# consumption                    ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'...
# co_2_emission                                                109 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media          Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                         Alloy wheels,Sport package,Sport suspension,Vo...
# safety_&_security              ABS,Central door lock,Driver-side airbag,Elect...
# emission_label                                                               NaN
# gears                                                                        NaN
# country_version                                                          Germany
# electricity_consumption                                                      NaN
# last_service_date                                                            NaN
# other_fuel_types                                                             NaN
# availability                                                                 NaN
# last_timing_belt_service_date                                                NaN
# available_from                                                               NaN
# consumption_comb                                                             4.1
# consumption_city                                                             4.6
# consumption_country                                                          3.8

# %%
# def check_other_column_values(row) :
#     if any(i in str(row) for i in col_list) :
#         return True
#     else :
#         False

# def find_easy(col_main, col_other, pattern) :
#     global col_list
#     col_list = list(df[col_main].dropna().unique())
#     if df[col_other].apply(check_other_column_values).isnull().sum() > 0 :
#         df["find"] = df[col_other].str.extract(pattern)
#         x_sum = df[df[col_main].isnull()]["find"].notna().sum()
#         if x_sum > 0 :
#             return f"{col_other} has {x_sum} values. You can fill {col_main} with them."
#         else :
#             return f"There ins't any useful information in {col_other} to fill {col_main}."

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##  Understanding Variables

# %% [markdown]
# ### url

# %%
first_look("url")
# Out:
# column name :  url
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  15919
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e'
#  'https://www.autoscout24.com//offers/audi-a1-1-8-tfsi-sport-gasoline-red-b2547f8a-e83f-6237-e053-e250040a56df'
#  'https://www.autoscout24.com//offers/audi-a1-sportback-1-6-tdi-s-tronic-einparkhilfe-plus-music-diesel-black-6183cb6a-8570-4b86-a132-9b54214bca88'
#  ...
#  'https://www.autoscout24.com//offers/renault-espace-blue-dci-200-edc-initiale-paris-leder-led-navi-key-diesel-white-6256d1a3-ea68-4193-91de-b5b5ffa4631c'
#  'https://www.autoscout24.com//offers/renault-espace-blue-dci-200cv-edc-business-nuova-da-immatricola-diesel-grey-5b0251a1-bd88-475c-a039-7e499da85d9d'
#  'https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481']
# ----------------------------------------
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-2019-sh-pdc-gasoline-white-1037d13f-0851-44dd-b559-c6f6def8e6d2                     1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-16e81c6c-58ce-4b86-9926-9f09302d0ef4                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-a48492d9-f2e5-436d-9ad4-dfb31ff19aed                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-navi-virtual-gasoline-white-6d94186e-c19d-4aa1-a223-bc0256d51845                  1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-pdc-sh-gasoline-white-047a0fe6-743e-4ae6-892e-e97bc13b1468                        1
#                                                                                                                                                               ..
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-5eb03fe7-5c36-40b6-a596-ee0de57372e1                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-996ac32a-6070-40af-b6ab-74f57232e256                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-a6700fd3-efb5-44a8-a85b-90c491c9d378                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-b9b30dfb-beb9-4157-b8b4-dbe86ba6573d                         1
# https://www.autoscout24.com//offers/renault-espace-zu-spaet-geht-an-haendler-da-wird-er-dann-23-000-ko-gasoline-silver-93caa088-19e3-905e-e053-e250040a8d8d    1
# Name: url, Length: 15919, dtype: int64
# ----------------------------------------
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
#                                                                                                                                                           ..
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-black-cf50f7b1-4d7b-466f-93a2-4e11ec0b4107                        1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-grey-3f47eb34-15c4-4763-860d-78fcbbd2c9ff                         1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-f7a4bc95-b2ef-4bac-9497-6bcbcd05db0b                       1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-1c94c7a2-67b5-49ca-ae42-42a6800fb3f5                       1
# https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481          1
# Name: url, Length: 15919, dtype: int64
# ################################################################################

# %% [markdown]
# ### short_description

# %%
first_look("short_description")
# Out:
# column name :  short_description
# ----------------------------------------
# Per_of_Nulls   :  % 0.29
# Number of Nulls  :  46
# Number of Uniques:  10001
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Sportback 1.4 TDI S-tronic Xenon Navi Klima' '1.8 TFSI sport'
#  'Sportback 1.6 TDI S tronic Einparkhilfe plus+music' ...
#  'ELYSEE ENERGY dCi 160 EDC' 'INITIALE Paris TCe 225 EDC GPF ACC EU6'
#  'TCe 225 EDC GPF LIM Deluxe Pano,RFK']
# ----------------------------------------
#  1,6 CDTI**NAVI*Klimaaut*Tempomat*EURO6*TÜV NEU     1
#  1.4 75 cv5 porte b-color                           1
#  1.4 TFSI Attraction (125 CV)                       6
#  1.4 Turbo S&S Excellence (125 CV)                  2
#  1.6 CDTi Dynamic (110 CV)                          4
#                                                    ..
# van 1.5 dci 75cv S S E6                             1
# van 1.5 dci 75cv S&S E6                            24
# zoé life                                            1
# Österr. Edition 16.CDTI                             1
# NaN                                                46
# Name: short_description, Length: 10002, dtype: int64
# ----------------------------------------
# SPB 1.6 TDI 116 CV S tronic Sport                 64
# NaN                                               46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10002, dtype: int64
# ################################################################################

# %% [markdown]
# ###  make_model & make & model

# %%
first_look("make_model")
# Out:
# column name :  make_model
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Audi A1' 'Audi A2' 'Audi A3' 'Opel Astra' 'Opel Corsa' 'Opel Insignia'
#  'Renault Clio' 'Renault Duster' 'Renault Espace']
# ----------------------------------------
# Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ----------------------------------------
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
# ################################################################################

# %%
first_look("make")
# Out:
# column name :  make
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  3
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Audi' 'Opel' 'Renault']
# ----------------------------------------
# Audi       5712
# Opel       7343
# Renault    2864
# Name: make, dtype: int64
# ----------------------------------------
# Opel       7343
# Audi       5712
# Renault    2864
# Name: make, dtype: int64
# ################################################################################

# %%
first_look("model")
# Out:
# column name :  model
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['A1' 'A2' 'A3' 'Astra' 'Corsa' 'Insignia' 'Clio' 'Duster' 'Espace']
# ----------------------------------------
# A1          2614
# A2             1
# A3          3097
# Astra       2526
# Clio        1839
# Corsa       2219
# Duster        34
# Espace       991
# Insignia    2598
# Name: model, dtype: int64
# ----------------------------------------
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64
# ################################################################################

# %%
df[["make_model","make","model"]].value_counts(dropna=False)
# Out:
# make_model      make     model
# Audi A3         Audi     A3          3097
# Audi A1         Audi     A1          2614
# Opel Insignia   Opel     Insignia    2598
# Opel Astra      Opel     Astra       2526
# Opel Corsa      Opel     Corsa       2219
# Renault Clio    Renault  Clio        1839
# Renault Espace  Renault  Espace       991
# Renault Duster  Renault  Duster        34
# Audi A2         Audi     A2             1
# dtype: int64

# %%
df.drop(columns=["make","model"], inplace=True)

# %% [markdown]
# ### body_type & body

# %%
first_look("body_type")
# Out:
# column name :  body_type
# ----------------------------------------
# Per_of_Nulls   :  % 0.38
# Number of Nulls  :  60
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Sedans' 'Station wagon' 'Compact' 'Other' 'Coupe' 'Van' 'Off-Road'
#  'Convertible' None 'Transporter']
# ----------------------------------------
# Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ----------------------------------------
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# ################################################################################

# %%
first_look("body")
# Out:
# column name :  body
# ----------------------------------------
# Per_of_Nulls   :  % 0.38
# Number of Nulls  :  60
# Number of Uniques:  9
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Sedans' 'Station wagon' 'Compact' 'Other' 'Coupe' 'Van' 'Off-Road'
#  'Convertible' nan 'Transporter']
# ----------------------------------------
# Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body, dtype: int64
# ----------------------------------------
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body, dtype: int64
# ################################################################################

# %%
df[["body_type","body"]].value_counts(dropna=False)
# Out:
# body_type      body
# Sedans         Sedans           7903
# Station wagon  Station wagon    3553
# Compact        Compact          3153
# Van            Van               783
# Other          Other             290
# Transporter    Transporter        88
# NaN            NaN                60
# Off-Road       Off-Road           56
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %%
#looking for the null values of body_type in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["body_type"].isnull()][i].str.contains("sedans|station wagon|compact|coupe|van|off-road|transporter", regex=True).any():
        print(i)
# Out:
# url
# short_description

# %%
df[df["body_type"].isnull()][df[df["body_type"].isnull()]["short_description"].str.contains("sedans|station wagon|compact|coupe|van|off-road|transporter", regex=True) == True]
# Out:
#                                                      url    make_model  \
# 13852  https://www.autoscout24.com//offers/renault-cl...  Renault Clio
#
#              short_description body_type  price   vat         km registration  \
# 13852  van 1.5 dci 75cv S S E6      None   8500  None  34,564 km      06/2017
#
#       prev_owner     hp           type previous_owners next_inspection  \
# 13852       None  55 kW  ,Used,,Diesel             NaN             NaN
#
#       inspection_new warranty full_service non_smoking_vehicle offer_number  \
# 13852            NaN                   NaN                 NaN       902099
#
#       first_registration body_color paint_type body_color_original upholstery  \
# 13852               2017      White        NaN              Bianco        NaN
#
#       body nr_of_doors nr_of_seats model_code gearing_type displacement  \
# 13852  NaN           5         NaN        NaN       Manual     1,461 cc
#
#       cylinders weight drive_chain    fuel consumption co_2_emission  \
# 13852         4    NaN         NaN  Diesel         NaN           NaN
#
#       emission_class comfort_&_convenience entertainment_&_media extras  \
# 13852            NaN                   NaN                   NaN    NaN
#
#         safety_&_security emission_label gears country_version  \
# 13852  ABS,Power steering            NaN   NaN             NaN
#
#       electricity_consumption last_service_date other_fuel_types availability  \
# 13852                     NaN               NaN              NaN          NaN
#
#       last_timing_belt_service_date available_from consumption_comb  \
# 13852                           NaN            NaN              NaN
#
#       consumption_city consumption_country
# 13852              NaN                 NaN

# %%
#In url column there is a van value, so body type gets van.
df.loc[df[df["body_type"].isnull()][df[df["body_type"].isnull()]["short_description"].str.contains("sedans|station wagon|compact|coupe|van|off-road|transporter", regex=True) == True].index,"body_type"] = "Van"

# %%
df.drop(columns="body", inplace=True)

# %% [markdown]
# ### vat

# %%
first_look("vat")
# Out:
# column name :  vat
# ----------------------------------------
# Per_of_Nulls   :  % 28.35
# Number of Nulls  :  4513
# Number of Uniques:  2
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['VAT deductible' 'Price negotiable' None]
# ----------------------------------------
# Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ----------------------------------------
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
# ################################################################################

# %% [markdown]
# ### km

# %%
first_look("km")
# Out:
# column name :  km
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  6690
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['56,013 km' '80,000 km' '83,450 km' ... '2,864 km' '1,506 km' '57 km']
# ----------------------------------------
# - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ----------------------------------------
# 10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
# ################################################################################

# %%
df["km"] = df["km"].str.strip(" km").str.replace(",","").replace("-",np.nan).astype(float)

# %%
first_look("km")
# Out:
# column name :  km
# ----------------------------------------
# Per_of_Nulls   :  % 6.43
# Number of Nulls  :  1024
# Number of Uniques:  6689
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [5.6013e+04 8.0000e+04 8.3450e+04 ... 2.8640e+03 1.5060e+03 5.7000e+01]
# ----------------------------------------
# 0.0           19
# 1.0          367
# 2.0            6
# 3.0           33
# 4.0           15
#             ...
# 248000.0       1
# 260000.0       1
# 291800.0       1
# 317000.0       1
# NaN         1024
# Name: km, Length: 6690, dtype: int64
# ----------------------------------------
# 10.0       1045
# NaN        1024
# 1.0         367
# 5.0         170
# 50.0        148
#            ...
# 67469.0       1
# 43197.0       1
# 10027.0       1
# 35882.0       1
# 57.0          1
# Name: km, Length: 6690, dtype: int64
# ################################################################################

# %% [markdown]
# ### registration & first_registration

# %%
first_look("registration")
# Out:
# column name :  registration
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  48
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['01/2016' '03/2017' '02/2016' '08/2016' '05/2016' '03/2016' '06/2017'
#  '05/2018' '09/2016' '06/2016' '10/2016' '04/2016' '06/2018' '11/2017'
#  '07/2016' '12/2016' '09/2018' '04/2018' '07/2017' '02/2017' '11/2016'
#  '01/2018' '05/2017' '04/2017' '07/2018' '01/2017' '02/2018' '03/2018'
#  '-/-' '08/2017' '10/2017' '08/2018' '09/2017' '12/2017' '04/2019'
#  '12/2018' '03/2019' '06/2019' '05/2019' '02/2019' '01/2019' '10/2018'
#  '11/2018' '09/2019' '07/2019' '08/2019' '11/2019' '12/2019']
# ----------------------------------------
# -/-        1597
# 01/2016     376
# 01/2017     306
# 01/2018     511
# 01/2019     541
# 02/2016     472
# 02/2017     368
# 02/2018     539
# 02/2019     585
# 03/2016     536
# 03/2017     471
# 03/2018     695
# 03/2019     543
# 04/2016     532
# 04/2017     380
# 04/2018     541
# 04/2019     506
# 05/2016     459
# 05/2017     404
# 05/2018     572
# 05/2019     440
# 06/2016     452
# 06/2017     409
# 06/2018     532
# 06/2019     224
# 07/2016     176
# 07/2017     215
# 07/2018     396
# 07/2019       6
# 08/2016      94
# 08/2017     114
# 08/2018     285
# 08/2019       1
# 09/2016     141
# 09/2017     149
# 09/2018     141
# 09/2019       5
# 10/2016     160
# 10/2017     154
# 10/2018      97
# 11/2016     142
# 11/2017     180
# 11/2018     110
# 11/2019       1
# 12/2016     134
# 12/2017     123
# 12/2018     103
# 12/2019       1
# Name: registration, dtype: int64
# ----------------------------------------
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64
# ################################################################################

# %%
first_look("first_registration")
# Out:
# column name :  first_registration
# ----------------------------------------
# Per_of_Nulls   :  % 10.03
# Number of Nulls  :  1597
# Number of Uniques:  4
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['2016' '2017' '2018' nan '2019']
# ----------------------------------------
# 2016    3674
# 2017    3273
# 2018    4522
# 2019    2853
# NaN     1597
# Name: first_registration, dtype: int64
# ----------------------------------------
# 2018    4522
# 2016    3674
# 2017    3273
# 2019    2853
# NaN     1597
# Name: first_registration, dtype: int64
# ################################################################################

# %%
df["registration"] = pd.to_datetime(df["registration"].replace("-/-", np.nan))
df["first_registration"] = pd.to_datetime(df["first_registration"].replace("-/-", np.nan))

# %%
df[~(df["registration"].dt.year == df["first_registration"].dt.year)][["registration","first_registration"]]
# Out:
#       registration first_registration
# 122            NaT                NaT
# 710            NaT                NaT
# 734            NaT                NaT
# 741            NaT                NaT
# 743            NaT                NaT
# ...            ...                ...
# 15896          NaT                NaT
# 15902          NaT                NaT
# 15907          NaT                NaT
# 15912          NaT                NaT
# 15914          NaT                NaT
#
# [1597 rows x 2 columns]

# %%
df[(df["registration"].isnull())&(df["first_registration"].isnull())].shape
# Out:
# (1597, 51)

# %%
first_look("registration")
# Out:
# column name :  registration
# ----------------------------------------
# Per_of_Nulls   :  % 10.03
# Number of Nulls  :  1597
# Number of Uniques:  47
# Type of columns:  datetime64[ns]
# ----------------------------------------
# Unique values of columns:  ['2016-01-01T00:00:00.000000000' '2017-03-01T00:00:00.000000000'
#  '2016-02-01T00:00:00.000000000' '2016-08-01T00:00:00.000000000'
#  '2016-05-01T00:00:00.000000000' '2016-03-01T00:00:00.000000000'
#  '2017-06-01T00:00:00.000000000' '2018-05-01T00:00:00.000000000'
#  '2016-09-01T00:00:00.000000000' '2016-06-01T00:00:00.000000000'
#  '2016-10-01T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
#  '2018-06-01T00:00:00.000000000' '2017-11-01T00:00:00.000000000'
#  '2016-07-01T00:00:00.000000000' '2016-12-01T00:00:00.000000000'
#  '2018-09-01T00:00:00.000000000' '2018-04-01T00:00:00.000000000'
#  '2017-07-01T00:00:00.000000000' '2017-02-01T00:00:00.000000000'
#  '2016-11-01T00:00:00.000000000' '2018-01-01T00:00:00.000000000'
#  '2017-05-01T00:00:00.000000000' '2017-04-01T00:00:00.000000000'
#  '2018-07-01T00:00:00.000000000' '2017-01-01T00:00:00.000000000'
#  '2018-02-01T00:00:00.000000000' '2018-03-01T00:00:00.000000000'
#                            'NaT' '2017-08-01T00:00:00.000000000'
#  '2017-10-01T00:00:00.000000000' '2018-08-01T00:00:00.000000000'
#  '2017-09-01T00:00:00.000000000' '2017-12-01T00:00:00.000000000'
#  '2019-04-01T00:00:00.000000000' '2018-12-01T00:00:00.000000000'
#  '2019-03-01T00:00:00.000000000' '2019-06-01T00:00:00.000000000'
#  '2019-05-01T00:00:00.000000000' '2019-02-01T00:00:00.000000000'
#  '2019-01-01T00:00:00.000000000' '2018-10-01T00:00:00.000000000'
#  '2018-11-01T00:00:00.000000000' '2019-09-01T00:00:00.000000000'
#  '2019-07-01T00:00:00.000000000' '2019-08-01T00:00:00.000000000'
#  '2019-11-01T00:00:00.000000000' '2019-12-01T00:00:00.000000000']
# ----------------------------------------
# 2016-01-01     376
# 2016-02-01     472
# 2016-03-01     536
# 2016-04-01     532
# 2016-05-01     459
# 2016-06-01     452
# 2016-07-01     176
# 2016-08-01      94
# 2016-09-01     141
# 2016-10-01     160
# 2016-11-01     142
# 2016-12-01     134
# 2017-01-01     306
# 2017-02-01     368
# 2017-03-01     471
# 2017-04-01     380
# 2017-05-01     404
# 2017-06-01     409
# 2017-07-01     215
# 2017-08-01     114
# 2017-09-01     149
# 2017-10-01     154
# 2017-11-01     180
# 2017-12-01     123
# 2018-01-01     511
# 2018-02-01     539
# 2018-03-01     695
# 2018-04-01     541
# 2018-05-01     572
# 2018-06-01     532
# 2018-07-01     396
# 2018-08-01     285
# 2018-09-01     141
# 2018-10-01      97
# 2018-11-01     110
# 2018-12-01     103
# 2019-01-01     541
# 2019-02-01     585
# 2019-03-01     543
# 2019-04-01     506
# 2019-05-01     440
# 2019-06-01     224
# 2019-07-01       6
# 2019-08-01       1
# 2019-09-01       5
# 2019-11-01       1
# 2019-12-01       1
# NaT           1597
# Name: registration, dtype: int64
# ----------------------------------------
# NaT           1597
# 2018-03-01     695
# 2019-02-01     585
# 2018-05-01     572
# 2019-03-01     543
# 2019-01-01     541
# 2018-04-01     541
# 2018-02-01     539
# 2016-03-01     536
# 2016-04-01     532
# 2018-06-01     532
# 2018-01-01     511
# 2019-04-01     506
# 2016-02-01     472
# 2017-03-01     471
# 2016-05-01     459
# 2016-06-01     452
# 2019-05-01     440
# 2017-06-01     409
# 2017-05-01     404
# 2018-07-01     396
# 2017-04-01     380
# 2016-01-01     376
# 2017-02-01     368
# 2017-01-01     306
# 2018-08-01     285
# 2019-06-01     224
# 2017-07-01     215
# 2017-11-01     180
# 2016-07-01     176
# 2016-10-01     160
# 2017-10-01     154
# 2017-09-01     149
# 2016-11-01     142
# 2018-09-01     141
# 2016-09-01     141
# 2016-12-01     134
# 2017-12-01     123
# 2017-08-01     114
# 2018-11-01     110
# 2018-12-01     103
# 2018-10-01      97
# 2016-08-01      94
# 2019-07-01       6
# 2019-09-01       5
# 2019-08-01       1
# 2019-11-01       1
# 2019-12-01       1
# Name: registration, dtype: int64
# ################################################################################

# %%
df.drop(columns="first_registration", inplace=True)

# %% [markdown]
# ### prev_owner & previous_owners

# %%
first_look("prev_owner")
# Out:
# column name :  prev_owner
# ----------------------------------------
# Per_of_Nulls   :  % 42.89
# Number of Nulls  :  6828
# Number of Uniques:  4
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['2 previous owners' None '1 previous owner' '3 previous owners'
#  '4 previous owners']
# ----------------------------------------
# 1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ----------------------------------------
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
# ################################################################################

# %%
first_look("previous_owners")
# Out:
# column name :  previous_owners
# ----------------------------------------
# Per_of_Nulls   :  % 41.71
# Number of Nulls  :  6640
# Number of Uniques:  101
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['2' nan '1' '0' '3' '4' '1102 g CO2/km (comb)' '1105 g CO2/km (comb)'
#  '1110 g CO2/km (comb)' '1116 g CO2/km (comb)'
#  '14.8 l/100 km (comb)5.9 l/100 km (city)4.2 l/100 km (country)'
#  '00 kWh/100 km (comb)' '0105 g CO2/km (comb)' '0106 g CO2/km (comb)'
#  '04.6 l/100 km (comb)5.8 l/100 km (city)3.9 l/100 km (country)'
#  '0104 g CO2/km (comb)' '1111 g CO2/km (comb)'
#  '14.9 l/100 km (comb)6 l/100 km (city)4.2 l/100 km (country)'
#  '2127 g CO2/km (comb)' '199 g CO2/km (comb)' '2122 g CO2/km (comb)'
#  '1114 g CO2/km (comb)' '1109 g CO2/km (comb)' '1107 g CO2/km (comb)'
#  '15.2 l/100 km (comb)6 l/100 km (city)4.8 l/100 km (country)'
#  '0117 g CO2/km (comb)' '0107 g CO2/km (comb)' '0114 g CO2/km (comb)'
#  '2124 g CO2/km (comb)' '1125 g CO2/km (comb)' '2119 g CO2/km (comb)'
#  '16.3 l/100 km (comb)8.6 l/100 km (city)5 l/100 km (country)'
#  '1128 g CO2/km (comb)' '1119 g CO2/km (comb)' '1124 g CO2/km (comb)'
#  '1127 g CO2/km (comb)' '196 g CO2/km (comb)' '1104 g CO2/km (comb)'
#  '15.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '1134 g CO2/km (comb)'
#  '16.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)'
#  '15.4 l/100 km (comb)7.1 l/100 km (city)4.4 l/100 km (country)'
#  '15.9 l/100 km (comb)7.4 l/100 km (city)5 l/100 km (country)'
#  '1129 g CO2/km (comb)'
#  '05.4 l/100 km (comb)7.1 l/100 km (city)4.4 l/100 km (country)'
#  '15 l/100 km (comb)5.9 l/100 km (city)4.5 l/100 km (country)'
#  '16 l/100 km (comb)7.8 l/100 km (city)4.9 l/100 km (country)'
#  '1133 g CO2/km (comb)' '10 g CO2/km (comb)' '1137 g CO2/km (comb)'
#  '2137 g CO2/km (comb)' '1142 g CO2/km (comb)' '184 g CO2/km (comb)'
#  '1140 g CO2/km (comb)'
#  '25.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '2129 g CO2/km (comb)'
#  '15.9 l/100 km (comb)7.5 l/100 km (city)5 l/100 km (country)'
#  '16.6 l/100 km (comb)8.2 l/100 km (city)5.7 l/100 km (country)'
#  '16.6 l/100 km (comb)8.2 l/100 km (city)5.6 l/100 km (country)'
#  '16 l/100 km (comb)8 l/100 km (city)4.9 l/100 km (country)'
#  '15.9 l/100 km (comb)7.9 l/100 km (city)4.8 l/100 km (country)'
#  '16.3 l/100 km (comb)7.8 l/100 km (city)5.4 l/100 km (country)'
#  '16.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)'
#  '1149 g CO2/km (comb)' '1Euro 6'
#  '06.6 l/100 km (comb)8.2 l/100 km (city)5.7 l/100 km (country)'
#  '16.6 l/100 km (comb)8.1 l/100 km (city)5.7 l/100 km (country)'
#  '0126 g CO2/km (comb)' '0120 g CO2/km (comb)'
#  '15.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '1159 g CO2/km (comb)' '1145 g CO2/km (comb)' '1126 g CO2/km (comb)'
#  '16 l/100 km (comb)7.7 l/100 km (city)4.9 l/100 km (country)'
#  '1147 g CO2/km (comb)' '1150 g CO2/km (comb)' '1141 g CO2/km (comb)'
#  '0136 g CO2/km (comb)' '1136 g CO2/km (comb)'
#  '15.8 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)'
#  '1181 g CO2/km (comb)'
#  '16.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)'
#  '16.7 l/100 km (comb)8.6 l/100 km (city)5.6 l/100 km (country)'
#  '15.9 l/100 km (comb)7.6 l/100 km (city)4.9 l/100 km (country)'
#  '0187 g CO2/km (comb)' '0139 g CO2/km (comb)' '1188 g CO2/km (comb)'
#  '1187 g CO2/km (comb)' '1120 g CO2/km (comb)' '185 g CO2/km (comb)'
#  '15.9 l/100 km (comb)7.6 l/100 km (city)5.1 l/100 km (country)'
#  '1135 g CO2/km (comb)'
#  '15 l/100 km (comb)6.3 l/100 km (city)4.2 l/100 km (country)'
#  '1113 g CO2/km (comb)' '2123 g CO2/km (comb)' '2125 g CO2/km (comb)'
#  '1139 g CO2/km (comb)'
#  '16.8 l/100 km (comb)8.7 l/100 km (city)5.7 l/100 km (country)'
#  '1153 g CO2/km (comb)' '1168 g CO2/km (comb)'
#  '17.4 l/100 km (comb)9.2 l/100 km (city)6.3 l/100 km (country)'
#  '1123 g CO2/km (comb)']
# ----------------------------------------
# 0                                                                 163
# 00 kWh/100 km (comb)                                                2
# 0104 g CO2/km (comb)                                                1
# 0105 g CO2/km (comb)                                                1
# 0106 g CO2/km (comb)                                                1
#                                                                  ...
# 2137 g CO2/km (comb)                                                1
# 25.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       2
# 3                                                                  17
# 4                                                                   2
# NaN                                                              6640
# Name: previous_owners, Length: 102, dtype: int64
# ----------------------------------------
# 1                                                                8103
# NaN                                                              6640
# 2                                                                 766
# 0                                                                 163
# 3                                                                  17
#                                                                  ...
# 1111 g CO2/km (comb)                                                1
# 1Euro 6                                                             1
# 2119 g CO2/km (comb)                                                1
# 16.6 l/100 km (comb)8.1 l/100 km (city)5.7 l/100 km (country)       1
# 1142 g CO2/km (comb)                                                1
# Name: previous_owners, Length: 102, dtype: int64
# ################################################################################

# %%
df["previous_owners"].str.extract("(\d).*").value_counts()
# Out:
# 1    8294
# 2     778
# 0     188
# 3      17
# 4       2
# dtype: int64

# %%
df.loc[df[df["prev_owner"].isnull()][df[df["prev_owner"].isnull()]["previous_owners"].str.startswith("0") == True].index,"prev_owner"] = "0 previous owner"

# %%
df["prev_owner"].value_counts()
# Out:
# 1 previous owner     8294
# 2 previous owners     778
# 0 previous owner      188
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df["prev_owner"] = df["prev_owner"].str.extract("(\d)").astype(float)

# %%
df["prev_owner"].value_counts(dropna=False)
# Out:
# 1.0    8294
# NaN    6640
# 2.0     778
# 0.0     188
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64

# %%
first_look("prev_owner")
# Out:
# column name :  prev_owner
# ----------------------------------------
# Per_of_Nulls   :  % 41.71
# Number of Nulls  :  6640
# Number of Uniques:  5
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [ 2. nan  1.  0.  3.  4.]
# ----------------------------------------
# 0.0     188
# 1.0    8294
# 2.0     778
# 3.0      17
# 4.0       2
# NaN    6640
# Name: prev_owner, dtype: int64
# ----------------------------------------
# 1.0    8294
# NaN    6640
# 2.0     778
# 0.0     188
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64
# ################################################################################

# %% [markdown]
# ### hp

# %%
first_look("hp")
# Out:
# column name :  hp
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  81
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['66 kW' '141 kW' '85 kW' '70 kW' '92 kW' '112 kW' '60 kW' '71 kW' '67 kW'
#  '110 kW' '93 kW' '147 kW' '86 kW' '140 kW' '87 kW' '- kW' '81 kW' '82 kW'
#  '135 kW' '132 kW' '100 kW' '96 kW' '162 kW' '150 kW' '294 kW' '228 kW'
#  '270 kW' '137 kW' '9 kW' '133 kW' '77 kW' '101 kW' '78 kW' '103 kW'
#  '1 kW' '74 kW' '118 kW' '84 kW' '88 kW' '80 kW' '76 kW' '149 kW' '44 kW'
#  '51 kW' '55 kW' '52 kW' '63 kW' '40 kW' '65 kW' '75 kW' '125 kW' '120 kW'
#  '184 kW' '239 kW' '121 kW' '143 kW' '191 kW' '89 kW' '195 kW' '127 kW'
#  '122 kW' '154 kW' '155 kW' '104 kW' '123 kW' '146 kW' '90 kW' '53 kW'
#  '54 kW' '56 kW' '164 kW' '4 kW' '163 kW' '57 kW' '119 kW' '165 kW'
#  '117 kW' '115 kW' '98 kW' '168 kW' '167 kW']
# ----------------------------------------
# - kW        88
# 1 kW        20
# 100 kW    1308
# 101 kW      47
# 103 kW     253
#           ...
# 90 kW        4
# 92 kW      466
# 93 kW        3
# 96 kW       72
# 98 kW        3
# Name: hp, Length: 81, dtype: int64
# ----------------------------------------
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
#           ...
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 9 kW         1
# Name: hp, Length: 81, dtype: int64
# ################################################################################

# %%
df["hp_kw"] = df.hp.str.extract("(\d+) kW").astype(float)

# %%
first_look("hp_kw")
# Out:
# column name :  hp_kw
# ----------------------------------------
# Per_of_Nulls   :  % 0.55
# Number of Nulls  :  88
# Number of Uniques:  80
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [ 66. 141.  85.  70.  92. 112.  60.  71.  67. 110.  93. 147.  86. 140.
#   87.  nan  81.  82. 135. 132. 100.  96. 162. 150. 294. 228. 270. 137.
#    9. 133.  77. 101.  78. 103.   1.  74. 118.  84.  88.  80.  76. 149.
#   44.  51.  55.  52.  63.  40.  65.  75. 125. 120. 184. 239. 121. 143.
#  191.  89. 195. 127. 122. 154. 155. 104. 123. 146.  90.  53.  54.  56.
#  164.   4. 163.  57. 119. 165. 117. 115.  98. 168. 167.]
# ----------------------------------------
# 1.0      20
# 4.0       1
# 9.0       1
# 40.0      2
# 44.0      1
#          ..
# 228.0     2
# 239.0     1
# 270.0     2
# 294.0    18
# NaN      88
# Name: hp_kw, Length: 81, dtype: int64
# ----------------------------------------
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
#          ...
# 84.0        1
# 195.0       1
# 44.0        1
# 239.0       1
# 9.0         1
# Name: hp_kw, Length: 81, dtype: int64
# ################################################################################

# %%
#looking for the null values of hp_kw in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["hp_kw"].isnull()][i].str.contains("kw|Kw|KW").any():
        print(i)
# Out:
# url
# short_description

# %%
df[df["hp_kw"].isnull()][df[df["hp_kw"].isnull()]["short_description"].str.contains("kw|Kw|KW")]
# Out:
#                                                     url make_model  \
# 1269  https://www.autoscout24.com//offers/audi-a1-ad...    Audi A1
# 4259  https://www.autoscout24.com//offers/audi-a3-de...    Audi A3
#
#                              short_description body_type  price   vat  \
# 1269  ADRENALIN 1.6 TDI 85KW (116CV) SPORTBACK   Compact  15500  None
# 4259     DESIGN EDITION 1.6 TDI 85KW SPORTBACK   Compact  18700  None
#
#            km registration  prev_owner    hp           type previous_owners  \
# 1269  11284.0   2018-06-01         NaN  - kW  ,Used,,Diesel             NaN
# 4259  16316.0   2018-06-01         NaN  - kW  ,Used,,Diesel             NaN
#
#      next_inspection inspection_new   warranty full_service  \
# 1269             NaN            NaN  36 months          NaN
# 4259             NaN            NaN  24 months          NaN
#
#      non_smoking_vehicle offer_number body_color paint_type  \
# 1269                 NaN      2642843       Blue        NaN
# 4259                 NaN      2683780       Grey        NaN
#
#      body_color_original upholstery nr_of_doors nr_of_seats model_code  \
# 1269                Azul        NaN           5         NaN        NaN
# 4259                Gris        NaN           5         NaN        NaN
#
#      gearing_type displacement cylinders weight drive_chain    fuel  \
# 1269       Manual          NaN       NaN    NaN         NaN  Diesel
# 4259       Manual          NaN       NaN    NaN         NaN  Diesel
#
#      consumption co_2_emission emission_class comfort_&_convenience  \
# 1269         NaN           NaN            NaN                   NaN
# 4259         NaN           NaN            NaN                   NaN
#
#      entertainment_&_media extras safety_&_security emission_label gears  \
# 1269                   NaN    NaN               NaN            NaN   NaN
# 4259                   NaN    NaN               NaN            NaN   NaN
#
#      country_version electricity_consumption last_service_date  \
# 1269             NaN                     NaN               NaN
# 4259             NaN                     NaN               NaN
#
#      other_fuel_types availability last_timing_belt_service_date  \
# 1269              NaN          NaN                           NaN
# 4259              NaN          NaN                           NaN
#
#      available_from consumption_comb consumption_city consumption_country  \
# 1269            NaN              NaN              NaN                 NaN
# 4259            NaN              NaN              NaN                 NaN
#
#       hp_kw
# 1269    NaN
# 4259    NaN

# %%
#Looking at short description column and get KW and change it to float and change the value in hp_kw with it
df.loc[df[df["hp_kw"].isnull()][df[df["hp_kw"].isnull()]["short_description"].str.contains("kw|Kw|KW")].index, "hp_kw"] = df[df["hp_kw"].isnull()]["short_description"].str.extract("(\d+)KW").loc[df[df["hp_kw"].isnull()][df[df["hp_kw"].isnull()]["short_description"].str.contains("kw|Kw|KW")].index].astype(float).values

# %%
df.drop(columns="hp", inplace=True)

# %% [markdown]
# ### type & fuel

# %%
first_look("type")
# Out:
# column name :  type
# ----------------------------------------
# Per_of_Nulls   :  % 0.01
# Number of Nulls  :  2
# Number of Uniques:  169
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [',Used,,Diesel (Particulate Filter)' ',Used,,Gasoline' ',Used,,Super 95'
#  ',Used,,Regular/Benzine 91'
#  ",Employee's car,,Diesel (Particulate Filter)" ',Used,,Diesel'
#  ',Used,,Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98'
#  ",Employee's car,,Regular/Benzine 91" ",Employee's car,,Diesel"
#  ",Employee's car,,Super E10 95" ',New,,Super 95 (Particulate Filter)'
#  ',Used,,Super 95 / Regular/Benzine 91' ",Employee's car,,Super 95"
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Super E10 95 / Super 95' ',Used,,Super E10 95'
#  ',Used,,Super 95 / Regular/Benzine 91 / Super Plus 98'
#  ',Demonstration,,Super 95'
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95'
#  ',Used,,Super 95 / Super Plus 98' ",Employee's car,,Gasoline"
#  ',Used,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  ',Pre-registered,,Gasoline' ',New,,Gasoline' ',Used,,Others'
#  ',Demonstration,,Super 95 / Super E10 95' ',Demonstration,,Gasoline'
#  ',New,,Super 95' ',Pre-registered,,Diesel (Particulate Filter)'
#  ',Pre-registered,,Diesel' ',Used,,Super 95 / Super E10 95'
#  ',Demonstration,,Diesel (Particulate Filter)' ',Pre-registered,,Super 95'
#  ',New,,Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91' ',Demonstration,,Diesel'
#  ',Used,,Gasoline (Particulate Filter)'
#  ',Used,,Regular/Benzine E10 91 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 (Particulate Filter)'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98 (Particulate Filter)'
#  ',Demonstration,,Super 95 (Particulate Filter)'
#  ',New,,Regular/Benzine E10 91' ',Demonstration,,Super E10 95'
#  ",Employee's car,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95"
#  ',New,,Regular/Benzine 91 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine 91 (Particulate Filter)'
#  ',New,,Super E10 95' ',New,,Super E10 95 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine 91'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ",Employee's car,,Regular/Benzine 91 (Particulate Filter)"
#  ',New,,Super Plus 98' ',Pre-registered,,Regular/Benzine 91'
#  ",Employee's car,,Gasoline (Particulate Filter)" ',New,,Diesel'
#  ',New,,Super E10 95 / Super 95' ',New,,Super 95 / Regular/Benzine 91'
#  ',New,,Super 95 / Super E10 95' ',New,,Diesel (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98'
#  ',Demonstration,,Super E10 95 / Super 95' ',Used,,CNG'
#  ',Used,,Super 95 (Particulate Filter)' nan ',New,,CNG'
#  ',Used,,Electric/Gasoline' ',Used,,CNG (Particulate Filter)'
#  ',Pre-registered,,Gasoline (Particulate Filter)'
#  ',Used,,Others (Particulate Filter)'
#  ',Pre-registered,,Regular/Benzine 91 (Particulate Filter)'
#  ',Used,,Super Plus 98' ',Pre-registered,,Super E10 95'
#  ',Pre-registered,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',New,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',Used,,Regular/Benzine 91 (Particulate Filter)'
#  ',Demonstration,,Super E10 95 (Particulate Filter)'
#  ',New,,Gasoline (Particulate Filter)' ',Pre-registered,,Biogas'
#  ',Pre-registered,,CNG (Particulate Filter)'
#  ',New,,CNG (Particulate Filter)' ',New,,Super 95 / Biodiesel'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',Used,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 (Particulate Filter)'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Super E10 95 (Particulate Filter)'
#  ',Used,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Domestic gas H'
#  ',Used,,Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  ",Employee's car,,Super 95 / Regular/Benzine 91"
#  ",Employee's car,,Super 95 (Particulate Filter)"
#  ',Pre-registered,,Regular/Benzine 91 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super 95 / Regular/Benzine 91'
#  ',Used,,Regular/Benzine E10 91'
#  ',Used,,Super E10 95 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98'
#  ',Used,,Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95'
#  ',New,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',Pre-registered,,Super Plus 98'
#  ',Demonstration,,Super Plus 98 / Super 95 / Super E10 95'
#  ',Demonstration,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',New,,Super 95 / Super Plus 98 / Super E10 95' ',New,,Super Plus E10 98'
#  ',Used,,Super 95 / Super Plus 98 (Particulate Filter)'
#  ',Demonstration,,Super Plus 98'
#  ',Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',New,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super Plus 98 / Super E10 95'
#  ',Pre-registered,,Super 95 / Super E10 95'
#  ',Pre-registered,,Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98'
#  ',Pre-registered,,CNG'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',New,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  ',Used,,Super 95 / Super E10 95 (Particulate Filter)'
#  ",Employee's car,,Super E10 95 (Particulate Filter)"
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95' ',Used,,LPG'
#  ',Used,,Liquid petroleum gas (LPG)'
#  ",Employee's car,,Super 95 / Super E10 95"
#  ',Used,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  ",Employee's car,,LPG"
#  ',Used,,Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Super 95 / Regular/Benzine 91'
#  ",Employee's car,,Super E10 95 / Super 95"
#  ",Employee's car,,Regular/Benzine 91 / Super 95 / Super E10 95"
#  ',Used,,Super 95 / Regular/Benzine E10 91 / Super E10 95'
#  ',Pre-registered,,Regular/Benzine E10 91'
#  ',Pre-registered,,Super 95 / Super Plus 98'
#  ',Used,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95'
#  ',Demonstration,,Super 95 / Super Plus 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super E10 95 / Regular/Benzine E10 91'
#  ',Demonstration,,Super 95 / Super E10 95 (Particulate Filter)'
#  ',Used,,Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91'
#  ',New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Pre-registered,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  ',Pre-registered,,Liquid petroleum gas (LPG)' ',Pre-registered,,Others'
#  ',Pre-registered,,Super E10 95 / Super 95 / Super Plus 98'
#  ',Pre-registered,,Super E10 95 / Regular/Benzine 91 / Regular/Benzine E10 91 / Super 95'
#  ',New,,LPG' ',Used,,Super 95 / Regular/Benzine E10 91'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91'
#  ',Pre-registered,,Super E10 95 / Super 95'
#  ',Used,,Super 95 / Super E10 95 / Super Plus E10 98'
#  ',Used,,Regular/Benzine 91 / Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  ',Demonstration,,Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95 / Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  ',Demonstration,,Super Plus 98 / Regular/Benzine 91'
#  ',Demonstration,,Super 95 / Regular/Benzine 91 (Particulate Filter)'
#  ',Pre-registered,,Super 95 / Super E10 95 / Regular/Benzine 91'
#  ',Used,,Super 95 / Super E10 95 / Super Plus 98' ',Used,,Electric'
#  ',Pre-registered,,LPG'
#  ',Demonstration,,Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95'
#  ",Employee's car,,Super E10 95 / Super 95 / Super Plus 98"
#  ',Demonstration,,Gasoline (Particulate Filter)'
#  ',Used,,Super E10 95 / Regular/Benzine 91'
#  ',Used,,Super 95 / Super Plus 98 / Super Plus E10 98'
#  ',Pre-registered,,Super Plus 98 / Super 95 / Super Plus E10 98'
#  ",Employee's car,,Others"
#  ',Pre-registered,,Super E10 95 / Regular/Benzine 91'
#  ',Pre-registered,,Super E10 95 (Particulate Filter)'
#  ',Demonstration,,Regular/Benzine E10 91']
# ----------------------------------------
# ,Demonstration,,Diesel                                                 45
# ,Demonstration,,Diesel (Particulate Filter)                           129
# ,Demonstration,,Gasoline                                              158
# ,Demonstration,,Gasoline (Particulate Filter)                           1
# ,Demonstration,,Regular/Benzine 91                                     36
#                                                                      ...
# ,Used,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98      8
# ,Used,,Super E10 95 / Super Plus E10 98                                 4
# ,Used,,Super Plus 98                                                    2
# ,Used,,Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95      1
# NaN                                                                     2
# Name: type, Length: 170, dtype: int64
# ----------------------------------------
# ,Used,,Diesel (Particulate Filter)                                                                                 3475
# ,Used,,Diesel                                                                                                      2516
# ,Used,,Gasoline                                                                                                    2367
# ,Used,,Super 95                                                                                                    1818
# ,Pre-registered,,Super 95                                                                                           500
#                                                                                                                    ...
# ,New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95       1
# ,Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)                               1
# ,Demonstration,,Super Plus 98                                                                                         1
# ,New,,Super Plus E10 98                                                                                               1
# ,Demonstration,,Regular/Benzine E10 91                                                                                1
# Name: type, Length: 170, dtype: int64
# ################################################################################

# %%
first_look("fuel")
# Out:
# column name :  fuel
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  77
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Diesel (Particulate Filter)' 'Gasoline' 'Super 95' 'Regular/Benzine 91'
#  'Diesel'
#  'Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98'
#  'Super E10 95' 'Super 95 (Particulate Filter)'
#  'Super 95 / Regular/Benzine 91'
#  'Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  'Super E10 95 / Super 95' 'Super 95 / Regular/Benzine 91 / Super Plus 98'
#  'Super 95 / Super Plus 98 / Super E10 95' 'Super 95 / Super Plus 98'
#  'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  'Others' 'Super 95 / Super E10 95' 'Gasoline (Particulate Filter)'
#  'Regular/Benzine E10 91 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98'
#  'Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98 (Particulate Filter)'
#  'Regular/Benzine E10 91'
#  'Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95'
#  'Regular/Benzine 91 (Particulate Filter)'
#  'Super E10 95 (Particulate Filter)' 'Super Plus 98' 'CNG'
#  'Electric/Gasoline' 'CNG (Particulate Filter)'
#  'Others (Particulate Filter)'
#  'Super 95 / Super E10 95 (Particulate Filter)' 'Biogas'
#  'Super 95 / Biodiesel'
#  'Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  'Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98'
#  'Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 (Particulate Filter)'
#  'Regular/Benzine 91 / Super 95 / Super Plus 98'
#  'Regular/Benzine 91 / Super 95'
#  'Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  'Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98'
#  'Domestic gas H'
#  'Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  'Regular/Benzine 91 / Regular/Benzine E10 91'
#  'Super E10 95 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98'
#  'Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95'
#  'Super 95 / Super Plus 98 (Particulate Filter)'
#  'Super Plus 98 / Super 95 / Super E10 95'
#  'Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)'
#  'Super Plus E10 98'
#  'Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91'
#  'Super Plus 98 / Super E10 95'
#  'Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98'
#  'Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95'
#  'LPG' 'Liquid petroleum gas (LPG)'
#  'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98'
#  'Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Super 95 / Regular/Benzine 91'
#  'Regular/Benzine 91 / Super 95 / Super E10 95'
#  'Super 95 / Regular/Benzine E10 91 / Super E10 95'
#  'Regular/Benzine 91 / Super 95 / Super E10 95 / Regular/Benzine E10 91'
#  'Super E10 95 / Super Plus E10 98'
#  'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91'
#  'Super E10 95 / Super 95 / Super Plus 98'
#  'Super E10 95 / Regular/Benzine 91 / Regular/Benzine E10 91 / Super 95'
#  'Super 95 / Regular/Benzine E10 91'
#  'Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98'
#  'Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91'
#  'Super 95 / Super E10 95 / Super Plus E10 98'
#  'Regular/Benzine 91 / Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91'
#  'Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95 / Regular/Benzine 91'
#  'Super Plus 98 / Regular/Benzine 91'
#  'Super 95 / Regular/Benzine 91 (Particulate Filter)'
#  'Super 95 / Super E10 95 / Regular/Benzine 91'
#  'Super 95 / Super E10 95 / Super Plus 98' 'Electric'
#  'Super E10 95 / Regular/Benzine 91'
#  'Super 95 / Super Plus 98 / Super Plus E10 98'
#  'Super Plus 98 / Super 95 / Super Plus E10 98']
# ----------------------------------------
# Biogas                                                            1
# CNG                                                              33
# CNG (Particulate Filter)                                          3
# Diesel                                                         2984
# Diesel (Particulate Filter)                                    4315
#                                                                ...
# Super Plus 98 / Super 95 / Super E10 95                           1
# Super Plus 98 / Super 95 / Super Plus E10 98                      1
# Super Plus 98 / Super E10 95                                      1
# Super Plus E10 98                                                 1
# Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95       1
# Name: fuel, Length: 77, dtype: int64
# ----------------------------------------
# Diesel (Particulate Filter)                                                                                  4315
# Super 95                                                                                                     3338
# Gasoline                                                                                                     3175
# Diesel                                                                                                       2984
# Super 95 / Regular/Benzine 91                                                                                 424
#                                                                                                              ...
# Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91                                                          1
# Super Plus 98 / Super E10 95                                                                                    1
# Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98       1
# Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98       1
# Super Plus 98 / Super 95 / Super Plus E10 98                                                                    1
# Name: fuel, Length: 77, dtype: int64
# ################################################################################

# %%
df[df["type"].isnull()]
# Out:
#                                                     url make_model  \
# 2765  https://www.autoscout24.com//offers/audi-a3-sp...    Audi A3
# 5237  https://www.autoscout24.com//offers/audi-a3-sp...    Audi A3
#
#                 short_description body_type  price   vat        km  \
# 2765   SPB 2.0 TDI S tronic Sport    Sedans  17900  None  115137.0
# 5237  SPB 1.6 TDI 116 CV S tronic    Sedans  25400  None       NaN
#
#      registration  prev_owner type previous_owners next_inspection  \
# 2765   2016-10-01         NaN  NaN             NaN             NaN
# 5237          NaT         NaN  NaN             NaN             NaN
#
#      inspection_new   warranty full_service non_smoking_vehicle offer_number  \
# 2765            NaN  ,,,Diesel          NaN                 NaN     57551628
# 5237            NaN        NaN          NaN                 NaN     57247041
#
#      body_color paint_type body_color_original    upholstery nr_of_doors  \
# 2765      White        NaN                 NaN  Cloth, Other           5
# 5237       Grey        NaN                 NaN  Cloth, Other           5
#
#      nr_of_seats model_code gearing_type displacement cylinders weight  \
# 2765           5        NaN    Automatic     1,968 cc         4    NaN
# 5237           5        NaN    Automatic     1,598 cc         4    NaN
#
#      drive_chain    fuel                                        consumption  \
# 2765       front  Diesel  ['4.5 l/100 km (comb)'],['5.3 l/100 km (city)'...
# 5237       front  Diesel  ['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'...
#
#             co_2_emission emission_class comfort_&_convenience  \
# 2765  118 g CO2/km (comb)         Euro 6      Air conditioning
# 5237  103 g CO2/km (comb)         Euro 6      Air conditioning
#
#                entertainment_&_media  \
# 2765  Bluetooth,Hands-free equipment
# 5237  Bluetooth,Hands-free equipment
#
#                                          extras  \
# 2765  Alloy wheels,Sport seats,Sport suspension
# 5237                               Alloy wheels
#
#                                       safety_&_security  emission_label gears  \
# 2765  ABS,Central door lock,Driver-side airbag,Isofi...  1 (No sticker)     6
# 5237  ABS,Central door lock,Driver-side airbag,Isofi...  1 (No sticker)     7
#
#      country_version electricity_consumption last_service_date  \
# 2765             NaN                     NaN               NaN
# 5237             NaN                     NaN               NaN
#
#      other_fuel_types availability last_timing_belt_service_date  \
# 2765              NaN          NaN                           NaN
# 5237              NaN          NaN                           NaN
#
#      available_from consumption_comb consumption_city consumption_country  \
# 2765            NaN              4.5              5.3                 4.1
# 5237            NaN              3.9              4.1                 3.7
#
#       hp_kw
# 2765  110.0
# 5237   85.0

# %%
#Contolling whether fuel in type or not
def isin_control(column1, column2):
    return column1 in column2
df[["type","fuel"]].apply(lambda x: isin_control(str(x.fuel), str(x.type)), axis=1).value_counts()
# Out:
# True     15917
# False        2
# dtype: int64

# %%
df["type"] = df["type"].str.split(",", expand=True)[1]

# %%
first_look("type")
# Out:
# column name :  type
# ----------------------------------------
# Per_of_Nulls   :  % 0.01
# Number of Nulls  :  2
# Number of Uniques:  5
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Used' "Employee's car" 'New' 'Demonstration' 'Pre-registered' nan]
# ----------------------------------------
# Demonstration       796
# Employee's car     1011
# New                1650
# Pre-registered     1364
# Used              11096
# NaN                   2
# Name: type, dtype: int64
# ----------------------------------------
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: type, dtype: int64
# ################################################################################

# %%
df["Particulate_Filter"] = df["fuel"].transform(lambda x: 1 if "Particulate" in str(x) else 0)
df["Particulate_Filter"].value_counts()
# Out:
# 0    11100
# 1     4819
# Name: Particulate_Filter, dtype: int64

# %%
def fuel_categorise(x):
    if  "Electric/Gasoline" in x:
        return "Hybrid"
    elif "LPG" in x or "gas" in x or "CNG" in x:
        return "Gas"
    elif "Electric" in x:
        return "Electric"
    elif "Diesel" in x:
        return "Diesel"
    elif "Gasoline" in x or "Super" in x or "Benzine" in x or "Regular" in x:
        return "Benzine"
    else : return "Other"
df["fuel"] = df["fuel"].transform(lambda x: fuel_categorise(x))

# %%
df.fuel.value_counts()
# Out:
# Benzine     8545
# Diesel      7299
# Gas           64
# Other          6
# Hybrid         4
# Electric       1
# Name: fuel, dtype: int64

# %%
df[df["fuel"] == "Other"]
# Out:
#                                                      url     make_model  \
# 819    https://www.autoscout24.com//offers/audi-a1-1-...        Audi A1
# 2885   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 4003   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 10374  https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 11677  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 14500  https://www.autoscout24.com//offers/renault-cl...   Renault Clio
#
#                                        short_description body_type  price  \
# 819              1.4TDI Sportback /Euro6 /Navi /SHZ /PDC    Sedans  14388
# 2885   SPORTBACK 1.4 TFSI G-Tron S-Tronic Adrenalin S...   Compact  16400
# 4003       Sportback 1.6 TDI S-Tronic*LED*Navigation*APS    Sedans  19490
# 10374                           1.4 GLP Selective Pro 90    Sedans  11300
# 11677                                            Edition     Other  18480
# 14500                   TCe Energy GLP Limited 66kW 90CV    Sedans  10800
#
#                   vat        km registration  prev_owner            type  \
# 819    VAT deductible   25684.0   2016-10-01         1.0            Used
# 2885   VAT deductible  123748.0   2016-04-01         NaN            Used
# 4003   VAT deductible   49267.0   2017-08-01         1.0            Used
# 10374  VAT deductible       5.0   2019-05-01         1.0  Pre-registered
# 11677  VAT deductible   14937.0   2018-02-01         NaN            Used
# 14500  VAT deductible   13000.0   2018-06-01         1.0  Employee's car
#
#       previous_owners   next_inspection inspection_new  \
# 819                 1               NaN   Yes4 (Green)
# 2885              NaN           04/2020            NaN
# 4003                1  08/20204 (Green)            NaN
# 10374               1               NaN            NaN
# 11677             NaN               NaN            Yes
# 14500               1               NaN            NaN
#
#                            warranty full_service non_smoking_vehicle  \
# 819
# 2885                            NaN       Euro 6                 NaN
# 4003
# 10374  24 months126 g CO2/km (comb)          NaN                 NaN
# 11677                           NaN          NaN                 NaN
# 14500         12 monthsEuro 6d-TEMP
#
#       offer_number body_color paint_type body_color_original    upholstery  \
# 819          0185N      White   Metallic      Gletscherweiss  Cloth, Black
# 2885        JH480V      White        NaN                 Wit  Cloth, Black
# 4003      M-289025        Red   Metallic   Tangorot Metallic  Cloth, Black
# 10374          NaN      White        NaN                 NaN  Cloth, Black
# 11677  00-40-12992        NaN        NaN                 NaN         Other
# 14500          NaN      White        NaN      BLANCO GLACIAR  Cloth, Black
#
#       nr_of_doors nr_of_seats model_code gearing_type displacement cylinders  \
# 819             5           5   0588/BDF       Manual     1,422 cc       NaN
# 2885            5           5        NaN    Automatic     1,395 cc         4
# 4003            5           5        NaN    Automatic     1,598 cc         4
# 10374           5           5        NaN       Manual     1,398 cc         4
# 11677           4         NaN        NaN       Manual     1,500 cc       NaN
# 14500           5           5        NaN       Manual       898 cc         3
#
#          weight drive_chain   fuel  \
# 819         NaN       front  Other
# 2885   1,255 kg         NaN  Other
# 4003        NaN       front  Other
# 10374  1,163 kg         NaN  Other
# 11677  1,518 kg       front  Other
# 14500  1,082 kg       front  Other
#
#                                              consumption        co_2_emission  \
# 819                                                  NaN                  NaN
# 2885                                                 NaN             [],[],[]
# 4003                                                 NaN                  NaN
# 10374  ['5.1 l/100 km (comb)'],['6.5 l/100 km (city)'...  126 g CO2/km (comb)
# 11677                                                NaN                  NaN
# 14500  ['4.7 l/100 km (comb)'],['5.7 l/100 km (city)'...  108 g CO2/km (comb)
#
#       emission_class                              comfort_&_convenience  \
# 819         [],[],[]  Armrest,Cruise control,Electrical side mirrors...
# 2885          Euro 6  Air conditioning,Armrest,Automatic climate con...
# 4003        [],[],[]  Air conditioning,Automatic climate control,Cru...
# 10374   Euro 6d-TEMP  Air conditioning,Cruise control,Electrical sid...
# 11677       [],[],[]  Air conditioning,Cruise control,Electrical sid...
# 14500   Euro 6d-TEMP  Air conditioning,Automatic climate control,Cru...
#
#                                    entertainment_&_media  \
# 819    Bluetooth,Hands-free equipment,On-board comput...
# 2885   CD player,Hands-free equipment,On-board comput...
# 4003   Bluetooth,CD player,Hands-free equipment,On-bo...
# 10374  Bluetooth,Hands-free equipment,On-board comput...
# 11677                        On-board computer,Radio,USB
# 14500  Bluetooth,Hands-free equipment,Radio,Sound sys...
#
#                                          extras  \
# 819                                         NaN
# 2885   Alloy wheels,Sport package,Trailer hitch
# 4003                               Alloy wheels
# 10374                Alloy wheels,Voice Control
# 11677                Alloy wheels,Trailer hitch
# 14500                 Alloy wheels,Touch screen
#
#                                        safety_&_security emission_label gears  \
# 819                                                  NaN      4 (Green)     5
# 2885   ABS,Central door lock,Driver-side airbag,Fog l...            NaN     7
# 4003   ABS,Central door lock,Daytime running lights,D...      4 (Green)     7
# 10374  ABS,Adaptive headlights,Central door lock with...            NaN     5
# 11677  Central door lock,Daytime running lights,Drive...      4 (Green)   NaN
# 14500  ABS,Central door lock with remote control,Dayt...            NaN     5
#
#       country_version electricity_consumption           last_service_date  \
# 819               NaN                     NaN                         NaN
# 2885      Netherlands                     NaN                         NaN
# 4003          Germany                     NaN                         NaN
# 10374           Spain                     NaN                         NaN
# 11677         Germany                     NaN                         NaN
# 14500           Spain                     NaN  06/2019108 g CO2/km (comb)
#
#       other_fuel_types availability last_timing_belt_service_date  \
# 819                NaN          NaN                           NaN
# 2885               NaN          NaN                           NaN
# 4003               NaN          NaN                           NaN
# 10374              NaN          NaN                           NaN
# 11677              NaN          NaN                           NaN
# 14500              NaN          NaN                           NaN
#
#       available_from consumption_comb consumption_city consumption_country  \
# 819              NaN              NaN              NaN                 NaN
# 2885             NaN              NaN              NaN                 NaN
# 4003             NaN              NaN              NaN                 NaN
# 10374            NaN              5.1              6.5                 4.3
# 11677            NaN              NaN              NaN                 NaN
# 14500            NaN              4.7              5.7                 4.1
#
#        hp_kw  Particulate_Filter
# 819     66.0                   0
# 2885    81.0                   0
# 4003    85.0                   1
# 10374   66.0                   0
# 11677  103.0                   0
# 14500   66.0                   0

# %%
df.loc[[819,4003],"fuel"] = "Diesel"

# %%
df.loc[df[df["fuel"] == "Other"].index,"fuel"] = "Benzine"

# %%
first_look("fuel")
# Out:
# column name :  fuel
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  5
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Diesel' 'Benzine' 'Gas' 'Hybrid' 'Electric']
# ----------------------------------------
# Benzine     8549
# Diesel      7301
# Electric       1
# Gas           64
# Hybrid         4
# Name: fuel, dtype: int64
# ----------------------------------------
# Benzine     8549
# Diesel      7301
# Gas           64
# Hybrid         4
# Electric       1
# Name: fuel, dtype: int64
# ################################################################################

# %% [markdown]
# ### next_inspection

# %%
first_look("next_inspection")
# Out:
# column name :  next_inspection
# ----------------------------------------
# Per_of_Nulls   :  % 77.79
# Number of Nulls  :  12384
# Number of Uniques:  1384
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['06/202199 g CO2/km (comb)' nan '02/202097 g CO2/km (comb)' ...
#  '02/2022153 g CO2/km (comb)'
#  '06/20217.4 l/100 km (comb)9.2 l/100 km (city)6.3 l/100 km (country)'
#  '01/2022168 g CO2/km (comb)']
# ----------------------------------------
# 01/1921120 g CO2/km (comb)                                               1
# 01/1955                                                                  1
# 01/1999                                                                  1
# 01/2001120 g CO2/km (comb)                                               1
# 01/2001122 g CO2/km (comb)                                               2
#                                                                      ...
# 12/2021167 g CO2/km (comb)                                               1
# 12/20215 l/100 km (comb)6.3 l/100 km (city)4.2 l/100 km (country)        1
# 12/2021Euro 6                                                            1
# 12/2022                                                                  1
# NaN                                                                  12384
# Name: next_inspection, Length: 1385, dtype: int64
# ----------------------------------------
# NaN                           12384
# 04/2022                          62
# 06/2021                          47
# 03/2021                          39
# 03/2022                          36
#                               ...
# 06/2021121 g CO2/km (comb)        1
# 02/2020139 g CO2/km (comb)        1
# 10/2021136 g CO2/km (comb)        1
# 06/2019139 g CO2/km (comb)        1
# 01/2022168 g CO2/km (comb)        1
# Name: next_inspection, Length: 1385, dtype: int64
# ################################################################################

# %%
df["next_inspection"].str.extract("(.*/\d\d\d\d)").value_counts(dropna=False)
# Out:
# NaN        12384
# 06/2021      471
# 03/2021      210
# 05/2021      180
# 04/2021      171
#            ...
# 05/2014        1
# 05/2016        1
# 05/2017        1
# 01/1955        1
# 01/1921        1
# Length: 78, dtype: int64

# %%
df["inspection_time"] = df["next_inspection"].str.extract("(.*/\d\d\d\d)")
df["inspection_time"] = pd.to_datetime(df["inspection_time"])
df["inspection_time"].value_counts(dropna=False)
# Out:
# NaT           12384
# 2021-06-01      471
# 2021-03-01      210
# 2021-05-01      180
# 2021-04-01      171
#               ...
# 2014-05-01        1
# 2016-04-01        1
# 1955-01-01        1
# 2018-01-01        1
# 2022-11-01        1
# Name: inspection_time, Length: 78, dtype: int64

# %%
#Getting some values in inspection time to np.nan because of year before 2019 and date before registration
df.loc[df[df["inspection_time"].dt.year < 2019].index, "inspection_time"] = np.nan
df.loc[df[df["registration"] > df["inspection_time"]].index, "inspection_time"] = np.nan

# %%
first_look("inspection_time")
# Out:
# column name :  inspection_time
# ----------------------------------------
# Per_of_Nulls   :  % 78.21
# Number of Nulls  :  12450
# Number of Uniques:  53
# Type of columns:  datetime64[ns]
# ----------------------------------------
# Unique values of columns:  ['2021-06-01T00:00:00.000000000'                           'NaT'
#  '2020-02-01T00:00:00.000000000' '2019-09-01T00:00:00.000000000'
#  '2019-10-01T00:00:00.000000000' '2020-04-01T00:00:00.000000000'
#  '2020-07-01T00:00:00.000000000' '2019-12-01T00:00:00.000000000'
#  '2019-05-01T00:00:00.000000000' '2019-07-01T00:00:00.000000000'
#  '2021-02-01T00:00:00.000000000' '2019-06-01T00:00:00.000000000'
#  '2020-05-01T00:00:00.000000000' '2019-11-01T00:00:00.000000000'
#  '2020-11-01T00:00:00.000000000' '2021-09-01T00:00:00.000000000'
#  '2020-03-01T00:00:00.000000000' '2021-04-01T00:00:00.000000000'
#  '2019-04-01T00:00:00.000000000' '2021-07-01T00:00:00.000000000'
#  '2021-01-01T00:00:00.000000000' '2022-05-01T00:00:00.000000000'
#  '2020-06-01T00:00:00.000000000' '2019-01-01T00:00:00.000000000'
#  '2020-09-01T00:00:00.000000000' '2021-03-01T00:00:00.000000000'
#  '2021-05-01T00:00:00.000000000' '2020-10-01T00:00:00.000000000'
#  '2019-02-01T00:00:00.000000000' '2019-03-01T00:00:00.000000000'
# 2021-12-01       22
# 2019-12-01       20
# 2023-01-01       20
# 2021-10-01       20
# 2023-02-01       12
# 2023-03-01       10
# 2022-07-01        9
# 2022-08-01        8
# 2023-04-01        3
# 2022-10-01        2
# 2023-05-01        2
# 2022-12-01        1
# 2024-03-01        1
# 2022-11-01        1
# Name: inspection_time, dtype: int64
# ################################################################################

# %% [markdown]
# ### inspection_new

# %%
first_look("inspection_new")
# Out:
# column name :  inspection_new
# ----------------------------------------
# Per_of_Nulls   :  % 75.3
# Number of Nulls  :  11987
# Number of Uniques:  201
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['YesEuro 6' nan 'Yes109 g CO2/km (comb)' 'Yes98 g CO2/km (comb)'
#  'Yes97 g CO2/km (comb)' 'Yes112 g CO2/km (comb)' 'Yes0 kWh/100 km (comb)'
#  'Yes104 g CO2/km (comb)' 'Yes102 g CO2/km (comb)' 'Yes91 g CO2/km (comb)'
#  'Yes4.4 l/100 km (comb)5.2 l/100 km (city)3.9 l/100 km (country)'
#  'Yes99 g CO2/km (comb)' 'Yes' 'Yes92 g CO2/km (comb)'
#  'Yes5 l/100 km (comb)6.2 l/100 km (city)4.3 l/100 km (country)'
#  'Yes103 g CO2/km (comb)'
#  'Yes4.9 l/100 km (comb)6.2 l/100 km (city)4.2 l/100 km (country)'
#  'Yes107 g CO2/km (comb)'
#  'Yes4.4 l/100 km (comb)5.4 l/100 km (city)3.8 l/100 km (country)'
#  'Yes4.6 l/100 km (comb)5.6 l/100 km (city)4 l/100 km (country)'
#  'Yes121 g CO2/km (comb)' 'Yes123 g CO2/km (comb)'
#  'Yes113 g CO2/km (comb)'
#  'Yes4.7 l/100 km (comb)5.8 l/100 km (city)4.1 l/100 km (country)'
#  'Yes106 g CO2/km (comb)' 'Yes117 g CO2/km (comb)'
#  'Yes118 g CO2/km (comb)' 'YesEuro 4'
#  'Yes4.2 l/100 km (comb)5 l/100 km (city)3.7 l/100 km (country)'
#  'Yes115 g CO2/km (comb)' 'Yes4 (Green)'
#  'Yes5.6 l/100 km (comb)7.1 l/100 km (city)4.7 l/100 km (country)'
#  'Yes4.5 l/100 km (comb)5.5 l/100 km (city)3.9 l/100 km (country)'
#  'Yes111 g CO2/km (comb)' 'Yes114 g CO2/km (comb)' 'Yes90 g CO2/km (comb)'
#  'Yes108 g CO2/km (comb)' 'Yes105 g CO2/km (comb)'
#  'Yes129 g CO2/km (comb)' 'Yes134 g CO2/km (comb)'
#  'Yes110 g CO2/km (comb)' 'YesEuro 6d-TEMP' 'Yes122 g CO2/km (comb)'
#  'Yes4.8 l/100 km (comb)5.9 l/100 km (city)4.1 l/100 km (country)'
#  'Yes116 g CO2/km (comb)'
#  'Yes4.9 l/100 km (comb)5.9 l/100 km (city)4.3 l/100 km (country)'
#  'Yes136 g CO2/km (comb)'
#  'Yes4.7 l/100 km (comb)5.9 l/100 km (city)4 l/100 km (country)'
#  'Yes4.9 l/100 km (comb)6 l/100 km (city)4.2 l/100 km (country)'
#  'Yes120 g CO2/km (comb)' 'Yes119 g CO2/km (comb)'
#  'Yes5.9 l/100 km (comb)7.6 l/100 km (city)5.1 l/100 km (country)'
#  'Yes5 l/100 km (comb)6.3 l/100 km (city)4.2 l/100 km (country)'
#  'Yes5 l/100 km (comb)6.4 l/100 km (city)4.2 l/100 km (country)'
#  'Yes6.2 l/100 km (comb)7.8 l/100 km (city)5.3 l/100 km (country)'
#  'Yes168 g CO2/km (comb)' 'Yes161 g CO2/km (comb)'
#  'Yes153 g CO2/km (comb)' 'Yes191 g CO2/km (comb)'
#  'Yes172 g CO2/km (comb)']
# ----------------------------------------
# Yes                         442
# Yes0 kWh/100 km (comb)       86
# Yes1 (No sticker)             1
# Yes100 g CO2/km (comb)        1
# Yes101 g CO2/km (comb)       25
#                           ...
# YesEuro 6                   523
# YesEuro 6c                    5
# YesEuro 6d                   24
# YesEuro 6d-TEMP             134
# NaN                       11987
# Name: inspection_new, Length: 202, dtype: int64
# ----------------------------------------
# NaN                                                                11987
# YesEuro 6                                                            523
# Yes                                                                  442
# Yes102 g CO2/km (comb)                                               174
# Yes4 (Green)                                                         166
#                                                                    ...
# Yes5.2 l/100 km (comb)6.7 l/100 km (city)4.2 l/100 km (country)        1
# Yes100 g CO2/km (comb)                                                 1
# Yes4.9 l/100 km (comb)5.9 l/100 km (city)4.3 l/100 km (country)        1
# Yes5.1 l/100 km (comb)6.4 l/100 km (city)4.3 l/100 km (country)        1
# Yes172 g CO2/km (comb)                                                 1
# Name: inspection_new, Length: 202, dtype: int64
# ################################################################################

# %%
df["inspection_situation"] = df["inspection_new"].apply(lambda x: 1 if "Yes" in str(x) else 0)
df["inspection_situation"].value_counts()
# Out:
# 0    11987
# 1     3932
# Name: inspection_situation, dtype: int64

# %%
first_look("inspection_situation")
# Out:
# column name :  inspection_situation
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  2
# Type of columns:  int64
# ----------------------------------------
# Unique values of columns:  [1 0]
# ----------------------------------------
# 0    11987
# 1     3932
# Name: inspection_situation, dtype: int64
# ----------------------------------------
# 0    11987
# 1     3932
# Name: inspection_situation, dtype: int64
# ################################################################################

# %%
#looking for the null values of inspection_situation in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["inspection_situation"].isnull()][i].str.contains("Yes").any():
        print(i)
#There is no column to get values

# %% [markdown]
# ### warranty

# %%
first_look("warranty")
# Out:
# column name :  warranty
# ----------------------------------------
# Per_of_Nulls   :  % 34.05
# Number of Nulls  :  5420
# Number of Uniques:  506
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['4 (Green)' nan '99 g CO2/km (comb)' 'Euro 6' '12 monthsEuro 6'
#  '3 months' '12 months' '6 months103 g CO2/km (comb)' ''
#  '12 months105 g CO2/km (comb)' '12 months112 g CO2/km (comb)'
#  '12 months97 g CO2/km (comb)' '12 months104 g CO2/km (comb)' '24 months'
#  '12 months102 g CO2/km (comb)' '97 g CO2/km (comb)' '50 months4 (Green)'
#  '12 months106 g CO2/km (comb)' '48 months' '107 g CO2/km (comb)'
#  '108 g CO2/km (comb)' '113 g CO2/km (comb)' '102 g CO2/km (comb)'
#  '112 g CO2/km (comb)' '36 months99 g CO2/km (comb)' '109 g CO2/km (comb)'
#  '20 months4 (Green)' '12 months99 g CO2/km (comb)' '106 g CO2/km (comb)'
#  '36 monthsEuro 6' '12 months109 g CO2/km (comb)' '100 g CO2/km (comb)'
#  '12 months0 kWh/100 km (comb)' '12 months101 g CO2/km (comb)'
#  '4.9 l/100 km (comb)6.2 l/100 km (city)4.2 l/100 km (country)'
#  '123 g CO2/km (comb)' '104 g CO2/km (comb)'
#  '12 months107 g CO2/km (comb)' '24 monthsEuro 6' '92 g CO2/km (comb)'
#  '94 g CO2/km (comb)' '6 months' '3 months99 g CO2/km (comb)'
#  '12 months121 g CO2/km (comb)' '23 monthsEuro 6' '12 monthsEuro 6c'
#  '12 months103 g CO2/km (comb)' '12 months91 g CO2/km (comb)'
#  '12 months4 (Green)' '60 months97 g CO2/km (comb)' '12 monthsEuro 5'
#  '60 months91 g CO2/km (comb)' '12 months114 g CO2/km (comb)'
#  '91 g CO2/km (comb)' '115 g CO2/km (comb)' '12 months98 g CO2/km (comb)'
#  '24 months108 g CO2/km (comb)' '12 months90 g CO2/km (comb)'
#  '6 months97 g CO2/km (comb)' '36 months108 g CO2/km (comb)' '36 months'
#  '12 months94 g CO2/km (comb)' '24 months97 g CO2/km (comb)'
#  '24 months102 g CO2/km (comb)' '12 months95 g CO2/km (comb)'
#  '12 months100 g CO2/km (comb)' '36 months136 g CO2/km (comb)'
#  '36 months102 g CO2/km (comb)' '116 g CO2/km (comb)' '23 months4 (Green)'
#  '103 g CO2/km (comb)' '60 months102 g CO2/km (comb)'
#  '110 g CO2/km (comb)' '1 (No sticker)' '12 months129 g CO2/km (comb)'
#  '36 months105 g CO2/km (comb)' '36 months4 (Green)' '48 monthsEuro 6'
#  '24 months112 g CO2/km (comb)' '36 months104 g CO2/km (comb)'
#  '12 months113 g CO2/km (comb)' 'Euro 5' '13 months104 g CO2/km (comb)'
#  'Euro 6d-TEMP' '24 months104 g CO2/km (comb)'
#  '36 months97 g CO2/km (comb)' '24 months98 g CO2/km (comb)' '60 months'
#  '48 months98 g CO2/km (comb)' '48 months4 (Green)' '120 g CO2/km (comb)'
#  '36 months98 g CO2/km (comb)' '24 months4 (Green)' '26 months4 (Green)'
#  '60 monthsEuro 6'
#  '4.4 l/100 km (comb)5.2 l/100 km (city)3.9 l/100 km (country)'
#  '46 months4 (Green)' '47 months4 (Green)' '49 months4 (Green)'
#  '89 g CO2/km (comb)' '24 months111 g CO2/km (comb)' '105 g CO2/km (comb)'
#  '111 g CO2/km (comb)' '117 g CO2/km (comb)'
#  '36 months111 g CO2/km (comb)' '48 months108 g CO2/km (comb)'
#  '24 months110 g CO2/km (comb)'
#  '36 months6 l/100 km (comb)8.2 l/100 km (city)4.8 l/100 km (country)'
#  '12 months110 g CO2/km (comb)' '12 months108 g CO2/km (comb)'
#  '36 months110 g CO2/km (comb)' '18 months' '24 months116 g CO2/km (comb)'
#  '60 months111 g CO2/km (comb)' '60 months104 g CO2/km (comb)'
#  '24 months114 g CO2/km (comb)'
#  '4.7 l/100 km (comb)5.9 l/100 km (city)4 l/100 km (country)'
#  '48 months104 g CO2/km (comb)' '138 g CO2/km (comb)'
#  '36 months6 l/100 km (comb)8.2 l/100 km (city)4.7 l/100 km (country)'
#  '128 g CO2/km (comb)'
#  '4.9 l/100 km (comb)6 l/100 km (city)4.2 l/100 km (country)'
#  '60 months105 g CO2/km (comb)' '24 months105 g CO2/km (comb)'
#  '24 months106 g CO2/km (comb)' '24 monthsEuro 6d-TEMP'
#  '60 months108 g CO2/km (comb)' '98 g CO2/km (comb)' '56 months4 (Green)'
#  '16 months116 g CO2/km (comb)' '119 g CO2/km (comb)'
#  '12 months119 g CO2/km (comb)' ',,,Diesel' '24 months99 g CO2/km (comb)'
#  '6 months99 g CO2/km (comb)' '3 months116 g CO2/km (comb)'
#  '12 months118 g CO2/km (comb)' '12 months126 g CO2/km (comb)'
#  '12 months116 g CO2/km (comb)' '12 months89 g CO2/km (comb)'
#  '101 g CO2/km (comb)' '26 monthsEuro 6' '24 months103 g CO2/km (comb)'
#  '36 months114 g CO2/km (comb)' '127 g CO2/km (comb)'
#  '24 months189 g CO2/km (comb)' '24 months115 g CO2/km (comb)'
#  '46 months112 g CO2/km (comb)' '24 months113 g CO2/km (comb)'
#  '12 months117 g CO2/km (comb)' '12 months5 (Blue)' '124 g CO2/km (comb)'
#  '60 months4 (Green)' '22 months105 g CO2/km (comb)'
#  '36 months103 g CO2/km (comb)' '118 g CO2/km (comb)'
#  '28 months106 g CO2/km (comb)' '60 months98 g CO2/km (comb)'
#  '10 months104 g CO2/km (comb)' '22 months106 g CO2/km (comb)'
#  '12 months111 g CO2/km (comb)' 'Euro 6d' '114 g CO2/km (comb)'
#  '6 months108 g CO2/km (comb)' '6 months98 g CO2/km (comb)'
#  '60 months106 g CO2/km (comb)' '125 g CO2/km (comb)'
#  '48 months117 g CO2/km (comb)' '24 months107 g CO2/km (comb)'
#  '18 months106 g CO2/km (comb)' '60 months107 g CO2/km (comb)'
#  '24 months134 g CO2/km (comb)' '19 months106 g CO2/km (comb)'
#  '25 months104 g CO2/km (comb)' '18 months120 g CO2/km (comb)'
#  '146 g CO2/km (comb)' '36 months117 g CO2/km (comb)'
#  '36 months119 g CO2/km (comb)' '11 months117 g CO2/km (comb)' '19 months'
#  '24 months117 g CO2/km (comb)' '48 months103 g CO2/km (comb)'
#  '48 months101 g CO2/km (comb)' '24 months0 kWh/100 km (comb)'
#  '48 months114 g CO2/km (comb)' '24 months1 (No sticker)' '72 months'
#  '36 months142 g CO2/km (comb)' '24 months118 g CO2/km (comb)'
#  '36 months107 g CO2/km (comb)' '135 g CO2/km (comb)'
#  '36 months112 g CO2/km (comb)'
#  '36 months5.5 l/100 km (comb)6.9 l/100 km (city)4.6 l/100 km (country)'
#  '36 months124 g CO2/km (comb)' '60 months124 g CO2/km (comb)'
#  '60 months116 g CO2/km (comb)' '60 months121 g CO2/km (comb)'
#  '60 months119 g CO2/km (comb)' '12 months127 g CO2/km (comb)'
#  '60 months5.6 l/100 km (comb)7.3 l/100 km (city)4.5 l/100 km (country)'
#  '60 months5.1 l/100 km (comb)6.3 l/100 km (city)4.3 l/100 km (country)'
#  '12 months124 g CO2/km (comb)' '6 monthsEuro 6' '122 g CO2/km (comb)'
#  '12 months128 g CO2/km (comb)'
#  '60 months4.9 l/100 km (comb)6.2 l/100 km (city)4.2 l/100 km (country)'
#  '12,087 g CO2/km (comb)' '24 months119 g CO2/km (comb)'
#  '23 months119 g CO2/km (comb)' '24 months127 g CO2/km (comb)'
#  '24 months130 g CO2/km (comb)' '60 months154 g CO2/km (comb)'
#  '60 months4.3 l/100 km (comb)5.1 l/100 km (city)3.8 l/100 km (country)'
#  '60 months152 g CO2/km (comb)' '36 months115 g CO2/km (comb)'
#  '60 months127 g CO2/km (comb)' '96 g CO2/km (comb)'
#  '12 months130 g CO2/km (comb)' '24 months88 g CO2/km (comb)'
#  '6 months94 g CO2/km (comb)' '12 months158 g CO2/km (comb)'
#  '36 months92 g CO2/km (comb)' '12 monthsEuro 6d-TEMP'
#  '12 months133 g CO2/km (comb)' '60 months149 g CO2/km (comb)'
#  '12 months93 g CO2/km (comb)' '60 months92 g CO2/km (comb)'
#  '12 months115 g CO2/km (comb)' '12 months92 g CO2/km (comb)' 'Euro 6c'
#  '12 months1 (No sticker)'
#  '4.3 l/100 km (comb)5.2 l/100 km (city)3.8 l/100 km (country)'
#  '5.4 l/100 km (comb)7.1 l/100 km (city)4.4 l/100 km (country)'
#  '60 months5.4 l/100 km (comb)7.1 l/100 km (city)4.4 l/100 km (country)'
#  '60 months128 g CO2/km (comb)' '60 months135 g CO2/km (comb)'
#  '23 months97 g CO2/km (comb)' '24 months95 g CO2/km (comb)'
#  '6 months93 g CO2/km (comb)' '95 g CO2/km (comb)' '129 g CO2/km (comb)'
#  '20 monthsEuro 6' '12 months122 g CO2/km (comb)'
#  '24 months4.5 l/100 km (comb)5.7 l/100 km (city)3.8 l/100 km (country)'
#  '60 months130 g CO2/km (comb)' '121 g CO2/km (comb)'
#  '130 g CO2/km (comb)' '60 months114 g CO2/km (comb)'
#  '24 months4.7 l/100 km (comb)5.4 l/100 km (city)4.2 l/100 km (country)'
#  '6 months92 g CO2/km (comb)' '60 months123 g CO2/km (comb)'
#  '24 months146 g CO2/km (comb)' '24 months133 g CO2/km (comb)' '28 months'
#  '60 months4.5 l/100 km (comb)5.4 l/100 km (city)4 l/100 km (country)'
#  '93 g CO2/km (comb)' '25 monthsEuro 6'
#  '4.3 l/100 km (comb)5.1 l/100 km (city)3.8 l/100 km (country)'
#  '60 months115 g CO2/km (comb)' '126 g CO2/km (comb)'
#  '139 g CO2/km (comb)' '60 monthsEuro 6d-TEMP' '154 g CO2/km (comb)'
#  '134 g CO2/km (comb)' '72 months138 g CO2/km (comb)'
#  '151 g CO2/km (comb)' '72 months149 g CO2/km (comb)'
#  '72 months139 g CO2/km (comb)'
#  '24 months6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)'
#  '36 monthsEuro 6d-TEMP'
#  '60 months6.4 l/100 km (comb)8.3 l/100 km (city)5.3 l/100 km (country)'
#  '60 months146 g CO2/km (comb)' '24 months125 g CO2/km (comb)'
#  '141 g CO2/km (comb)' '60 months134 g CO2/km (comb)'
#  '24 months5.6 l/100 km (comb)7.3 l/100 km (city)4.6 l/100 km (country)'
#  '24 months135 g CO2/km (comb)'
#  '5.6 l/100 km (comb)7.3 l/100 km (city)4.6 l/100 km (country)'
#  '12 months134 g CO2/km (comb)' '60 months144 g CO2/km (comb)'
#  '72 monthsEuro 6d-TEMP' '72 months151 g CO2/km (comb)'
#  '24 months124 g CO2/km (comb)' '24 months129 g CO2/km (comb)'
#  '36 months127 g CO2/km (comb)' '60 months139 g CO2/km (comb)'
#  '3 months107 g CO2/km (comb)' '60 months125 g CO2/km (comb)'
#  '149 g CO2/km (comb)' '72 months129 g CO2/km (comb)'
#  '72 months116 g CO2/km (comb)' '72 months102 g CO2/km (comb)'
#  '72 months107 g CO2/km (comb)' '72 months115 g CO2/km (comb)'
#  '60 monthsEuro 6d' '60 months110 g CO2/km (comb)'
#  '72 months114 g CO2/km (comb)' '2 months' '133 g CO2/km (comb)'
#  '72 months125 g CO2/km (comb)' '60 months14 g CO2/km (comb)'
#  '24 months121 g CO2/km (comb)' '12 monthsEuro 6d'
#  '4.7 l/100 km (comb)5.5 l/100 km (city)4.1 l/100 km (country)'
#  '60 months133 g CO2/km (comb)' '140 g CO2/km (comb)'
#  '137 g CO2/km (comb)'
#  '12 months6.3 l/100 km (comb)7.8 l/100 km (city)5.4 l/100 km (country)'
#  '142 g CO2/km (comb)' '150 g CO2/km (comb)' '1 monthsEuro 6'
#  '60 months6.6 l/100 km (comb)8.2 l/100 km (city)5.7 l/100 km (country)'
#  '136 g CO2/km (comb)' '12 months149 g CO2/km (comb)'
#  '12 months140 g CO2/km (comb)' '60 months137 g CO2/km (comb)'
#  '12 months123 g CO2/km (comb)'
#  '5.9 l/100 km (comb)7.5 l/100 km (city)5 l/100 km (country)'
#  '6 months110 g CO2/km (comb)' '12 months137 g CO2/km (comb)'
#  '20 months142 g CO2/km (comb)' '12 months12,324 g CO2/km (comb)'
#  '2 months4 (Green)' '12 months82 g CO2/km (comb)'
#  '24 months139 g CO2/km (comb)' '12 months132 g CO2/km (comb)'
#  '60 months5.4 l/100 km (comb)6.7 l/100 km (city)4.6 l/100 km (country)'
#  '12 months120 g CO2/km (comb)' '12 months87 g CO2/km (comb)'
#  '60 months126 g CO2/km (comb)' '60 months142 g CO2/km (comb)'
#  '24 months140 g CO2/km (comb)' '60 months5.4 l/100 km (comb)'
#  '143 g CO2/km (comb)' '132 g CO2/km (comb)'
#  '24 months120 g CO2/km (comb)'
#  '60 months5.2 l/100 km (comb)6.6 l/100 km (city)4.4 l/100 km (country)'
#  '3 months110 g CO2/km (comb)'
#  '60 months5.2 l/100 km (comb)6.8 l/100 km (city)4.3 l/100 km (country)'
#  '60 months5.1 l/100 km (comb)6.7 l/100 km (city)4.2 l/100 km (country)'
#  '60 months120 g CO2/km (comb)' '48 months120 g CO2/km (comb)'
#  '24 monthsEuro 6d' '12 months143 g CO2/km (comb)' '153 g CO2/km (comb)'
#  '6 l/100 km (comb)7.8 l/100 km (city)4.9 l/100 km (country)'
#  '131 g CO2/km (comb)' '12 months51 g CO2/km (comb)'
#  '5.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '157 g CO2/km (comb)' '24 months142 g CO2/km (comb)'
#  '24 months157 g CO2/km (comb)' '24 months143 g CO2/km (comb)'
#  '6.3 l/100 km (comb)7.8 l/100 km (city)5.4 l/100 km (country)'
#  '72 months142 g CO2/km (comb)' '60 months143 g CO2/km (comb)'
#  '24 months150 g CO2/km (comb)' '24 months132 g CO2/km (comb)'
#  '24 months6 l/100 km (comb)7.8 l/100 km (city)4.9 l/100 km (country)'
#  '60 months150 g CO2/km (comb)' '24 months136 g CO2/km (comb)'
#  '158 g CO2/km (comb)' '36 months150 g CO2/km (comb)'
#  '155 g CO2/km (comb)'
#  '60 months5.6 l/100 km (comb)7.2 l/100 km (city)4.8 l/100 km (country)'
#  '72 months133 g CO2/km (comb)'
#  '72 months5.6 l/100 km (comb)7 l/100 km (city)4.8 l/100 km (country)'
#  '12 months5.6 l/100 km (comb)7.2 l/100 km (city)4.7 l/100 km (country)'
#  '24 months126 g CO2/km (comb)' '4 months' '60 months145 g CO2/km (comb)'
#  '60 months141 g CO2/km (comb)' '145 g CO2/km (comb)'
#  '12 months135 g CO2/km (comb)' '175 g CO2/km (comb)'
#  '2 months149 g CO2/km (comb)' '8 months' '12 months145 g CO2/km (comb)'
#  '12 months146 g CO2/km (comb)' '12 months0 g CO2/km (comb)'
#  '12 months170 g CO2/km (comb)' '24 months161 g CO2/km (comb)'
#  '12 months138 g CO2/km (comb)' '12 months147 g CO2/km (comb)'
#  '12 months169 g CO2/km (comb)' '6 months104 g CO2/km (comb)' 'Euro 4'
#  '60 months103 g CO2/km (comb)' '2 monthsEuro 6'
#  '24 months109 g CO2/km (comb)'
#  '60 months5.6 l/100 km (comb)7.6 l/100 km (city)4.4 l/100 km (country)'
#  '6 months109 g CO2/km (comb)' '144 g CO2/km (comb)' '24 months5 (Blue)'
#  '12 months148 g CO2/km (comb)' '12 months141 g CO2/km (comb)'
#  '60 months166 g CO2/km (comb)' '16 monthsEuro 6'
#  '12 months6.1 l/100 km (comb)7.5 l/100 km (city)5.3 l/100 km (country)'
#  '7 months134 g CO2/km (comb)' '60 monthsEuro 6c'
#  '12 months139 g CO2/km (comb)' '12 months136 g CO2/km (comb)'
#  '60 months5.9 l/100 km (comb)7.5 l/100 km (city)4.9 l/100 km (country)'
#  '12 months150 g CO2/km (comb)' '147 g CO2/km (comb)'
#  '148 g CO2/km (comb)' '60 months138 g CO2/km (comb)'
#  '18 months141 g CO2/km (comb)'
#  '60 months6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)'
#  '60 months6.2 l/100 km (comb)7.6 l/100 km (city)5.4 l/100 km (country)'
#  '12 months14,457 g CO2/km (comb)'
#  '60 months6.1 l/100 km (comb)7.5 l/100 km (city)5.3 l/100 km (country)'
#  '60 months6 l/100 km (comb)7.3 l/100 km (city)5.2 l/100 km (country)'
#  '199 g CO2/km (comb)' '60 months148 g CO2/km (comb)'
#  '60 months5.8 l/100 km (comb)7.5 l/100 km (city)4.9 l/100 km (country)'
#  '18 monthsEuro 6'
#  '60 months5.7 l/100 km (comb)7.3 l/100 km (city)4.8 l/100 km (country)'
#  '18 months129 g CO2/km (comb)' '15 months132 g CO2/km (comb)' '13 months'
#  '12 months5.9 l/100 km (comb)7.5 l/100 km (city)4.9 l/100 km (country)'
#  '24 months141 g CO2/km (comb)' '24 months147 g CO2/km (comb)'
#  '187 g CO2/km (comb)' '24 months187 g CO2/km (comb)'
#  '24 months145 g CO2/km (comb)' '24 months151 g CO2/km (comb)'
#  '72 months143 g CO2/km (comb)' '72 months4 (Green)'
#  '6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)'
#  '6.7 l/100 km (comb)8.6 l/100 km (city)5.6 l/100 km (country)'
#  '156 g CO2/km (comb)' '72 months140 g CO2/km (comb)'
#  '12 months6.7 l/100 km (comb)8.6 l/100 km (city)5.6 l/100 km (country)'
#  '12 months151 g CO2/km (comb)' '197 g CO2/km (comb)'
#  '72 months154 g CO2/km (comb)' '45 g CO2/km (comb)'
#  '72 months197 g CO2/km (comb)'
#  '24 months6.4 l/100 km (comb)8.1 l/100 km (city)5.4 l/100 km (country)'
#  '171 g CO2/km (comb)' '172 g CO2/km (comb)'
#  '72 months6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)'
#  '72 months130 g CO2/km (comb)' '164 g CO2/km (comb)'
#  '60 months6.2 l/100 km (comb)7.9 l/100 km (city)5.2 l/100 km (country)'
#  '72 months156 g CO2/km (comb)' '3 months128 g CO2/km (comb)'
#  '161 g CO2/km (comb)' '24 months128 g CO2/km (comb)'
#  '20 months139 g CO2/km (comb)'
#  '72 months6 l/100 km (comb)7.3 l/100 km (city)5.2 l/100 km (country)'
#  '6 l/100 km (comb)7.3 l/100 km (city)5.2 l/100 km (country)'
#  '3 months146 g CO2/km (comb)' '3 monthsEuro 6'
#  '48 months92 g CO2/km (comb)' '5 (Blue)' '24 months85 g CO2/km (comb)'
#  '12 months85 g CO2/km (comb)' '3 months85 g CO2/km (comb)'
#  '6 months105 g CO2/km (comb)' '85 g CO2/km (comb)'
#  '6 months85 g CO2/km (comb)' '17 monthsEuro 6'
#  '36 months85 g CO2/km (comb)' '6 months120 g CO2/km (comb)'
#  '24 months92 g CO2/km (comb)' '36 monthsEuro 6d'
#  '60 months113 g CO2/km (comb)' '45 monthsEuro 6'
#  '16 months135 g CO2/km (comb)' '14 months135 g CO2/km (comb)'
#  '17 months105 g CO2/km (comb)' '9 months' '48 months113 g CO2/km (comb)'
#  '60 months118 g CO2/km (comb)' '23 months' '65 months118 g CO2/km (comb)'
#  '5 l/100 km (comb)6.3 l/100 km (city)4.2 l/100 km (country)'
#  '21 months140 g CO2/km (comb)' '21 months120 g CO2/km (comb)'
#  '34 monthsEuro 6' '33 monthsEuro 6' '14 months120 g CO2/km (comb)'
#  '40 months' '6 months140 g CO2/km (comb)' '1 months'
#  '48 months139 g CO2/km (comb)' '188 g CO2/km (comb)'
#  '48 months142 g CO2/km (comb)' '11 monthsEuro 6' '34 months'
#  '60 months153 g CO2/km (comb)' '30 months' '168 g CO2/km (comb)'
#  '16 months152 g CO2/km (comb)' '45 months168 g CO2/km (comb)'
#  '152 g CO2/km (comb)' '26 months' '25 months'
#  '12 months125 g CO2/km (comb)' '20 months120 g CO2/km (comb)'
#  '174 g CO2/km (comb)' '24 months152 g CO2/km (comb)'
#  '36 months7.4 l/100 km (comb)9.6 l/100 km (city)6 l/100 km (country)']
# ----------------------------------------
#                   1343
# ,,,Diesel            1
# 1 (No sticker)      17
# 1 months             1
# 1 monthsEuro 6       2
#                   ...
# Euro 6            1868
# Euro 6c             21
# Euro 6d             11
# Euro 6d-TEMP       362
# NaN               5420
# Name: warranty, Length: 507, dtype: int64
# ----------------------------------------
# NaN                                                                    5420
# Euro 6                                                                 1868
#                                                                        1343
# 12 months                                                              1305
# 24 months                                                               585
#                                                                        ...
# 2 months                                                                  1
# 72 months125 g CO2/km (comb)                                              1
# 60 months14 g CO2/km (comb)                                               1
# 24 months121 g CO2/km (comb)                                              1
# 36 months7.4 l/100 km (comb)9.6 l/100 km (city)6 l/100 km (country)       1
# Name: warranty, Length: 507, dtype: int64
# ################################################################################

# %%
df["warranty_month"] = df["warranty"].str.extract("(\d+) month").astype(float)

# %%
#looking for the null values of inspection_situation in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["warranty_month"].isnull()][i].str.contains("month").any():
        print(i)
#There is no column to get values

# %%
first_look("warranty_month")
# Out:
# column name :  warranty_month
# ----------------------------------------
# Per_of_Nulls   :  % 69.51
# Number of Nulls  :  11066
# Number of Uniques:  41
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [nan 12.  3.  6. 24. 50. 48. 36. 20. 23. 60. 13. 26. 46. 47. 49. 18. 56.
#  16. 22. 28. 10. 19. 25. 11. 72.  2.  1.  4.  8.  7. 15. 17. 45. 14.  9.
#  65. 21. 34. 33. 40. 30.]
# ----------------------------------------
# 1.0         3
# 2.0         5
# 3.0        33
# 4.0         3
# 6.0       125
# 7.0         1
# 8.0         1
# 9.0         2
# 10.0        1
# 11.0        2
# 12.0     2594
# 13.0        3
# 14.0        2
# 15.0        1
# 16.0        4
# 17.0        2
# 18.0       10
# 19.0        3
# 20.0        7
# 21.0        2
# 22.0        2
# 23.0       11
# 24.0     1118
# 25.0        6
# 26.0        4
# 28.0        2
# 30.0        1
# 33.0        1
# 34.0        3
# 36.0      279
# 40.0        1
# 45.0        2
# 46.0        2
# 47.0        1
# 48.0      149
# 49.0        1
# 50.0        4
# 56.0        1
# 60.0      401
# 65.0        1
# 72.0       59
# NaN     11066
# Name: warranty_month, dtype: int64
# ----------------------------------------
# NaN     11066
# 12.0     2594
# 24.0     1118
# 60.0      401
# 36.0      279
# 48.0      149
# 6.0       125
# 72.0       59
# 3.0        33
# 23.0       11
# 18.0       10
# 20.0        7
# 25.0        6
# 2.0         5
# 50.0        4
# 26.0        4
# 16.0        4
# 4.0         3
# 1.0         3
# 19.0        3
# 34.0        3
# 13.0        3
# 28.0        2
# 22.0        2
# 14.0        2
# 11.0        2
# 46.0        2
# 21.0        2
# 9.0         2
# 17.0        2
# 45.0        2
# 33.0        1
# 40.0        1
# 65.0        1
# 10.0        1
# 15.0        1
# 7.0         1
# 8.0         1
# 56.0        1
# 49.0        1
# 47.0        1
# 30.0        1
# Name: warranty_month, dtype: int64
# ################################################################################

# %% [markdown]
# ### co_2_emission

# %%
first_look("co_2_emission")
# Out:
# column name :  co_2_emission
# ----------------------------------------
# Per_of_Nulls   :  % 11.36
# Number of Nulls  :  1808
# Number of Uniques:  123
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['99 g CO2/km (comb)' '129 g CO2/km (comb)' '109 g CO2/km (comb)'
#  '92 g CO2/km (comb)' '98 g CO2/km (comb)' '97 g CO2/km (comb)' nan
#  '105 g CO2/km (comb)' '112 g CO2/km (comb)' '103 g CO2/km (comb)'
#  '102 g CO2/km (comb)' '95 g CO2/km (comb)' '104 g CO2/km (comb)'
#  '[],[],[]' '91 g CO2/km (comb)' '94 g CO2/km (comb)'
#  '117 g CO2/km (comb)' '123 g CO2/km (comb)' '106 g CO2/km (comb)'
#  '108 g CO2/km (comb)' '121 g CO2/km (comb)' '107 g CO2/km (comb)'
#  '101 g CO2/km (comb)' '113 g CO2/km (comb)' '137 g CO2/km (comb)'
#  '100 g CO2/km (comb)' '116 g CO2/km (comb)' '114 g CO2/km (comb)'
#  '118 g CO2/km (comb)' '331 g CO2/km (comb)' '115 g CO2/km (comb)'
#  '119 g CO2/km (comb)' '90 g CO2/km (comb)' '136 g CO2/km (comb)'
#  '134 g CO2/km (comb)' '110 g CO2/km (comb)' '111 g CO2/km (comb)'
#  '120 g CO2/km (comb)' '89 g CO2/km (comb)' '142 g CO2/km (comb)'
#  '126 g CO2/km (comb)' '122 g CO2/km (comb)' '128 g CO2/km (comb)'
#  '127 g CO2/km (comb)' '138 g CO2/km (comb)' '130 g CO2/km (comb)'
#  '125 g CO2/km (comb)' '85 g CO2/km (comb)' '124 g CO2/km (comb)'
#  '152 g CO2/km (comb)' '88 g CO2/km (comb)' '189 g CO2/km (comb)'
#  '194 g CO2/km (comb)' '149 g CO2/km (comb)' '153 g CO2/km (comb)'
#  '188 g CO2/km (comb)' '36 g CO2/km (comb)' '1,060 g CO2/km (comb)'
#  '96 g CO2/km (comb)' '990 g CO2/km (comb)' '146 g CO2/km (comb)'
#  '135 g CO2/km (comb)' '158 g CO2/km (comb)' '12,087 g CO2/km (comb)'
#  '141 g CO2/km (comb)' '172 g CO2/km (comb)' '154 g CO2/km (comb)'
#  '150 g CO2/km (comb)' '167 g CO2/km (comb)' '174 g CO2/km (comb)'
#  '93 g CO2/km (comb)' '133 g CO2/km (comb)' '131 g CO2/km (comb)'
#  '145 g CO2/km (comb)' '147 g CO2/km (comb)' '156 g CO2/km (comb)'
#  '87 g CO2/km (comb)' '5 g CO2/km (comb)' '148 g CO2/km (comb)'
#  '139 g CO2/km (comb)' '151 g CO2/km (comb)' '144 g CO2/km (comb)'
#  '168 g CO2/km (comb)' '160 g CO2/km (comb)' '170 g CO2/km (comb)'
#  '80 g CO2/km (comb)' '132 g CO2/km (comb)' '155 g CO2/km (comb)'
#  '14 g CO2/km (comb)' '159 g CO2/km (comb)' '0 g CO2/km (comb)'
#  '143 g CO2/km (comb)' '140 g CO2/km (comb)' '82 g CO2/km (comb)'
#  '12,324 g CO2/km (comb)' '84 g CO2/km (comb)' '165 g CO2/km (comb)'
#  '51 g CO2/km (comb)' '157 g CO2/km (comb)' '169 g CO2/km (comb)'
#  '166 g CO2/km (comb)' '253 g CO2/km (comb)' '164 g CO2/km (comb)'
#  '175 g CO2/km (comb)' '190 g CO2/km (comb)' '161 g CO2/km (comb)'
#  '239 g CO2/km (comb)' '197 g CO2/km (comb)' '184 g CO2/km (comb)'
#  '14,457 g CO2/km (comb)' '199 g CO2/km (comb)' '13,983 g CO2/km (comb)'
#  '187 g CO2/km (comb)' '181 g CO2/km (comb)' '186 g CO2/km (comb)'
#  '177 g CO2/km (comb)' '180 g CO2/km (comb)' '162 g CO2/km (comb)'
#  '45 g CO2/km (comb)' '171 g CO2/km (comb)' '183 g CO2/km (comb)'
#  '1 g CO2/km (comb)' '191 g CO2/km (comb)' '193 g CO2/km (comb)']
# ----------------------------------------
# 0 g CO2/km (comb)           2
# 1 g CO2/km (comb)           1
# 1,060 g CO2/km (comb)       1
# 100 g CO2/km (comb)        36
# 101 g CO2/km (comb)       105
#                          ...
# 98 g CO2/km (comb)        151
# 99 g CO2/km (comb)        545
# 990 g CO2/km (comb)         1
# [],[],[]                  628
# NaN                      1808
# Name: co_2_emission, Length: 124, dtype: int64
# ----------------------------------------
# NaN                      1808
# 120 g CO2/km (comb)       740
# [],[],[]                  628
# 99 g CO2/km (comb)        545
# 97 g CO2/km (comb)        537
#                          ...
# 14 g CO2/km (comb)          1
# 1,060 g CO2/km (comb)       1
# 51 g CO2/km (comb)          1
# 165 g CO2/km (comb)         1
# 193 g CO2/km (comb)         1
# Name: co_2_emission, Length: 124, dtype: int64
# ################################################################################

# %%
df["co2_emission_gr"] = df["co_2_emission"].str.extract("(.*) g")[0].str.replace(",",".").astype(float)

# %%
first_look("co2_emission_gr")
# Out:
# column name :  co2_emission_gr
# ----------------------------------------
# Per_of_Nulls   :  % 15.3
# Number of Nulls  :  2436
# Number of Uniques:  122
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [ 99.    129.    109.     92.     98.     97.        nan 105.    112.
#  103.    102.     95.    104.     91.     94.    117.    123.    106.
#  108.    121.    107.    101.    113.    137.    100.    116.    114.
#  118.    331.    115.    119.     90.    136.    134.    110.    111.
#  120.     89.    142.    126.    122.    128.    127.    138.    130.
#  125.     85.    124.    152.     88.    189.    194.    149.    153.
#  188.     36.      1.06   96.    990.    146.    135.    158.     12.087
#  141.    172.    154.    150.    167.    174.     93.    133.    131.
#  145.    147.    156.     87.      5.    148.    139.    151.    144.
#  168.    160.    170.     80.    132.    155.     14.    159.      0.
#  143.    140.     82.     12.324  84.    165.     51.    157.    169.
#  166.    253.    164.    175.    190.    161.    239.    197.    184.
#   14.457 199.     13.983 187.    181.    186.    177.    180.    162.
#   45.    171.    183.      1.    191.    193.   ]
# ----------------------------------------
# 0.000         2
# 1.000         1
# 1.060         1
# 5.000         3
# 12.087        3
#            ...
# 239.000       1
# 253.000       1
# 331.000       1
# 990.000       1
# NaN        2436
# Name: co2_emission_gr, Length: 123, dtype: int64
# ----------------------------------------
# NaN       2436
# 120.00     740
# 99.00      545
# 97.00      537
# 104.00     501
#           ...
# 14.00        1
# 1.06         1
# 51.00        1
# 165.00       1
# 193.00       1
# Name: co2_emission_gr, Length: 123, dtype: int64
# ################################################################################

# %%
df[df["co2_emission_gr"].isnull()]
# Out:
#                                                      url      make_model  \
# 9      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 13     https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 30     https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 39     https://www.autoscout24.com//offers/audi-a1-89...         Audi A1
# 43     https://www.autoscout24.com//offers/audi-a1-89...         Audi A1
# ...                                                  ...             ...
# 15883  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15903  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15906  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15908  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15909  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 9                  SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.    Sedans  17990
# 13           1.4 TFSI 150ch COD Ambition Luxe S tronic 7    Sedans  18399
# 30                           Sportback 1.4TDI Attraction   Compact  11290
# 39     (€8950,-excl.VAT/Guarantee) SB 1.4 TDi Ultra Eur6   Compact  11630
# 43     (€8900,-excl.VAT/Guarantee) SB 1.4TDI Ultra Eu...   Compact  11569
# ...                                                  ...       ...    ...
# 15883                    RENAULT INITIALE BLUE DCI 200PS       Van  47950
# 15903               1.8 TCe 225ch FAP Initiale Paris EDC       Van  39990
# 15906                   V Tce 225 EDC FAP Initiale Paris       Van  39990
# 15908            1.8 TCe 225ch energy Initiale Paris EDC       Van  39990
# 15909                           Limited Blue dCi 200 EDC       Van  39990
#
#                   vat        km registration  prev_owner           type  \
# 9                None   16103.0   2017-06-01         NaN           Used
# 13               None   45764.0   2016-06-01         NaN           Used
# 30               None   38400.0   2016-06-01         NaN           Used
# 39     VAT deductible  110715.0   2016-01-01         1.0           Used
# 43     VAT deductible  111265.0   2016-03-01         1.0           Used
# ...               ...       ...          ...         ...            ...
# 15883            None      57.0   2019-05-01         NaN  Demonstration
# 15903            None      10.0   2019-01-01         NaN           Used
# 15906  VAT deductible      10.0   2019-01-01         NaN           Used
# 15908            None      10.0   2019-02-01         NaN           Used
# 15909  VAT deductible    3500.0   2019-05-01         NaN  Demonstration
#
#       previous_owners next_inspection inspection_new   warranty full_service  \
# 9                 NaN             NaN            NaN   3 months          NaN
# 13                NaN             NaN            NaN  12 months          NaN
# 30                NaN             NaN            NaN  12 months          NaN
# 39                  1             NaN            NaN        NaN       Euro 6
# 43                  1             NaN            NaN        NaN       Euro 6
# ...               ...             ...            ...        ...          ...
# 15883             NaN             NaN            NaN  48 months
# 15903             NaN             NaN            NaN  12 months          NaN
# 15906             NaN             NaN            NaN  12 months          NaN
# 15908             NaN             NaN            NaN  12 months          NaN
# 15909             NaN             NaN            NaN  48 months          NaN
#
#       non_smoking_vehicle      offer_number body_color paint_type  \
# 9                     NaN               NaN      White        NaN
# 13                    NaN    scap-ED-642-CV       Grey        NaN
# 30                    NaN           2780690      Black        NaN
# 39                    NaN        64/06/2019     Silver   Metallic
# 43                    NaN       148/05/2019      Black   Metallic
# ...                   ...               ...        ...        ...
# 15883                              8-900099      Black   Metallic
# 15903                 NaN  re62c9-FD-691-GF      Black        NaN
# 15906                 NaN          VO190299      White        NaN
# 15908                 NaN  re74c2-FE-210-EB      Black        NaN
# 15909                 NaN           1-15447      Black   Metallic
#
#       body_color_original upholstery nr_of_doors nr_of_seats model_code  \
# 9                   Blanc        NaN           5           4        NaN
# 13             Gris Clair        NaN           3           4        NaN
# 30                  Negro        NaN           5           5        NaN
# 39                 Silver      Cloth           5           5        NaN
# 43                  Black      Cloth           5           5        NaN
# ...                   ...        ...         ...         ...        ...
# 15883    BLACK-PEARL MET.        NaN           5           5        NaN
# 15903         NOIR ETOILE        NaN           5           5        NaN
# 15906               blanc        NaN           5         NaN        NaN
# 15908               NOIRE        NaN           5           5        NaN
# 15909         Black-Pearl        NaN           5           5        NaN
#
#       gearing_type displacement cylinders    weight drive_chain     fuel  \
# 9        Automatic       999 cc       NaN       NaN         NaN  Benzine
# 13       Automatic     1,395 cc       NaN       NaN         NaN  Benzine
# 30          Manual     1,422 cc         3  1,195 kg       front   Diesel
# 39          Manual     1,422 cc       NaN       NaN         NaN   Diesel
# 43          Manual     1,422 cc       NaN       NaN         NaN   Diesel
# ...            ...          ...       ...       ...         ...      ...
# 15883    Automatic     1,997 cc       NaN  1,847 kg         NaN   Diesel
# 15903    Automatic     1,798 cc       NaN       NaN         NaN  Benzine
# 15906    Automatic          NaN       NaN       NaN         NaN  Benzine
# 15908    Automatic     1,798 cc       NaN       NaN         NaN  Benzine
# 15909    Automatic     1,997 cc       NaN  1,779 kg         NaN   Diesel
#
#                                              consumption co_2_emission  \
# 9                                                    NaN           NaN
# 13                                                   NaN           NaN
# 30     ['3 l/100 km (comb)'],['3 l/100 km (city)'],['...           NaN
# 39                                                   NaN      [],[],[]
# 43                                                   NaN      [],[],[]
# ...                                                  ...           ...
# 15883                                                NaN      [],[],[]
# 15903                                                NaN           NaN
# 15906                      ['7.4 l/100 km (comb)'],[],[]           NaN
# 15908                                                NaN           NaN
# 15909                                                NaN      [],[],[]
#
#       emission_class                              comfort_&_convenience  \
# 9                NaN                                                NaN
# 13               NaN  Air conditioning,Automatic climate control,Cru...
# 30               NaN                                                NaN
# 39            Euro 6  Air conditioning,Automatic climate control,Cru...
# 43            Euro 6  Air conditioning,Automatic climate control,Lig...
# ...              ...                                                ...
# 15883            NaN  Air conditioning,Armrest,Automatic climate con...
# 15903            NaN  Air conditioning,Automatic climate control,Cru...
# 15906            NaN                       Cruise control,Power windows
# 15908            NaN  Air conditioning,Automatic climate control,Cru...
# 15909            NaN  Air conditioning,Automatic climate control,Cru...
#
#                                    entertainment_&_media  \
# 9                                                    NaN
# 13                     Bluetooth,On-board computer,Radio
# 30                                                   NaN
# 39     Bluetooth,CD player,Hands-free equipment,MP3,O...
# 43     Bluetooth,CD player,Hands-free equipment,MP3,O...
# ...                                                  ...
# 15883  Bluetooth,Hands-free equipment,MP3,On-board co...
# 15903  Bluetooth,Hands-free equipment,On-board comput...
# 15906                                                NaN
# 15908  Bluetooth,Hands-free equipment,On-board comput...
# 15909  Bluetooth,Hands-free equipment,On-board comput...
#
#                                           extras  \
# 9                                            NaN
# 13     Alloy wheels,Sport seats,Sport suspension
# 30                                           NaN
# 39                 Alloy wheels,Sport suspension
# 43                                  Alloy wheels
# ...                                          ...
# 15883    Alloy wheels,Touch screen,Voice Control
# 15903                               Alloy wheels
# 15906                               Alloy wheels
# 15908                               Alloy wheels
# 15909                  Alloy wheels,Touch screen
#
#                                        safety_&_security emission_label gears  \
# 9                                                    NaN            NaN     7
# 13     ABS,Adaptive headlights,Central door lock,Dayt...            NaN   NaN
# 30                                                   NaN            NaN     5
# 39     ABS,Daytime running lights,Driver-side airbag,...            NaN     5
# 43     ABS,Daytime running lights,Driver-side airbag,...            NaN     5
# ...                                                  ...            ...   ...
# 15883  ABS,Adaptive Cruise Control,Adaptive headlight...            NaN     7
# 15903  ABS,Central door lock,Daytime running lights,D...            NaN   NaN
# 15906  ABS,Driver-side airbag,Passenger-side airbag,S...            NaN   NaN
# 15908  ABS,Central door lock,Daytime running lights,D...            NaN   NaN
# 15909  ABS,Blind spot monitor,Central door lock,Dayti...            NaN     7
#
#       country_version electricity_consumption last_service_date  \
# 9                 NaN                     NaN               NaN
# 13                NaN                     NaN               NaN
# 30                NaN                     NaN               NaN
# 39                NaN                     NaN               NaN
# 43                NaN                     NaN               NaN
# ...               ...                     ...               ...
# 15883         Austria                     NaN               NaN
# 15903             NaN                     NaN               NaN
# 15906             NaN                     NaN               NaN
# 15908             NaN                     NaN               NaN
# 15909         Austria                     NaN               NaN
#
#       other_fuel_types availability last_timing_belt_service_date  \
# 9                  NaN          NaN                           NaN
# 13                 NaN          NaN                           NaN
# 30                 NaN          NaN                           NaN
# 39                 NaN          NaN                           NaN
# 43                 NaN          NaN                           NaN
# ...                ...          ...                           ...
# 15883              NaN          NaN                           NaN
# 15903              NaN          NaN                           NaN
# 15906              NaN          NaN                           NaN
# 15908              NaN          NaN                           NaN
# 15909              NaN          NaN                           NaN
#
#       available_from consumption_comb consumption_city consumption_country  \
# 9                NaN              NaN              NaN                 NaN
# 13               NaN              NaN              NaN                 NaN
# 30               NaN                3                3                   3
# 39               NaN              NaN              NaN                 NaN
# 43               NaN              NaN              NaN                 NaN
# ...              ...              ...              ...                 ...
# 15883            NaN              NaN              NaN                 NaN
# 15903            NaN              NaN              NaN                 NaN
# 15906            NaN              7.4              NaN                 NaN
# 15908            NaN              NaN              NaN                 NaN
# 15909            NaN              NaN              NaN                 NaN
#
#        hp_kw  Particulate_Filter inspection_time  inspection_situation  \
# 9       70.0                   0             NaT                     0
# 13     112.0                   0             NaT                     0
# 30      66.0                   0             NaT                     0
# 39      66.0                   1             NaT                     0
# 43      66.0                   1             NaT                     0
# ...      ...                 ...             ...                   ...
# 15883  147.0                   0             NaT                     0
# 15903  168.0                   0             NaT                     0
# 15906    NaN                   0             NaT                     0
# 15908  167.0                   0             NaT                     0
# 15909  147.0                   1             NaT                     0
#
#        warranty_month  co2_emission_gr
# 9                 3.0              NaN
# 13               12.0              NaN
# 30               12.0              NaN
# 39                NaN              NaN
# 43                NaN              NaN
# ...               ...              ...
# 15883            48.0              NaN
# 15903            12.0              NaN
# 15906            12.0              NaN
# 15908            12.0              NaN
# 15909            48.0              NaN
#
# [2436 rows x 55 columns]

# %%
#looking for the null values of inspection_situation in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["co2_emission_gr"].isnull()][i].str.contains("g CO2").any():
        print(i)
# Out:
# full_service

# %%
df[df["co2_emission_gr"].isnull()][df[df["co2_emission_gr"].isnull()]["full_service"].str.contains("g CO2") == True]
# Out:
#                                                    url make_model  \
# 363  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
#
#                            short_description body_type  price             vat  \
# 363  1.0 TFSI S tronic Navi Automatik Sitzh.    Sedans  14959  VAT deductible
#
#           km registration  prev_owner  type previous_owners next_inspection  \
# 363  56967.0   2016-03-01         2.0  Used               2             NaN
#
#                                         inspection_new  \
# 363  Yes4.4 l/100 km (comb)5.4 l/100 km (city)3.8 l...
#
#                          warranty         full_service non_smoking_vehicle  \
# 363  12 months0 kWh/100 km (comb)  102 g CO2/km (comb)              Euro 6
#
#     offer_number body_color paint_type     body_color_original    upholstery  \
# 363        13938      Black   Metallic  Mythosschwarz Metallic  Cloth, Black
#
#     nr_of_doors nr_of_seats model_code gearing_type displacement cylinders  \
# 363           3           4   0588/BCV    Automatic       999 cc         3
#
#     weight drive_chain     fuel  \
# 363    NaN         NaN  Benzine
#
#                                            consumption co_2_emission  \
# 363  4.4 l/100 km (comb),5.4 l/100 km (city),3.8 l/...           NaN
#
#     emission_class                              comfort_&_convenience  \
# 363            NaN  Air conditioning,Armrest,Automatic climate con...
#
#                                  entertainment_&_media  \
# 363  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                             extras  \
# 363  Alloy wheels,Sport suspension
#
#                                      safety_&_security emission_label gears  \
# 363  ABS,Central door lock,Daytime running lights,D...      4 (Green)     7
#
#     country_version electricity_consumption last_service_date  \
# 363         Germany     0 kWh/100 km (comb)               NaN
#
#     other_fuel_types availability last_timing_belt_service_date  \
# 363         [],[],[]          NaN                           NaN
#
#     available_from consumption_comb consumption_city consumption_country  \
# 363            NaN              4.4              5.4                 3.8
#
#      hp_kw  Particulate_Filter inspection_time  inspection_situation  \
# 363   70.0                   0             NaT                     1
#
#      warranty_month  co2_emission_gr
# 363            12.0              NaN

# %%
df.loc[df[df["co2_emission_gr"].isnull()][df[df["co2_emission_gr"].isnull()]["full_service"].str.contains("g CO2")== True].index, "co2_emission_gr"] = df[df["co2_emission_gr"].isnull()]["full_service"].str.extract("(\d+) g CO2/km").loc[df[df["co2_emission_gr"].isnull()][df[df["co2_emission_gr"].isnull()]["full_service"].str.contains("g CO2") == True].index].astype(float).values

# %% [markdown]
# ### full_service

# %%
first_look("full_service")
# Out:
# column name :  full_service
# ----------------------------------------
# Per_of_Nulls   :  % 48.39
# Number of Nulls  :  7704
# Number of Uniques:  121
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['' nan '99 g CO2/km (comb)' '4 (Green)' '92 g CO2/km (comb)' 'Euro 6'
#  '5 (Blue)' '97 g CO2/km (comb)' '102 g CO2/km (comb)'
#  '104 g CO2/km (comb)' '103 g CO2/km (comb)' '112 g CO2/km (comb)'
#  'Euro 6d-TEMP' '1 (No sticker)' '91 g CO2/km (comb)'
#  '114 g CO2/km (comb)' 'Euro 5' '118 g CO2/km (comb)'
#  '115 g CO2/km (comb)' '117 g CO2/km (comb)'
#  '4.4 l/100 km (comb)5.2 l/100 km (city)3.9 l/100 km (country)'
#  '105 g CO2/km (comb)' '129 g CO2/km (comb)' '101 g CO2/km (comb)'
#  '120 g CO2/km (comb)' '110 g CO2/km (comb)' '111 g CO2/km (comb)'
#  '137 g CO2/km (comb)' '0 kWh/100 km (comb)' '108 g CO2/km (comb)'
#  '98 g CO2/km (comb)' '126 g CO2/km (comb)' 'Euro 6d'
#  '106 g CO2/km (comb)'
#  '4.8 l/100 km (comb)5.9 l/100 km (city)4.2 l/100 km (country)'
#  '4.9 l/100 km (comb)6 l/100 km (city)4.2 l/100 km (country)'
#  '4.6 l/100 km (comb)5.8 l/100 km (city)3.9 l/100 km (country)'
#  '122 g CO2/km (comb)' '113 g CO2/km (comb)' '107 g CO2/km (comb)'
#  '116 g CO2/km (comb)' '119 g CO2/km (comb)' '109 g CO2/km (comb)'
#  '85 g CO2/km (comb)' '94 g CO2/km (comb)' '128 g CO2/km (comb)'
#  '89 g CO2/km (comb)' '189 g CO2/km (comb)' '153 g CO2/km (comb)'
#  '188 g CO2/km (comb)' '96 g CO2/km (comb)' 'Euro 6c'
#  '121 g CO2/km (comb)' '124 g CO2/km (comb)' '125 g CO2/km (comb)'
#  '141 g CO2/km (comb)' '130 g CO2/km (comb)' '95 g CO2/km (comb)'
#  '90 g CO2/km (comb)' '147 g CO2/km (comb)' '88 g CO2/km (comb)'
#  '127 g CO2/km (comb)'
#  '5.4 l/100 km (comb)7.3 l/100 km (city)4.2 l/100 km (country)'
#  '93 g CO2/km (comb)'
#  '4.3 l/100 km (comb)5.2 l/100 km (city)3.9 l/100 km (country)'
#  '136 g CO2/km (comb)' '151 g CO2/km (comb)' '146 g CO2/km (comb)'
#  '154 g CO2/km (comb)' '144 g CO2/km (comb)' '149 g CO2/km (comb)'
#  '139 g CO2/km (comb)' '138 g CO2/km (comb)'
#  '5.4 l/100 km (comb)7 l/100 km (city)4.5 l/100 km (country)'
#  '5.8 l/100 km (comb)7.4 l/100 km (city)4.9 l/100 km (country)'
#  '134 g CO2/km (comb)'
#  '5.5 l/100 km (comb)7.2 l/100 km (city)4.5 l/100 km (country)'
#  '6 l/100 km (comb)7.5 l/100 km (city)5.2 l/100 km (country)'
#  '80 g CO2/km (comb)'
#  '5.9 l/100 km (comb)7.8 l/100 km (city)4.8 l/100 km (country)'
#  '4.7 l/100 km (comb)5.4 l/100 km (city)4.2 l/100 km (country)'
#  '132 g CO2/km (comb)' '133 g CO2/km (comb)'
#  '5 l/100 km (comb)5.9 l/100 km (city)4.5 l/100 km (country)'
#  '143 g CO2/km (comb)' '140 g CO2/km (comb)' '123 g CO2/km (comb)'
#  '142 g CO2/km (comb)'
#  '4.9 l/100 km (comb)6.2 l/100 km (city)4.1 l/100 km (country)'
#  '6 l/100 km (comb)8 l/100 km (city)4.9 l/100 km (country)'
#  '84 g CO2/km (comb)' '82 g CO2/km (comb)' '87 g CO2/km (comb)'
#  '5.4 l/100 km (comb)6.7 l/100 km (city)4.6 l/100 km (country)'
#  '131 g CO2/km (comb)' '5.4 l/100 km (comb)'
#  '5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)'
#  '6.6 l/100 km (comb)8.2 l/100 km (city)5.6 l/100 km (country)'
#  '6.2 l/100 km (comb)7.7 l/100 km (city)5.4 l/100 km (country)'
#  '135 g CO2/km (comb)'
#  '6.3 l/100 km (comb)7.8 l/100 km (city)5.4 l/100 km (country)'
#  '150 g CO2/km (comb)' '157 g CO2/km (comb)' '156 g CO2/km (comb)'
#  '159 g CO2/km (comb)'
#  '5.7 l/100 km (comb)7.3 l/100 km (city)4.8 l/100 km (country)'
#  '152 g CO2/km (comb)' '253 g CO2/km (comb)' '164 g CO2/km (comb)'
#  '166 g CO2/km (comb)' '148 g CO2/km (comb)' '169 g CO2/km (comb)'
#  '145 g CO2/km (comb)'
#  '6.5 l/100 km (comb)8.1 l/100 km (city)5.5 l/100 km (country)'
#  '13,983 g CO2/km (comb)' '197 g CO2/km (comb)'
#  '6.6 l/100 km (comb)8.3 l/100 km (city)5.6 l/100 km (country)'
#  '6.6 l/100 km (comb)8.4 l/100 km (city)5.6 l/100 km (country)'
#  '5.7 l/100 km (comb)7.2 l/100 km (city)4.8 l/100 km (country)'
#  '5.9 l/100 km (comb)7.6 l/100 km (city)4.9 l/100 km (country)'
#  '5.9 l/100 km (comb)7.6 l/100 km (city)5.1 l/100 km (country)' 'Euro 4']
# ----------------------------------------
#                        1985
# 0 kWh/100 km (comb)       2
# 1 (No sticker)           29
# 101 g CO2/km (comb)      10
# 102 g CO2/km (comb)      29
#                        ...
# Euro 6                 2097
# Euro 6c                  28
# Euro 6d                  11
# Euro 6d-TEMP            399
# NaN                    7704
# Name: full_service, Length: 122, dtype: int64
# ----------------------------------------
# NaN                                                             7704
# 4 (Green)                                                       2235
# Euro 6                                                          2097
#                                                                 1985
# Euro 6d-TEMP                                                     399
#                                                                 ...
# 6 l/100 km (comb)8 l/100 km (city)4.9 l/100 km (country)           1
# 84 g CO2/km (comb)                                                 1
# 87 g CO2/km (comb)                                                 1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)       1
# Euro 4                                                             1
# Name: full_service, Length: 122, dtype: int64
# ################################################################################

# %% [markdown]
# ### non_smoking_vehicle

# %%
first_look("non_smoking_vehicle")
# Out:
# column name :  non_smoking_vehicle
# ----------------------------------------
# Per_of_Nulls   :  % 54.92
# Number of Nulls  :  8742
# Number of Uniques:  93
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['' nan 'Euro 6' '4 (Green)' '102 g CO2/km (comb)' '97 g CO2/km (comb)'
#  '103 g CO2/km (comb)' '99 g CO2/km (comb)' '106 g CO2/km (comb)'
#  '117 g CO2/km (comb)' '107 g CO2/km (comb)' 'Euro 5'
#  '123 g CO2/km (comb)' 'Euro 6d-TEMP' '90 g CO2/km (comb)'
#  '108 g CO2/km (comb)' '98 g CO2/km (comb)' '104 g CO2/km (comb)'
#  '112 g CO2/km (comb)' '105 g CO2/km (comb)' '91 g CO2/km (comb)'
#  '110 g CO2/km (comb)' '142 g CO2/km (comb)' '115 g CO2/km (comb)'
#  '111 g CO2/km (comb)' '136 g CO2/km (comb)' '116 g CO2/km (comb)'
#  '101 g CO2/km (comb)' '118 g CO2/km (comb)' '137 g CO2/km (comb)'
#  '127 g CO2/km (comb)' '119 g CO2/km (comb)' '189 g CO2/km (comb)'
#  '1.6 l/100 km (comb)' '126 g CO2/km (comb)' '134 g CO2/km (comb)'
#  '1 (No sticker)' '122 g CO2/km (comb)' '114 g CO2/km (comb)'
#  '5.2 l/100 km (comb)6.4 l/100 km (city)4.4 l/100 km (country)'
#  '5.2 l/100 km (comb)5.8 l/100 km (city)4.8 l/100 km (country)'
#  '125 g CO2/km (comb)' '121 g CO2/km (comb)' 'Euro 6d'
#  '113 g CO2/km (comb)' '95 g CO2/km (comb)' '130 g CO2/km (comb)'
#  '92 g CO2/km (comb)' '124 g CO2/km (comb)' '128 g CO2/km (comb)'
#  '5.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '151 g CO2/km (comb)' '149 g CO2/km (comb)'
#  '6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)'
#  '135 g CO2/km (comb)' '139 g CO2/km (comb)' '138 g CO2/km (comb)'
#  '5 (Blue)' '143 g CO2/km (comb)' '120 g CO2/km (comb)'
#  '100 g CO2/km (comb)' '131 g CO2/km (comb)' 'Euro 6c'
#  '129 g CO2/km (comb)' '157 g CO2/km (comb)'
#  '6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)'
#  '150 g CO2/km (comb)' '158 g CO2/km (comb)' '133 g CO2/km (comb)'
#  '140 g CO2/km (comb)'
#  '5.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)'
#  '147 g CO2/km (comb)' '159 g CO2/km (comb)' '166 g CO2/km (comb)'
#  '169 g CO2/km (comb)' '109 g CO2/km (comb)' '132 g CO2/km (comb)'
#  '144 g CO2/km (comb)' '152 g CO2/km (comb)'
#  '6.1 l/100 km (comb)7.8 l/100 km (city)5.1 l/100 km (country)'
#  '6.4 l/100 km (comb)8.1 l/100 km (city)5.4 l/100 km (country)'
#  '156 g CO2/km (comb)'
#  '6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)'
#  '148 g CO2/km (comb)' '146 g CO2/km (comb)'
#  '6.3 l/100 km (comb)8 l/100 km (city)5.3 l/100 km (country)'
#  '6.5 l/100 km (comb)7.9 l/100 km (city)5.6 l/100 km (country)'
#  '154 g CO2/km (comb)' '85 g CO2/km (comb)' '82 g CO2/km (comb)'
#  '153 g CO2/km (comb)' '172 g CO2/km (comb)' '161 g CO2/km (comb)'
#  '175 g CO2/km (comb)']
# ----------------------------------------
#                        3717
# 1 (No sticker)           24
# 1.6 l/100 km (comb)       1
# 100 g CO2/km (comb)      18
# 101 g CO2/km (comb)       1
#                        ...
# Euro 6                 1127
# Euro 6c                  17
# Euro 6d                   9
# Euro 6d-TEMP            345
# NaN                    8742
# Name: non_smoking_vehicle, Length: 94, dtype: int64
# ----------------------------------------
# NaN                                                             8742
#                                                                 3717
# 4 (Green)                                                       1240
# Euro 6                                                          1127
# Euro 6d-TEMP                                                     345
#                                                                 ...
# 6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)       1
# 91 g CO2/km (comb)                                                 1
# 101 g CO2/km (comb)                                                1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       1
# 175 g CO2/km (comb)                                                1
# Name: non_smoking_vehicle, Length: 94, dtype: int64
# ################################################################################

# %% [markdown]
# ### offer_number

# %%
first_look("offer_number")
# Out:
# column name :  offer_number
# ----------------------------------------
# Per_of_Nulls   :  % 19.94
# Number of Nulls  :  3175
# Number of Uniques:  11440
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['LR-062483' nan 'AM-95365' ... 'Espace16' '2691331' 'Re_30000008029']
# ----------------------------------------
# # 250678          1
# # 8H6050830       1
# # G1024529        1
# # G6050580        1
# #8023778          2
#                ...
# x_45689v          2
# y8fx64x           1
# zr11914           1
# zr11916           1
# NaN            3175
# Name: offer_number, Length: 11441, dtype: int64
# ----------------------------------------
# NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
# ################################################################################

# %%
df.drop(columns="offer_number", inplace=True)

# %% [markdown]
# ### body_color & body_color_original

# %%
first_look("body_color")
# Out:
# column name :  body_color
# ----------------------------------------
# Per_of_Nulls   :  % 3.75
# Number of Nulls  :  597
# Number of Uniques:  14
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Black' 'Red' 'Brown' 'White' 'Grey' 'Silver' 'Blue' nan 'Beige' 'Violet'
#  'Yellow' 'Green' 'Bronze' 'Orange' 'Gold']
# ----------------------------------------
# Beige      108
# Black     3745
# Blue      1431
# Bronze       6
# Brown      289
# Gold         2
# Green      154
# Grey      3505
# Orange       3
# Red        957
# Silver    1647
# Violet      18
# White     3406
# Yellow      51
# NaN        597
# Name: body_color, dtype: int64
# ----------------------------------------
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
# ################################################################################

# %%
first_look("body_color_original")
# Out:
# column name :  body_color_original
# ----------------------------------------
# Per_of_Nulls   :  % 23.61
# Number of Nulls  :  3759
# Number of Uniques:  1927
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Mythosschwarz' nan 'mythosschwarz metallic' ... 'Grau - Stahl Grau'
#  'titaniumgraumetallic' 'Perlmutt-Weiß Metallic (Weiß)']
# ----------------------------------------
# "PLATIN"                          1
# "satinsilber "                    1
# (0C0C) Monsungrau Metallic        1
# (B4B4) Cortinaweiss               1
# (NNP)                             1
#                                ...
# wählbar - ggf. mit Aufpreis     118
# wählbar -ggfl. mit Aufpreis       1
# wählbar, ggf gegen Aufpreis       2
# zwart                             2
# NaN                            3759
# Name: body_color_original, Length: 1928, dtype: int64
# ----------------------------------------
# NaN                              3759
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            238
# Brillantschwarz                   216
#                                  ...
# Rouge-Braun (G0Y)                   1
# VARI COLRI DISPONIBILI              1
# Kokosnussbraun Metallic             1
# Farbe frei wählbar                  1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1928, dtype: int64
# ################################################################################

# %%
df[df["body_color"].isnull()]["body_color_original"].value_counts()
# Out:
# wählbar - ggf. mit Aufpreis       118
# wählbar                            88
# Metallic o. Uni (wählbar)          33
# wählbar - ggf gegen Aufpreis       25
# null                               15
#                                  ...
# rouge eclat                         1
# quarzgrau dunkel Grau metallic      1
# Licht Grau M2                       1
# graphitgrau Metallik                1
# Farbe: Sonstige                     1
# Name: body_color_original, Length: 86, dtype: int64

# %%
df[df["body_color"].isnull()]["body_color_original"].apply(lambda x: x in ['Schwarz' ,'Rot', 'Braun' ,'Weiß', 'Grau', 'Silber',  'Blau', 'Beige' ,'Violett', 'Gelb' ,'Grün' ,'Bronze' ,'Orange' ,'Gold']).value_counts()
# Out:
# False    597
# Name: body_color_original, dtype: int64

# %%
#looking for the null values of inspection_situation in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["body_color"].isnull()][i].str.contains('Black|Red|Brown|White|Grey|Silver|Blue |Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True).any():
        print(i)
# Out:
# short_description
# inspection_new
# warranty
# full_service
# non_smoking_vehicle
# body_color_original
# upholstery
# emission_label

# %%
df[df["body_color"].isnull()][df[df["body_color"].isnull()]["body_color_original"].str.contains('Black|Red|Brown|White|Grey|Silver|Blue|Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True) == True]
# Out:
#                                                      url     make_model  \
# 1706   https://www.autoscout24.com//offers/audi-a1-sp...        Audi A1
# 9075   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 11591  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 11620  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 11627  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
#
#                                        short_description      body_type  \
# 1706   Sportback 1.0 TFSI Ultra *Sitzheizung*Start/St...         Sedans
# 9075    E Edition Aut. SHZG LHZG GRA PDC Klima Bluetooth         Sedans
# 11591                    2 SPORT TOURER EDITION 136 CDTI  Station wagon
# 11620                     2 GRAND SPORT EDITION 110 CDTI          Coupe
# 11627                    2 SPORT TOURER EDITION 136 CDTI  Station wagon
#
#        price             vat       km registration  prev_owner  \
# 1706   16490  VAT deductible    100.0   2018-07-01         NaN
# 9075   13890  VAT deductible     10.0   2018-08-01         1.0
# 11591  18654            None  13953.0   2017-10-01         NaN
# 11620  17094            None  28142.0   2017-06-01         NaN
# 11627  18054            None  24178.0   2017-11-01         NaN
#
#                  type previous_owners next_inspection          inspection_new  \
# 1706   Pre-registered             NaN             NaN                     NaN
# 9075   Pre-registered               1             NaN  Yes149 g CO2/km (comb)
# 11591            Used             NaN             NaN                     NaN
# 11620            Used             NaN             NaN                     NaN
# 11627            Used             NaN             NaN                     NaN
#
#       warranty full_service non_smoking_vehicle body_color paint_type  \
# 1706       NaN          NaN                 NaN        NaN        NaN
# 9075       NaN          NaN              Euro 6        NaN   Metallic
# 11591      NaN          NaN                 NaN        NaN        NaN
# 11620      NaN          NaN                 NaN        NaN        NaN
# 11627      NaN          NaN                 NaN        NaN        NaN
#
#               body_color_original    upholstery nr_of_doors nr_of_seats  \
# 1706                Cortina White  Cloth, Black           5           5
# 9075   Graphit Grau/Graffiti Grey           NaN           5           5
# 11591        GAN Sovereign Silver           NaN           5         NaN
# 11620           GDX Darkmoon Blue           NaN           4         NaN
# 11627        GF6 Satin Steel Grey           NaN           5         NaN
#
#       model_code gearing_type displacement cylinders    weight drive_chain  \
# 1706         NaN       Manual       999 cc       NaN       NaN       front
# 9075    0035/BCB    Automatic     1,398 cc         4  1,248 kg         NaN
# 11591        NaN       Manual          NaN       NaN       NaN         NaN
# 11620        NaN       Manual          NaN       NaN       NaN         NaN
# 11627        NaN       Manual          NaN       NaN       NaN         NaN
#
#           fuel                                        consumption  \
# 1706   Benzine  ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],...
# 9075   Benzine  ['6.6 l/100 km (comb)'],['8.2 l/100 km (city)'...
# 11591   Diesel                                                NaN
# 11620   Diesel                                                NaN
# 11627   Diesel                                                NaN
#
#              co_2_emission emission_class  \
# 1706    97 g CO2/km (comb)         Euro 6
# 9075   149 g CO2/km (comb)         Euro 6
# 11591             [],[],[]            NaN
# 11620             [],[],[]            NaN
# 11627             [],[],[]            NaN
#
#                                    comfort_&_convenience  \
# 1706   Air conditioning,Armrest,Automatic climate con...
# 9075   Air conditioning,Cruise control,Electrical sid...
# 11591                              Park Distance Control
# 11620                              Park Distance Control
# 11627                              Park Distance Control
#
#                                    entertainment_&_media        extras  \
# 1706               CD player,MP3,On-board computer,Radio  Alloy wheels
# 9075   Bluetooth,Hands-free equipment,MP3,On-board co...  Alloy wheels
# 11591                                                NaN           NaN
# 11620                                                NaN           NaN
# 11627                                                NaN           NaN
#
#                                        safety_&_security emission_label gears  \
# 1706   ABS,Central door lock,Daytime running lights,E...      4 (Green)     5
# 9075   ABS,Central door lock,Daytime running lights,D...      4 (Green)     6
# 11591                  Passenger-side airbag,Side airbag            NaN   NaN
# 11620                  Passenger-side airbag,Side airbag            NaN   NaN
# 11627                  Passenger-side airbag,Side airbag            NaN   NaN
#
#       country_version electricity_consumption last_service_date  \
# 1706   European Union                     NaN               NaN
# 9075              NaN                     NaN               NaN
# 11591             NaN                     NaN               NaN
# 11620             NaN                     NaN               NaN
# 11627             NaN                     NaN               NaN
#
#       other_fuel_types availability last_timing_belt_service_date  \
# 1706               NaN          NaN                           NaN
# 9075               NaN          NaN                           NaN
# 11591              NaN          NaN                           NaN
# 11620              NaN          NaN                           NaN
# 11627              NaN          NaN                           NaN
#
#       available_from consumption_comb consumption_city consumption_country  \
# 1706             NaN              4.2                5                 3.7
# 9075             NaN              6.6              8.2                 5.6
# 11591            NaN              NaN              NaN                 NaN
# 11620            NaN              NaN              NaN                 NaN
# 11627            NaN              NaN              NaN                 NaN
#
#        hp_kw  Particulate_Filter inspection_time  inspection_situation  \
# 1706    70.0                   0             NaT                     0
# 9075    66.0                   0             NaT                     1
# 11591  100.0                   0             NaT                     0
# 11620   81.0                   0             NaT                     0
# 11627  100.0                   0             NaT                     0
#
#        warranty_month  co2_emission_gr
# 1706              NaN             97.0
# 9075              NaN            149.0
# 11591             NaN              NaN
# 11620             NaN              NaN
# 11627             NaN              NaN

# %%
df.loc[[1706,9075,11591,11620,11627],"body_color"] = ["White","Grey","Silver","Blue","Grey"]

# %%
df[df["body_color"].isnull()][df[df["body_color"].isnull()]["short_description"].str.contains('Black|Red|Brown|White|Grey|Silver|Blue|Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True) == True]
# Out:
#                                                      url      make_model  \
# 1641   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1680   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1928   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 2321   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 2361   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 2362   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 8804   https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 10131  https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 15493  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15654  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15663  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15854  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                              short_description body_type  price  \
# 1641     Sportback 35 TFSI Black line S tronic   Compact  23032
# 1680     Sportback 30 TFSI Black line S tronic   Compact  21664
# 1928     Sportback 40 TFSI Black line S tronic   Compact  28200
# 2321              Sportback 30 TFSI Black line   Compact  19826
# 2361              Sportback 25 TFSI Black line   Compact  18670
# 2362              Sportback 25 TFSI Black line   Compact  18670
# 8804      E Klimaanlage Radio Bluetooth ISOFIX   Compact   6450
# 10131      1.4 90CV aut. 5 porte Black Edition    Sedans  14900
# 15493             Blue dCi TT Intens EDC 118kW       Van  32550
# 15654            Blue dCi TT Limited EDC 118kW       Van  35146
# 15663         2.0dCi TT Limited Blue EDC 147kW       Van  36890
# 15854  2.0dCi TT Initiale Paris Blue EDC 147kW       Van  43911
#
#                   vat       km registration  prev_owner            type  \
# 1641             None      NaN          NaT         NaN             New
# 1680             None      NaN          NaT         NaN             New
# 1928             None      NaN          NaT         NaN             New
# 2321             None      NaN          NaT         NaN             New
# 2361             None      NaN          NaT         NaN             New
# 2362             None      NaN          NaT         NaN             New
# 8804   VAT deductible  73519.0   2016-04-01         2.0            Used
# 10131            None      NaN   2019-03-01         NaN  Pre-registered
# 15493            None      NaN          NaT         NaN             New
# 15654            None      NaN          NaT         NaN             New
# 15663            None      NaN          NaT         NaN             New
# 15854            None      NaN          NaT         NaN             New
#
#       previous_owners next_inspection inspection_new  \
# 1641              NaN             NaN            NaN
# 1680              NaN             NaN            NaN
# 1928              NaN             NaN            NaN
# 2321              NaN             NaN            NaN
# 2361              NaN             NaN            NaN
# 2362              NaN             NaN            NaN
# 8804                2             NaN            NaN
# 10131             NaN             NaN            NaN
# 15493             NaN             NaN            NaN
# 15654             NaN             NaN            NaN
# 15663             NaN             NaN            NaN
# 15854             NaN             NaN            NaN
#
#                            warranty         full_service non_smoking_vehicle  \
# 1641                            NaN                  NaN                 NaN
# 1680                            NaN                  NaN                 NaN
# 1928                            NaN                  NaN                 NaN
# 2321                            NaN                  NaN                 NaN
# 2361                            NaN                  NaN                 NaN
# 2362                            NaN                  NaN                 NaN
# 8804   60 months5.4 l/100 km (comb)  128 g CO2/km (comb)              Euro 6
# 10131                           NaN                  NaN                 NaN
# 15493                           NaN                  NaN                 NaN
# 15654                           NaN                  NaN                 NaN
# 15663                           NaN                  NaN                 NaN
# 15854                           NaN                  NaN                 NaN
#
#       body_color paint_type body_color_original    upholstery nr_of_doors  \
# 1641         NaN        NaN                 NaN           NaN           5
# 1680         NaN        NaN                 NaN           NaN           5
# 1928         NaN        NaN                 NaN           NaN           5
# 2321         NaN        NaN                 NaN           NaN           5
# 2361         NaN        NaN                 NaN           NaN           5
# 2362         NaN        NaN                 NaN           NaN           5
# 8804         NaN        NaN                 NaN  Cloth, Black           2
# 10131        NaN        NaN                null           NaN           5
# 15493        NaN        NaN                 NaN           NaN           5
# 15654        NaN        NaN                 NaN           NaN           5
# 15663        NaN        NaN                 NaN           NaN           5
# 15854        NaN        NaN                 NaN           NaN           5
#
#       nr_of_seats model_code gearing_type displacement cylinders    weight  \
# 1641            5        NaN    Automatic     1,498 cc         4  1,180 kg
# 1680            5        NaN    Automatic       999 cc         3  1,200 kg
# 1928            5        NaN    Automatic     1,984 cc         4  1,180 kg
# 2321            5        NaN       Manual       999 cc         3  1,180 kg
# 2361            5        NaN       Manual       999 cc         3  1,165 kg
# 2362            5        NaN       Manual       999 cc         3  1,165 kg
# 8804            5        NaN       Manual     1,229 cc       NaN       NaN
# 10131           5        NaN    Automatic     1,398 cc         4  1,199 kg
# 15493           5        NaN    Automatic     1,997 cc         4  1,659 kg
# 15654           5        NaN    Automatic     1,997 cc         4  1,659 kg
# 15663           5        NaN    Automatic     1,997 cc         4  1,659 kg
# 15854           5        NaN    Automatic     1,997 cc         4  1,659 kg
#
#       drive_chain     fuel                                        consumption  \
# 1641        front  Benzine  ['5 l/100 km (comb)'],['6 l/100 km (city)'],['...
# 1680        front  Benzine  ['4 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 1928        front  Benzine  ['6 l/100 km (comb)'],['8 l/100 km (city)'],['...
# 2321        front  Benzine  ['4 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 2361        front  Benzine  ['4 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 2362        front  Benzine  ['4 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 8804          NaN  Benzine                               5.4 l/100 km (comb),
# 10131       front  Benzine  ['6 l/100 km (comb)'],['8 l/100 km (city)'],['...
# 15493       front   Diesel  ['5 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 15654       front   Diesel  ['5 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 15663       front   Diesel  ['5 l/100 km (comb)'],['5 l/100 km (city)'],['...
# 15854       front   Diesel  ['5 l/100 km (comb)'],['5 l/100 km (city)'],['...
#
#              co_2_emission emission_class  \
# 1641                   NaN            NaN
# 1680                   NaN            NaN
# 1928                   NaN            NaN
# 2321                   NaN            NaN
# 2361                   NaN            NaN
# 2362                   NaN            NaN
# 8804   128 g CO2/km (comb)            NaN
# 10131  139 g CO2/km (comb)         Euro 6
# 15493                  NaN            NaN
# 15654                  NaN            NaN
# 15663                  NaN            NaN
# 15854                  NaN            NaN
#
#                                    comfort_&_convenience  \
# 1641                                                 NaN
# 1680                                                 NaN
# 1928                                                 NaN
# 2321                                                 NaN
# 2361                                                 NaN
# 2362                                                 NaN
# 8804   Air conditioning,Electrical side mirrors,Hill ...
# 10131  Air conditioning,Electrical side mirrors,Power...
# 15493                                                NaN
# 15654                                                NaN
# 15663                                                NaN
# 15854                                                NaN
#
#                entertainment_&_media                                  extras  \
# 1641                             NaN                                     NaN
# 1680                             NaN                                     NaN
# 1928                             NaN                                     NaN
# 2321                             NaN                                     NaN
# 2361                             NaN                                     NaN
# 2362                             NaN                                     NaN
# 8804         On-board computer,Radio                                     NaN
# 10131  Bluetooth,CD player,Radio,USB  Alloy wheels,Sport package,Sport seats
# 15493                            NaN                                     NaN
# 15654                            NaN                                     NaN
# 15663                            NaN                                     NaN
# 15854                            NaN                                     NaN
#
#                                        safety_&_security emission_label gears  \
# 1641                                                 NaN            NaN     7
# 1680                                                 NaN            NaN     7
# 1928                                                 NaN            NaN     7
# 2321                                                 NaN            NaN     6
# 2361                                                 NaN            NaN     5
# 2362                                                 NaN            NaN     5
# 8804   ABS,Central door lock,Daytime running lights,D...      4 (Green)     5
# 10131  ABS,Central door lock,Driver-side airbag,Elect...            NaN     6
# 15493                                                NaN            NaN     6
# 15654                                                NaN            NaN     6
# 15663                                                NaN            NaN     6
# 15854                                                NaN            NaN     6
#
#       country_version electricity_consumption last_service_date  \
# 1641              NaN                     NaN               NaN
# 1680              NaN                     NaN               NaN
# 1928              NaN                     NaN               NaN
# 2321              NaN                     NaN               NaN
# 2361              NaN                     NaN               NaN
# 2362              NaN                     NaN               NaN
# 8804          Germany                     NaN               NaN
# 10131             NaN                     NaN               NaN
# 15493             NaN                     NaN               NaN
# 15654             NaN                     NaN               NaN
# 15663             NaN                     NaN               NaN
# 15854             NaN                     NaN               NaN
#
#       other_fuel_types availability last_timing_belt_service_date  \
# 1641               NaN          NaN                           NaN
# 1680               NaN          NaN                           NaN
# 1928               NaN          NaN                           NaN
# 2321               NaN          NaN                           NaN
# 2361               NaN          NaN                           NaN
# 2362               NaN          NaN                           NaN
# 8804          [],[],[]          NaN                           NaN
# 10131              NaN          NaN                           NaN
# 15493              NaN          NaN                           NaN
# 15654              NaN          NaN                           NaN
# 15663              NaN          NaN                           NaN
# 15854              NaN          NaN                           NaN
#
#       available_from consumption_comb consumption_city consumption_country  \
# 1641             NaN                5                6                   3
# 1680             NaN                4                5                   4
# 1928             NaN                6                8                   4
# 2321             NaN                4                5                   4
# 2361             NaN                4                5                   3
# 2362             NaN                4                5                   3
# 8804             NaN              5.4              NaN                 NaN
# 10131            NaN                6                8                 4.9
# 15493            NaN                5                5                   4
# 15654            NaN                5                5                   4
# 15663            NaN                5                5                   4
# 15854            NaN                5                5                   4
#
#        hp_kw  Particulate_Filter inspection_time  inspection_situation  \
# 1641   110.0                   0             NaT                     0
# 1680    85.0                   0             NaT                     0
# 1928   147.0                   0             NaT                     0
# 2321    85.0                   0             NaT                     0
# 2361    70.0                   0             NaT                     0
# 2362    70.0                   0             NaT                     0
# 8804    51.0                   0             NaT                     0
# 10131   66.0                   0             NaT                     0
# 15493  118.0                   0             NaT                     0
# 15654  118.0                   0             NaT                     0
# 15663  147.0                   0             NaT                     0
# 15854  147.0                   0             NaT                     0
#
#        warranty_month  co2_emission_gr
# 1641              NaN              NaN
# 1680              NaN              NaN
# 1928              NaN              NaN
# 2321              NaN              NaN
# 2361              NaN              NaN
# 2362              NaN              NaN
# 8804             60.0            128.0
# 10131             NaN            139.0
# 15493             NaN              NaN
# 15654             NaN              NaN
# 15663             NaN              NaN
# 15854             NaN              NaN

# %%
df[df["body_color"].isnull()][df[df["body_color"].isnull()]["short_description"].str.contains('Black|Red|Brown|White|Grey|Silver|Blue|Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True) == True]["short_description"].str.extract("(Black |Blue )")
# Out:
#             0
# 1641   Black
# 1680   Black
# 1928   Black
# 2321   Black
# 2361   Black
# 2362   Black
# 8804      NaN
# 10131  Black
# 15493   Blue
# 15654   Blue
# 15663   Blue
# 15854   Blue

# %%
df.loc[df[df["body_color"].isnull()][df[df["body_color"].isnull()]["short_description"].str.contains('Black|Red|Brown|White|Grey|Silver|Blue|Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True) == True].index, "body_color"] = df[df["body_color"].isnull()][df[df["body_color"].isnull()]["short_description"].str.contains('Black|Red|Brown|White|Grey|Silver|Blue|Beige|Violet|Yellow|Green|Bronze|Orange|Gold', regex=True) == True]["short_description"].str.extract("(Black |Blue )").values

# %%
df.drop(columns="body_color_original", inplace=True)

# %% [markdown]
# ### paint_type

# %%
first_look("paint_type")
# Out:
# column name :  paint_type
# ----------------------------------------
# Per_of_Nulls   :  % 36.26
# Number of Nulls  :  5772
# Number of Uniques:  3
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Metallic' nan 'Uni/basic' 'Perl effect']
# ----------------------------------------
# Metallic       9794
# Perl effect       6
# Uni/basic       347
# NaN            5772
# Name: paint_type, dtype: int64
# ----------------------------------------
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
# ################################################################################

# %% [markdown]
# ### upholstery

# %%
first_look("upholstery")
# Out:
# column name :  upholstery
# ----------------------------------------
# Per_of_Nulls   :  % 23.37
# Number of Nulls  :  3720
# Number of Uniques:  46
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Cloth, Black' 'Cloth, Grey' nan 'Part leather, Black' 'Cloth, Other'
#  'Full leather, Black' 'Cloth, White' 'Black' 'Cloth' 'Other, Black'
#  'Part leather' 'Full leather' 'Full leather, Red' 'alcantara, Black'
#  'Other, Other' 'Velour' 'Cloth, Blue' 'Cloth, Red' 'Grey' 'Blue'
#  'Velour, Black' 'Velour, Grey' 'Other' 'Part leather, Grey'
#  'Cloth, Orange' 'Part leather, Other' 'alcantara, Grey' 'Other, Grey'
#  'Full leather, Grey' 'Part leather, Brown' 'alcantara, Other'
#  'Full leather, Brown' 'Part leather, Beige' 'Cloth, Beige'
#  'Full leather, Other' 'White' 'Cloth, Brown' 'Other, Yellow' 'alcantara'
#  'Full leather, Beige' 'Beige' 'Part leather, White' 'Part leather, Red'
#  'Brown' 'Full leather, Blue' 'Other, Brown' 'Full leather, White']
# ----------------------------------------
# Beige                     3
# Black                   491
# Blue                      2
# Brown                    12
# Cloth                  1005
# Cloth, Beige             13
# Cloth, Black           5821
# Cloth, Blue              12
# Cloth, Brown             28
# Cloth, Grey             891
# Cloth, Orange             1
# Cloth, Other            639
# Cloth, Red                5
# Cloth, White              8
# Full leather            139
# Full leather, Beige      36
# Full leather, Black     575
# Full leather, Blue        2
# Full leather, Brown     116
# Full leather, Grey       67
# Full leather, Other      72
# Full leather, Red         1
# Full leather, White       1
# Grey                    273
# Other                    56
# Other, Black            110
# Other, Brown              1
# Other, Grey              15
# Other, Other            182
# Other, Yellow             4
# Part leather            140
# Part leather, Beige       2
# Part leather, Black    1121
# Part leather, Brown      50
# Part leather, Grey      116
# Part leather, Other      65
# Part leather, Red         3
# Part leather, White       2
# Velour                   16
# Velour, Black            36
# Velour, Grey              8
# White                     2
# alcantara                 2
# alcantara, Black         47
# alcantara, Grey           6
# alcantara, Other          2
# NaN                    3720
# Name: upholstery, dtype: int64
# ----------------------------------------
# Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# Cloth, Blue              12
# Velour, Grey              8
# Cloth, White              8
# alcantara, Grey           6
# Cloth, Red                5
# Other, Yellow             4
# Part leather, Red         3
# Beige                     3
# Part leather, White       2
# Full leather, Blue        2
# alcantara, Other          2
# alcantara                 2
# White                     2
# Part leather, Beige       2
# Blue                      2
# Cloth, Orange             1
# Full leather, Red         1
# Other, Brown              1
# Full leather, White       1
# Name: upholstery, dtype: int64
# ################################################################################

# %%
#classify upholstery by color and type
df["upholstery_type"] = df["upholstery"].str.extract("(Cloth|\w+ leather|Other|Velour|alcantara)")

# %%
df["upholstery_color"] = df["upholstery"].str.extract("(Black|Grey|\sOther|Brown|Beige|Blue|Red|Yellow|White|Orange)")

# %%
#looking for the null values of upholstery_type in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["upholstery_type"].isnull()][i].str.contains("(Cloth|\w+ leather|Velour|alcantara)", regex=True).any():
        print(i)
#There is no column to get values

# %%
df.drop(columns="upholstery", inplace=True)

# %% [markdown]
# ### nr_of_doors & nr_of_seats

# %%
first_look("nr_of_doors")
# Out:
# column name :  nr_of_doors
# ----------------------------------------
# Per_of_Nulls   :  % 1.33
# Number of Nulls  :  212
# Number of Uniques:  6
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['5' '3' '4' '2' nan '1' '7']
# ----------------------------------------
# 1          1
# 2        219
# 3        832
# 4       3079
# 5      11575
# 7          1
# NaN      212
# Name: nr_of_doors, dtype: int64
# ----------------------------------------
# 5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
# ################################################################################

# %%
first_look("nr_of_seats")
# Out:
# column name :  nr_of_seats
# ----------------------------------------
# Per_of_Nulls   :  % 6.14
# Number of Nulls  :  977
# Number of Uniques:  6
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['5' '4' nan '6' '3' '2' '7']
# ----------------------------------------
# 2        116
# 3          1
# 4       1125
# 5      13336
# 6          2
# 7        362
# NaN      977
# Name: nr_of_seats, dtype: int64
# ----------------------------------------
# 5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
# ################################################################################

# %%
#Changing data types to float
df["nr_of_doors"] = df["nr_of_doors"].astype(float)
df["nr_of_seats"] = df["nr_of_seats"].astype(float)

# %% [markdown]
# ### model_code

# %%
first_look("model_code")
# Out:
# column name :  model_code
# ----------------------------------------
# Per_of_Nulls   :  % 68.73
# Number of Nulls  :  10941
# Number of Uniques:  232
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['0588/BDF' '0588/BCY' nan '0588/BDC' '0588/BDB' '0588/BCV' '0588/BCZ'
#  '0588/BHL' '0588/BDG' '0588/BCW' '0588/BDA' '0588/BDD' '0588/BCX'
#  '0588/BHM' '0000/000' '0588/BDE' '0588/BNO' '0588/000' '0588/AUJ'
#  '0588/BNQ' '0588/BN0' '0588/BNP' '0588/BNN' '0588/BJV' '0588/AWJ'
#  '0588/AYB' '0588/BAH' '0588/BAI' '0588/AXC' '0588/BAF' '0588/AVO'
#  '0588/AWS' '0588/BAM' '0588/BAD' '0588/AWX' '0588/BAE' '0588/BAJ'
#  '0588/AZX' '0588/AVR' '0588/AYA' '0588/AVQ' '0588/BET' '0588/AWQ'
#  '0588/AGL' '0588/BIB' '0588/AZY' '0588/BLH' '0588/BER' '0588/BHX'
#  '0588/BLL' '0588/BLG' '0588/BLF' '0588/AZZ' '0588/BHT' '0588/AYC'
#  '0588/BLK' '0035/BHZ' '0035/BHQ' '0035/BFM' '0035/BHV' '0035/BHP'
# 3333/BKQ       18
# 3333/BKR        8
# NaN         10941
# Name: model_code, Length: 233, dtype: int64
# ----------------------------------------
# NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
#             ...
# 0035/AVN        1
# 0035/BEM        1
# 0035/BAG        1
# 0035/BAA        1
# 3333/BKG        1
# Name: model_code, Length: 233, dtype: int64
# ################################################################################

# %%
df.drop(columns="model_code", inplace=True)

# %% [markdown]
# ### gearing_type

# %%
first_look("gearing_type")
# Out:
# column name :  gearing_type
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  3
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Automatic' 'Manual' 'Semi-automatic']
# ----------------------------------------
# Automatic         7297
# Manual            8153
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ----------------------------------------
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ################################################################################

# %% [markdown]
# ### displacement

# %%
first_look("displacement")
# Out:
# column name :  displacement
# ----------------------------------------
# Per_of_Nulls   :  % 3.12
# Number of Nulls  :  496
# Number of Uniques:  77
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['1,422 cc' '1,798 cc' '1,598 cc' '999 cc' '1,395 cc' '929 cc' nan
#  '1,596 cc' '1,600 cc' '1,000 cc' '1,984 cc' '1,498 cc' '1,197 cc'
#  '995 cc' '998 cc' '1,968 cc' '1,400 cc' '2,000 cc' '1,568 cc' '1,896 cc'
#  '2,480 cc' '1,499 cc' '1,495 cc' '1,398 cc' '1,584 cc' '997 cc'
#  '1,399 cc' '1,364 cc' '1,490 cc' '996 cc' '1,696 cc' '1,686 cc'
#  '1,396 cc' '15,898 cc' '139 cc' '1,368 cc' '140 cc' '1,397 cc' '1,248 cc'
#  '1,229 cc' '1,300 cc' '1,200 cc' '973 cc' '1,239 cc' '1,350 cc'
#  '1,369 cc' '1,390 cc' '122 cc' '1,198 cc' '1,195 cc' '1,956 cc'
#  '1,998 cc' '2 cc' '2,967 cc' '1,856 cc' '16,000 cc' '1,500 cc' '1,496 cc'
#  '1,533 cc' '1 cc' '1,599 cc' '1,995 cc' '1,461 cc' '1,618 cc' '1,149 cc'
#  '1,199 cc' '898 cc' '890 cc' '900 cc' '54 cc' '1,100 cc' '1,333 cc'
#  '899 cc' '1,589 cc' '1,580 cc' '1,997 cc' '160 cc' '1,800 cc']
# ----------------------------------------
# 1 cc          36
# 1,000 cc      40
# 1,100 cc       1
# 1,149 cc     288
# 1,195 cc       1
#             ...
# 996 cc         1
# 997 cc         4
# 998 cc        72
# 999 cc      2438
# NaN          496
# Name: displacement, Length: 78, dtype: int64
# ----------------------------------------
# 1,598 cc    4761
# 999 cc      2438
# 1,398 cc    1314
# 1,399 cc     749
# 1,229 cc     677
#             ...
# 122 cc         1
# 1,198 cc       1
# 1,195 cc       1
# 2,967 cc       1
# 1,800 cc       1
# Name: displacement, Length: 78, dtype: int64
# ################################################################################

# %%
df["displacement"].str.contains("cc").value_counts(dropna=False)
# Out:
# True    15423
# NaN       496
# Name: displacement, dtype: int64

# %%
df["engine_size"] = df["displacement"].str.replace(",","").str.extract("(\d+)").astype(float)

# %%
for i in df.select_dtypes(include="O").columns:
    if df[df["engine_size"].isnull()][i].str.contains("\w+-(\d-\d)-", regex=True).any():
        print(i)
# Out:
# url

# %%
df[df["engine_size"].isnull()][df[df["engine_size"].isnull()]["url"].str.contains("-\d-\d-", regex=True) == True]["url"].unique()
# Out:
# array(['https://www.autoscout24.com//offers/audi-a1-1-6-tdi-metal-plus-s-tronic-bi-color-navi-xeno-diesel-black-2db3a838-ee5a-457d-853d-a88d77cd3426',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-sportback-1-4-tdi-s-tronic-adrenalin2-diesel-grey-8bbc9cf9-2598-4f9b-a6cb-35e6d48c12b3',
#        'https://www.autoscout24.com//offers/audi-a1-spb-1-6-tdi-116-cv-s-tronic-diesel-white-4adfa6f2-1721-40a0-a505-bb9af9f435cd',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-sportback-1-0-tfsi-95cv-attraction-gasoline-black-7e4808de-7057-4ea6-9580-50af607954bd',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-ultra-5deurs-2016-46580-kms-diesel-black-0842913d-77a9-44fa-a7ef-7a851984018c',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-1-0-tfsi-95ch-adrenalin-s-tronic-7-gasoline-red-1a964d44-2688-46b7-9d56-ab891f529d46',
#        'https://www.autoscout24.com//offers/audi-a1-adrenalin-1-4-tdi-66kw-90cv-sportback-somos-conc-diesel-black-1929a121-e7c3-4f1b-b60b-ed6731d76747',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-90-gps-tel-clim-1main-diesel-white-4f5c7eb0-fe5f-4f58-8ff2-e5816fbdfe12',
#        'https://www.autoscout24.com//offers/audi-a1-adrenalin-1-0-tfsi-70kw-95cv-sportback-gasoline-black-c3d933b0-db46-4943-af80-e71f1b472ec1',
#        'https://www.autoscout24.com//offers/audi-a1-1-6-tdi-drive-select-klimaauto-pdc-shzg-diesel-black-b14a7962-ba88-4961-a3d5-bc510f67bba8',
#        'https://www.autoscout24.com//offers/audi-a1-audi-a1-sport-1-0-tfsi-pacchetto-media-retro-epc-gasoline-silver-577073f9-2ad7-43ad-b4aa-85195ad5ca5d',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-a1-sportback-1-0-tfsi-ultra-95-s-tronic-gasoline-8258f0b0-b787-4b11-a9eb-6f506a557d60',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-a1-sportback-1-0-tfsi-ultra-95-s-tronic-gasoline-black-c47cbc01-63f6-4b36-bc11-a9d91de88c32',
#        'https://www.autoscout24.com//offers/audi-a1-sportback-a1-sportback-1-0-tfsi-ultra-95-s-tronic-gasoline-white-99b9c9d4-54b8-4624-bd8e-3b5b72b099ab',
#        'https://www.autoscout24.com//offers/audi-a1-adrenalin-1-0-tfsi-70kw-95cv-sportback-gasoline-36e7e4a6-d512-4de3-89a2-0964cb303c3d',
#        'https://www.autoscout24.com//offers/audi-a1-1-0-82-cv-tfsi-neopatentati-gasoline-black-af14cb31-0e51-43aa-9008-2dd8e195f96b',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-zen-surequipe-diesel-white-810c8710-0e61-4537-beda-bd721f596830',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-zen-surequipee-diesel-e01a5e79-e93e-4a0f-bd12-091e148df0e1',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-intens-diesel-white-13a8a053-a693-422b-aabe-23172177a83d',
#        'https://www.autoscout24.com//offers/renault-espace-1-6-dci-160ch-energy-intens-edc-surequipe-diesel-grey-bd750cfb-94bb-4375-b370-327aadf50acd',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-intens-diesel-grey-532d9e24-3f91-4732-99a3-b917bfd3b734',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-zen-diesel-black-ac3dbbbf-c4b9-4e6a-971b-810533203113',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-intens-surequipe-diesel-grey-cbf257b2-9a32-4308-83aa-93409ea1d99a',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-zen-diesel-black-54ef98d4-e843-4155-a202-7f4a685af725',
#        'https://www.autoscout24.com//offers/renault-espace-nouveau-1-6-dci-160-auto-intens-diesel-c1003a83-39b6-469c-8fe5-c79019367266',
#        'https://www.autoscout24.com//offers/renault-espace-1-6-dci-intense-automatica-tetto-7posti-diesel-grey-916f741e-40a6-4446-8c54-a24d1b5ec235',
#        'https://www.autoscout24.com//offers/renault-espace-v-1-6-dci-160ch-energy-intens-edc-import-diesel-grey-2e472f21-2981-4fe7-bdc2-01bf40f57c40',
#        'https://www.autoscout24.com//offers/renault-espace-v-1-6-bluedci-160cv-edc-initiale-paris-7pl-diesel-grey-c91a2c70-3198-48fb-8db2-eb97e7724983',
#        'https://www.autoscout24.com//offers/renault-espace-intens-energy-1-6-dci-160cv-edc-diesel-silver-39869312-4c19-4fae-92c0-65d56946dad5',
#        'https://www.autoscout24.com//offers/renault-espace-v-1-6-bluedci-160cv-edc-initiale-paris-7pl-diesel-white-0dae2f58-c705-456d-bb04-d945ca1ce804',
#        'https://www.autoscout24.com//offers/renault-espace-1-6-dci-160-cv-edc-intens-rif-fn573-diesel-black-56e58dfe-0603-45bb-8746-8d02c6f6726b',
#        'https://www.autoscout24.com//offers/renault-espace-1-6-dci-edc-initiale-paris-diesel-grey-8fade73e-2c82-40a7-9d50-5b88f04ad210'],
#       dtype=object)

# %%
df[df["engine_size"].isnull()][df[df["engine_size"].isnull()]["url"].str.contains("-\d-\d-", regex=True) == True]["url"].str.extract("\w+-(\d-\d)-")[0].str.replace("-","").astype(float)*100
# Out:
# 142      1600.0
# 191      1400.0
# 412      1600.0
# 505      1000.0
# 636      1400.0
#           ...
# 15472    1600.0
# 15477    1600.0
# 15496    1600.0
# 15573    1600.0
# 15706    1600.0
# Name: 0, Length: 320, dtype: float64

# %%
df.loc[df[df["engine_size"].isnull()][df[df["engine_size"].isnull()]["url"].str.contains("-\d-\d-", regex=True) == True].index, "engine_size"] = df[df["engine_size"].isnull()][df[df["engine_size"].isnull()]["url"].str.contains("-\d-\d-", regex=True) == True]["url"].str.extract("\w+-(\d-\d)-")[0].str.replace("-","").astype(float)*100

# %%
first_look("engine_size")
# Out:
# column name :  engine_size
# ----------------------------------------
# Per_of_Nulls   :  % 1.11
# Number of Nulls  :  176
# Number of Uniques:  79
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [1.4220e+03 1.7980e+03 1.5980e+03 9.9900e+02 1.3950e+03 9.2900e+02
#  1.6000e+03 1.4000e+03 1.5960e+03        nan 1.0000e+03 1.9840e+03
#  1.4980e+03 1.1970e+03 9.9500e+02 9.9800e+02 1.9680e+03 2.0000e+03
#  1.5680e+03 1.8960e+03 2.4800e+03 1.4990e+03 1.4950e+03 1.3980e+03
#  1.5840e+03 9.9700e+02 1.3990e+03 1.3640e+03 1.4900e+03 9.9600e+02
#  1.6960e+03 1.6860e+03 1.3960e+03 1.5898e+04 1.3900e+02 1.3680e+03
#  1.4000e+02 1.3970e+03 1.2480e+03 1.3000e+03 1.2290e+03 1.2000e+03
#  9.7300e+02 1.2390e+03 1.3500e+03 1.3690e+03 1.3900e+03 1.2200e+02
#  1.1980e+03 1.1950e+03 1.9560e+03 1.9980e+03 2.8000e+03 2.0000e+00
#  2.9670e+03 1.8560e+03 1.6000e+04 1.5000e+03 1.4960e+03 1.5330e+03
#  1.0000e+00 1.5990e+03 1.9950e+03 1.4610e+03 1.6180e+03 1.1490e+03
#  1.1990e+03 8.9800e+02 4.1000e+03 8.9000e+02 9.0000e+02 5.4000e+01
#  1.1000e+03 1.3330e+03 8.9900e+02 1.5890e+03 1.5800e+03 1.9970e+03
#  1.6000e+02 1.8000e+03]
# ----------------------------------------
# 1.0         36
# 2.0          2
# 54.0         1
# 122.0        1
# 139.0        4
#           ...
# 2967.0       1
# 4100.0       1
# 15898.0      1
# 16000.0      1
# NaN        176
# Name: engine_size, Length: 80, dtype: int64
# ----------------------------------------
# 1598.0    4761
# 999.0     2438
# 1398.0    1314
# 1399.0     749
# 1229.0     677
#           ...
# 1198.0       1
# 1195.0       1
# 2800.0       1
# 2967.0       1
# 1800.0       1
# Name: engine_size, Length: 80, dtype: int64
# ################################################################################

# %%
df.drop(columns="displacement", inplace=True)

# %% [markdown]
# ### cylinders

# %%
first_look("cylinders")
# Out:
# column name :  cylinders
# ----------------------------------------
# Per_of_Nulls   :  % 35.68
# Number of Nulls  :  5680
# Number of Uniques:  7
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['3' '4' nan '8' '5' '1' '6' '2']
# ----------------------------------------
# 1         1
# 2         2
# 3      2104
# 4      8105
# 5        22
# 6         3
# 8         2
# NaN    5680
# Name: cylinders, dtype: int64
# ----------------------------------------
# 4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64
# ################################################################################

# %%
df["cylinders"] = df["cylinders"].astype(float)

# %% [markdown]
# ### weight

# %%
first_look("weight")
# Out:
# column name :  weight
# ----------------------------------------
# Per_of_Nulls   :  % 43.81
# Number of Nulls  :  6974
# Number of Uniques:  434
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  
#  '1,277 kg' '1,717 kg' '1,139 kg' '1,054 kg' '1,152 kg' '1,279 kg'
#  '1,128 kg' '1,164 kg' '1,071 kg' '1,686 kg' '1,563 kg' '1,121 kg'
#  '1,087 kg' '1,092 kg' '1,059 kg' '1,052 kg' '1,194 kg' '1,058 kg'
#  '1,055 kg' '977 kg' '1,084 kg' '1,196 kg' '1,009 kg' '980 kg' '1,227 kg'
#  '1,224 kg' '1,057 kg' '1,030 kg' '1,711 kg' '1,082 kg' '1,204 kg'
#  '1,201 kg' '1,143 kg' '1,123 kg' '1,017 kg' '1,670 kg' '1,126 kg'
#  '900 kg' '1,267 kg' '1,189 kg' '1,566 kg' '1,091 kg' '1,127 kg'
#  '1,161 kg' '1,659 kg' '2,353 kg' '1,734 kg' '1,791 kg' '1,684 kg'
#  '1,648 kg' '2,471 kg' '1,634 kg' '1,609 kg' '2,410 kg' '1,819 kg'
#  '1,736 kg' '1,621 kg' '1,697 kg' '1,622 kg' '2,044 kg' '1,804 kg'
#  '1,515 kg' '1,761 kg' '1,779 kg' '1,708 kg' '1,758 kg' '1,724 kg'
#  '1,833 kg' '1,891 kg' '1,702 kg' '1,809 kg' '1,624 kg' '1,780 kg'
#  '1,797 kg' '1,647 kg' '1,939 kg' '1,608 kg' '1,847 kg' '2,037 kg']
# ----------------------------------------
# 1 kg           2
# 1,009 kg       1
# 1,010 kg       3
# 1,017 kg       1
# 1,030 kg       1
#             ...
# 840 kg         1
# 900 kg         1
# 977 kg         2
# 980 kg        11
# NaN         6974
# Name: weight, Length: 435, dtype: int64
# ----------------------------------------
# NaN         6974
# 1,163 kg     574
# 1,360 kg     356
# 1,165 kg     301
# 1,335 kg     242
#             ...
# 1,960 kg       1
# 1,258 kg       1
# 1,167 kg       1
# 1,331 kg       1
# 2,037 kg       1
# Name: weight, Length: 435, dtype: int64
# ################################################################################

# %%
#looking for the null values of weight in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["weight"].isnull()][i].str.contains("\d+ kg", regex=True).any():
        print(i)
#There is no column to get values
# Out:
# consumption

# %%
df[df["weight"].isnull()][df[df["weight"].isnull()]["consumption"].str.contains("\d+ kg", regex=True) == True]
# Out:
#                                                     url make_model  \
# 5161  https://www.autoscout24.com//offers/audi-a3-sp...    Audi A3
#
#                     short_description body_type  price             vat    km  \
# 5161  SPB 30 g-tron S tronic Business    Sedans  26900  VAT deductible  60.0
#
#      registration  prev_owner            type previous_owners next_inspection  \
# 5161   2019-05-01         NaN  Pre-registered             NaN             NaN
#
#      inspection_new   warranty full_service non_smoking_vehicle body_color  \
# 5161            NaN  24 months          NaN                 NaN       Grey
#
#      paint_type  nr_of_doors  nr_of_seats gearing_type  cylinders weight  \
# 5161   Metallic          5.0          5.0    Automatic        4.0    NaN
#
#      drive_chain fuel                                        consumption  \
# 5161       front  Gas  ['8.3 kg/100 km (comb)'],['10.5 kg/100 km (cit...
#
#            co_2_emission emission_class  \
# 5161  95 g CO2/km (comb)   Euro 6d-TEMP
#
#                                   comfort_&_convenience  \
# 5161  Air conditioning,Armrest,Automatic climate con...
#
#                                   entertainment_&_media  \
# 5161  Bluetooth,CD player,Hands-free equipment,On-bo...
#
#                           extras  \
# 5161  Alloy wheels,Voice Control
#
#                                       safety_&_security  emission_label gears  \
# 5161  ABS,Central door lock,Daytime running lights,D...  1 (No sticker)     7
#
#      country_version electricity_consumption last_service_date  \
# 5161             NaN                     NaN               NaN
#
#      other_fuel_types availability last_timing_belt_service_date  \
# 5161              NaN          NaN                           NaN
#
#      available_from consumption_comb consumption_city consumption_country  \
# 5161            NaN              8.3             10.5                 6.9
#
#       hp_kw  Particulate_Filter inspection_time  inspection_situation  \
# 5161   96.0                   0             NaT                     0
#
#       warranty_month  co2_emission_gr upholstery_type upholstery_color  \
# 5161            24.0             95.0           Cloth             Grey
#
#       engine_size
# 5161       1498.0

# %%
df["weight"] = df["weight"].str.replace(",","").str.extract("(\d+)").astype(float)

# %% [markdown]
# ### drive_chain

# %%
first_look("drive_chain")
# Out:
# column name :  drive_chain
# ----------------------------------------
# Per_of_Nulls   :  % 43.08
# Number of Nulls  :  6858
# Number of Uniques:  3
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['front' nan '4WD' 'rear']
# ----------------------------------------
# 4WD       171
# front    8886
# rear        4
# NaN      6858
# Name: drive_chain, dtype: int64
# ----------------------------------------
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64
# ################################################################################

# %% [markdown]
# ### emission_class

# %%
first_look("emission_class")
# Out:
# column name :  emission_class
# ----------------------------------------
# Per_of_Nulls   :  % 18.98
# Number of Nulls  :  3021
# Number of Uniques:  7
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Euro 6' nan 'Euro 5' 'Euro 6d-TEMP' '[],[],[]' 'Euro 6c' 'Euro 4'
#  'Euro 6d']
# ----------------------------------------
# Euro 4             40
# Euro 5             78
# Euro 6          10139
# Euro 6c           127
# Euro 6d            62
# Euro 6d-TEMP     1845
# [],[],[]          607
# NaN              3021
# Name: emission_class, dtype: int64
# ----------------------------------------
# Euro 6          10139
# NaN              3021
# Euro 6d-TEMP     1845
# [],[],[]          607
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64
# ################################################################################

# %%
df.loc[df[~(df["emission_class"].str.contains("Euro")==True)].index,"emission_class"] = np.nan

# %%
for i in df.select_dtypes(include="O").columns:
    if df[df["emission_class"].isnull()][i].str.contains("Euro \d", regex=True).any():
        print(i)
# Out:
# short_description
# inspection_new
# warranty
# full_service
# non_smoking_vehicle
# last_service_date

# %%
for i in df.select_dtypes(include="O").columns:
    if df[df["emission_class"].isnull()][i].str.contains("Euro \d", regex=True).any():
        df.loc[df[df["emission_class"].isnull()][df[df["emission_class"].isnull()][i].str.contains("Euro \d", regex=True) == True].index, "emission_class"] = df[df["emission_class"].isnull()][df[df["emission_class"].isnull()][i].str.contains("Euro \d", regex=True) == True][i].str.extract("(Euro \d+.*)")[0]

# %%
df["emission_class"] = df["emission_class"].str.extract("(Euro \d\w?|\d\w-TEMP)")

# %%
first_look("emission_class")
# Out:
# column name :  emission_class
# ----------------------------------------
# Per_of_Nulls   :  % 18.34
# Number of Nulls  :  2920
# Number of Uniques:  5
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Euro 6' nan 'Euro 5' 'Euro 6d' 'Euro 6c' 'Euro 4']
# ----------------------------------------
# Euro 4        40
# Euro 5        78
# Euro 6     10625
# Euro 6c      135
# Euro 6d     2121
# NaN         2920
# Name: emission_class, dtype: int64
# ----------------------------------------
# Euro 6     10625
# NaN         2920
# Euro 6d     2121
# Euro 6c      135
# Euro 5        78
# Euro 4        40
# Name: emission_class, dtype: int64
# ################################################################################

# %% [markdown]
# ### comfort_&_convenience	& entertainment_&_media	& extras & safety_&_security & description

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/]['''):
    """
    exclude  - satırlar da kategori ayırım yerleri
    pattern  - satırdaki veriyi ayırma regex
    strip    - alakasız işaretleri kaldırma
    """
    import re
    column = Series.dropna().apply(str).str.strip(strip)
    diff_value = list()
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
first_look("comfort_&_convenience")
# Out:
# column name :  comfort_&_convenience
# ----------------------------------------
# Per_of_Nulls   :  % 5.78
# Number of Nulls  :  920
# Number of Uniques:  6198
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system'
#  'Air conditioning,Automatic climate control,Hill Holder,Leather steering wheel,Lumbar support,Parking assist system sensors rear,Power windows,Start-stop system,Tinted windows'
#  'Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Seat heating,Start-stop system'
#  ...
#  'Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Panorama roof,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system,Sunroof'
#  'Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Massage seats,Multi-function steering wheel,Navigation system,Panorama roof,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system'
#  'Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof']
# ----------------------------------------
# Air conditioning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   79
# Air conditioning,Air suspension,Armrest,Automatic climate control,Auxiliary heating,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Split rear seats,Start-stop system,Tinted windows,Wind deflector                                                                                                                                                                                                                                   1
# Air conditioning,Air suspension,Armrest,Automatic climate control,Auxiliary heating,Cruise control,Electrically adjustable seats,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Leather seats,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Panorama roof,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Seat ventilation,Split rear seats,Start-stop system,Sunroof,Tinted windows                                                               1
# Air conditioning,Air suspension,Armrest,Automatic climate control,Auxiliary heating,Cruise control,Electrically adjustable seats,Electrical side mirrors,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system self-steering,Power windows,Rain sensor,Seat heating,Seat ventilation,Split rear seats,Start-stop system,Tinted windows                                                                                                                                                                                                           1
# Air conditioning,Air suspension,Armrest,Automatic climate control,Auxiliary heating,Cruise control,Electrically adjustable seats,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Massage seats,Multi-function steering wheel,Navigation system,Panorama roof,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Split rear seats,Start-stop system,Sunroof,Tinted windows      1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Power windows,Seat ventilation,Split rear seats                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    11
# Power windows,Start-stop system                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     4
# Rain sensor                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Sunroof                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             8
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               920
# Name: comfort_&_convenience, Length: 6199, dtype: int64
# ----------------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               134
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                       130
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                   105
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Split rear seats,Start-stop system,Tinted windows                                                                                                                                                                                                           1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof                                                                                                1
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Split rear seats,Start-stop system,Tinted windows                                                                                                                 1
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating                                                                                                                                                                                                                1
# Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof      1
# Name: comfort_&_convenience, Length: 6199, dtype: int64
# ################################################################################

# %%
get_diff_category_column(df["comfort_&_convenience"])
# Out:
# {0: 'Air conditioning',
#  1: 'Air suspension',
#  2: 'Armrest',
#  3: 'Automatic climate control',
#  4: 'Auxiliary heating',
#  5: 'Cruise control',
#  6: 'Electric Starter',
#  7: 'Electric tailgate',
#  8: 'Electrical side mirrors',
#  9: 'Electrically adjustable seats',
#  10: 'Electrically heated windshield',
#  11: 'Heads-up display',
#  12: 'Heated steering wheel',
#  13: 'Hill Holder',
#  14: 'Keyless central door lock',
#  15: 'Leather seats',
#  16: 'Leather steering wheel',
#  17: 'Light sensor',
#  18: 'Lumbar support',
#  19: 'Massage seats',
#  20: 'Multi-function steering wheel',
#  21: 'Navigation system',
#  22: 'Panorama roof',
#  23: 'Park Distance Control',
#  24: 'Parking assist system camera',
#  25: 'Parking assist system self-steering',
#  26: 'Parking assist system sensors front',
#  27: 'Parking assist system sensors rear',
#  28: 'Power windows',
#  29: 'Rain sensor',
#  30: 'Seat heating',
#  31: 'Seat ventilation',
#  32: 'Split rear seats',
#  33: 'Start-stop system',
#  34: 'Sunroof',
#  35: 'Tinted windows',
#  36: 'Wind deflector',
#  37: 'Windshield'}

# %%
first_look("entertainment_&_media")
# Out:
# column name :  entertainment_&_media
# ----------------------------------------
# Per_of_Nulls   :  % 8.63
# Number of Nulls  :  1374
# Number of Uniques:  346
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Bluetooth,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,Hands-free equipment,On-board computer,Radio,Sound system'
#  'MP3,On-board computer'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'CD player,MP3,Radio' 'Radio' nan
#  'CD player,Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,On-board computer,Radio'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Radio,Sound system'
#  'Bluetooth,CD player,MP3,On-board computer,Radio,USB'
#  'On-board computer,Radio' 'CD player,MP3,Radio,Sound system,USB'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Radio'
#  'CD player,MP3,On-board computer,Radio' 'Bluetooth,CD player' 'CD player'
#  'CD player,On-board computer,Radio'
#  'Bluetooth,CD player,On-board computer,Radio' 'MP3,Radio'
#  'Bluetooth,Hands-free equipment,On-board computer'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,USB'
#  'CD player,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,MP3,On-board computer'
#  'Bluetooth,Hands-free equipment,MP3,Radio'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,USB'
#  'CD player,MP3,On-board computer,Radio,USB'
#  'Bluetooth,CD player,MP3,Radio,Sound system,USB' 'Bluetooth,Radio'
#  'Bluetooth,Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,CD player,MP3,On-board computer,Radio'
#  'MP3,On-board computer,Radio'
#  'Bluetooth,Hands-free equipment,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,MP3,On-board computer,USB'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,Sound system'
#  'Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,MP3'
#  'Bluetooth,CD player,Hands-free equipment,MP3,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,Radio,Sound system'
#  'CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Sound system'
#  'CD player,On-board computer,Radio,Sound system'
#  'CD player,Hands-free equipment,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Hands-free equipment,MP3,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio'
#  'CD player,Hands-free equipment,Radio,USB'
#  'Bluetooth,MP3,On-board computer,Radio'
#  'CD player,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,MP3,On-board computer,Radio,Sound system,USB' 'Bluetooth,MP3'
#  'Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,Hands-free equipment,On-board computer,USB' 'CD player,Radio'
#  'CD player,On-board computer' 'Bluetooth,Hands-free equipment,Radio'
#  'On-board computer'
#  'Bluetooth,CD player,Digital radio,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer'
#  'Bluetooth,CD player,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'CD player,Hands-free equipment,MP3,On-board computer,Radio'
#  'Bluetooth,CD player,Hands-free equipment,Radio'
#  'CD player,MP3,On-board computer,Radio,Sound system,USB'
#  'CD player,Hands-free equipment,On-board computer,Sound system,USB'
#  'Bluetooth,CD player,Radio'
#  'Bluetooth,CD player,MP3,On-board computer,USB'
#  'Bluetooth,Radio,Sound system' 'CD player,Hands-free equipment'
#  'Bluetooth,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,Radio,Sound system'
#  'Bluetooth,CD player,On-board computer'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Sound system,USB'
#  'CD player,MP3,On-board computer' 'Bluetooth'
#  'Bluetooth,CD player,On-board computer,Radio,USB'
#  'CD player,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,Radio,Sound system,USB'
#  'Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,USB'
#  'Bluetooth,Hands-free equipment,On-board computer,Sound system'
#  'CD player,Digital radio,Hands-free equipment,MP3,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,Radio,USB'
#  'Bluetooth,Hands-free equipment,Radio,Sound system'
#  'CD player,Radio,Sound system' 'Bluetooth,CD player,Hands-free equipment'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Sound system'
#  'On-board computer,Radio,USB' 'Hands-free equipment'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Digital radio,MP3,Radio,USB'
#  'Bluetooth,Digital radio,On-board computer,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,On-board computer'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,Radio,Sound system'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,Radio'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Sound system'
#  'Bluetooth,Digital radio,MP3,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,Radio,Sound system,USB'
#  'MP3,On-board computer,Radio,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Sound system'
#  'Hands-free equipment,On-board computer,Sound system'
#  'Hands-free equipment,Radio'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio'
#  'Bluetooth,MP3,On-board computer,Radio,USB'
#  'Bluetooth,Radio,Sound system,USB'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio'
#  'Bluetooth,CD player,MP3,Radio'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,Radio,USB'
#  'CD player,Digital radio,MP3,On-board computer,Radio'
#  'Digital radio,MP3,Radio'
#  'CD player,Digital radio,On-board computer,Radio,USB'
#  'CD player,Digital radio,Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,MP3,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,Radio'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system'
#  'CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'CD player,Digital radio,MP3,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Sound system'
#  'CD player,Digital radio,MP3'
#  'Hands-free equipment,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,USB'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,USB'
#  'CD player,Digital radio,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,On-board computer,Radio,Sound system'
#  'Bluetooth,Hands-free equipment,MP3,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,MP3,Sound system,USB'
#  'Bluetooth,Radio,USB'
#  'Bluetooth,CD player,On-board computer,Radio,Sound system,USB'
#  'Sound system' 'CD player,Hands-free equipment,Radio,Sound system'
#  'Bluetooth,Hands-free equipment,Sound system,USB'
#  'MP3,On-board computer,USB' 'Bluetooth,MP3,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,Radio,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'MP3,USB' 'Bluetooth,Hands-free equipment'
#  'Bluetooth,Hands-free equipment,On-board computer,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,Sound system'
#  'Digital radio,On-board computer,Radio,USB'
#  'Bluetooth,CD player,Hands-free equipment,Sound system,USB'
#  'Hands-free equipment,Sound system'
#  'Hands-free equipment,MP3,On-board computer,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system'
#  'Bluetooth,Hands-free equipment,MP3,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Sound system'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,Radio,USB'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,Television,USB'
#  'CD player,On-board computer,Radio,USB'
#  'Bluetooth,Digital radio,On-board computer,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Sound system,USB'
#  'Digital radio,Hands-free equipment,On-board computer,Radio,USB'
#  'Digital radio,Hands-free equipment,MP3,On-board computer,Radio,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,USB'
#  'Bluetooth,Digital radio' 'Bluetooth,MP3,Radio'
#  'Bluetooth,Digital radio,MP3,On-board computer,Radio'
#  'CD player,Hands-free equipment,Radio'
#  'Bluetooth,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,USB'
#  'Bluetooth,CD player,Radio,USB'
#  'Hands-free equipment,On-board computer,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment'
#  'Bluetooth,Digital radio,Hands-free equipment,Sound system,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Sound system,USB'
#  'On-board computer,Sound system'
#  'Bluetooth,Hands-free equipment,Sound system' 'CD player,Radio,USB'
#  'CD player,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,On-board computer,Radio,USB'
#  'Bluetooth,Hands-free equipment,USB' 'Bluetooth,MP3,On-board computer'
#  'Bluetooth,On-board computer,Radio,Sound system'
#  'On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,On-board computer,USB'
#  'CD player,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,On-board computer,USB' 'Bluetooth,On-board computer,Radio,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB'
#  'Bluetooth,MP3,On-board computer,Radio,Television,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,USB'
#  'CD player,MP3,On-board computer,USB' 'CD player,MP3,Radio,USB'
#  'Bluetooth,Hands-free equipment,MP3,Radio,Sound system,USB'
#  'Bluetooth,MP3,Radio,Sound system'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,USB'
#  'CD player,Hands-free equipment,On-board computer'
#  'Bluetooth,CD player,On-board computer,Sound system' 'CD player,MP3'
#  'CD player,On-board computer,USB'
#  'Bluetooth,Digital radio,On-board computer,Radio,Sound system'
#  'Bluetooth,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment'
#  'CD player,Hands-free equipment,On-board computer,USB'
#  'Bluetooth,CD player,MP3,Radio,Sound system'
#  'Digital radio,On-board computer,Radio'
#  'Bluetooth,CD player,Hands-free equipment,USB'
#  'Bluetooth,Digital radio,On-board computer'
#  'CD player,Digital radio,On-board computer,USB'
#  'Bluetooth,CD player,Digital radio,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB'
#  'CD player,Hands-free equipment,MP3,Radio'
#  'Bluetooth,CD player,Digital radio,MP3,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,MP3,On-board computer,USB'
#  'CD player,On-board computer,Sound system'
#  'Bluetooth,CD player,MP3,Radio,USB'
#  'Bluetooth,CD player,On-board computer,USB'
#  'Bluetooth,CD player,Digital radio,On-board computer,Radio'
#  'Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'CD player,Hands-free equipment,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,Radio,Sound system,USB' 'USB'
#  'Bluetooth,Digital radio,Hands-free equipment,USB'
#  'CD player,Digital radio,MP3,On-board computer,Radio,USB'
#  'Hands-free equipment,On-board computer'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,Radio,Sound system,USB'
#  'CD player,Hands-free equipment,On-board computer,Sound system'
#  'Bluetooth,Digital radio,MP3,On-board computer,Radio,Sound system,USB'
#  'Hands-free equipment,Radio,USB'
#  'CD player,Hands-free equipment,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,Radio,Sound system,USB'
#  'MP3,Radio,Sound system'
#  'Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Sound system,USB'
#  'Bluetooth,Sound system'
#  'Bluetooth,Digital radio,Hands-free equipment,Radio'
#  'CD player,Digital radio,Hands-free equipment,Radio,USB'
#  'On-board computer,USB'
#  'Digital radio,Hands-free equipment,On-board computer,Radio'
#  'Bluetooth,Digital radio,On-board computer,Radio,Television,USB'
#  'Digital radio,Hands-free equipment,MP3,On-board computer,Radio'
#  'Bluetooth,Digital radio,Radio' 'Bluetooth,CD player,Digital radio,Radio'
#  'Bluetooth,CD player,MP3,USB'
#  'Bluetooth,Digital radio,On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Sound system,Television,USB'
#  'CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio'
#  'Hands-free equipment,On-board computer,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Radio,Television,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,Radio,USB'
#  'Bluetooth,On-board computer,Sound system,USB'
#  'Digital radio,MP3,On-board computer,Radio,USB'
#  'Digital radio,Hands-free equipment,MP3,On-board computer,USB'
#  'Digital radio,On-board computer'
#  'CD player,Digital radio,On-board computer,Radio'
#  'Bluetooth,CD player,Digital radio,On-board computer'
#  'Bluetooth,CD player,USB'
#  'Digital radio,Hands-free equipment,On-board computer,USB'
#  'Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,Television,USB'
#  'Radio,USB' 'Bluetooth,CD player,Digital radio,Radio,USB'
#  'Bluetooth,MP3,USB' 'MP3,On-board computer,Radio,Sound system'
#  'CD player,USB' 'Bluetooth,CD player,Radio,Sound system,USB'
#  'Bluetooth,CD player,MP3'
#  'Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,Television,USB'
#  'On-board computer,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,MP3,USB'
#  'CD player,Digital radio,Radio' 'Bluetooth,Sound system,USB'
#  'Hands-free equipment,MP3,On-board computer,Radio'
#  'Bluetooth,MP3,On-board computer,Sound system,USB'
#  'MP3,On-board computer,Radio,Sound system,USB' 'MP3'
#  'Digital radio,Radio' 'Bluetooth,MP3,Radio,Sound system,USB'
#  'MP3,Radio,Sound system,USB'
#  'CD player,Hands-free equipment,MP3,Radio,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,Radio'
#  'Bluetooth,CD player,Digital radio,On-board computer,Radio,Sound system,USB'
#  'CD player,MP3,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Sound system,Television,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer'
#  'CD player,Hands-free equipment,MP3,On-board computer'
#  'CD player,Hands-free equipment,MP3,On-board computer,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Sound system,Television,USB'
#  'Hands-free equipment,MP3,Radio,USB' 'Hands-free equipment,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,On-board computer,Sound system,USB'
#  'Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,USB'
#  'Digital radio,Radio,USB' 'Digital radio,MP3,On-board computer,Radio'
#  'Digital radio,Hands-free equipment' 'Digital radio'
#  'Radio,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,MP3,On-board computer,Radio,Sound system'
#  'Digital radio,On-board computer,USB'
#  'Bluetooth,Digital radio,Radio,Sound system,USB'
#  'Bluetooth,Digital radio,Radio,USB'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,USB'
#  'Hands-free equipment,MP3,On-board computer,Sound system,USB'
#  'Bluetooth,Digital radio,USB'
#  'Hands-free equipment,MP3,On-board computer' 'Sound system,USB'
#  'Bluetooth,Digital radio,On-board computer,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,Sound system,USB'
#  'Bluetooth,Digital radio,On-board computer,Sound system'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Sound system,Television,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,Radio,Sound system,Television,USB'
#  'Digital radio,Sound system,USB'
#  'Bluetooth,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Television,USB'
#  'Bluetooth,CD player,On-board computer,Sound system,USB'
#  'On-board computer,Sound system,USB' 'Bluetooth,Digital radio,MP3,Radio'
#  'Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,USB'
#  'Hands-free equipment,MP3,Radio,Sound system,USB'
#  'Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,Television,USB'
#  'Bluetooth,Digital radio,MP3,Sound system,USB'
#  'Bluetooth,Digital radio,MP3,On-board computer,Sound system,USB'
#  'Digital radio,Sound system' 'MP3,Radio,USB'
#  'CD player,Hands-free equipment,On-board computer,Radio,Sound system,Television'
#  'Bluetooth,Digital radio,MP3,Radio,USB'
#  'Digital radio,Hands-free equipment,On-board computer,Radio,Sound system'
#  'Digital radio,USB' 'Digital radio,Hands-free equipment,Radio'
#  'CD player,Digital radio,Hands-free equipment,On-board computer,Radio,Sound system,Television,USB'
#  'Digital radio,MP3,On-board computer,Radio,Sound system,USB'
#  'Digital radio,On-board computer,Sound system']
# ----------------------------------------
# Bluetooth                                                                                           125
# Bluetooth,CD player                                                                                  14
# Bluetooth,CD player,Digital radio,Hands-free equipment                                                1
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio                   25
# Bluetooth,CD player,Digital radio,Hands-free equipment,MP3,On-board computer,Radio,Sound system      20
#                                                                                                    ...
# Radio,USB                                                                                            29
# Sound system                                                                                         15
# Sound system,USB                                                                                     12
# USB                                                                                                  46
# NaN                                                                                                1374
# Name: entertainment_&_media, Length: 347, dtype: int64
# ----------------------------------------
# NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# CD player,Hands-free equipment,MP3,Radio,USB                                                           1
# MP3,Radio,Sound system,USB                                                                             1
# Bluetooth,MP3,On-board computer,Radio,Television,USB                                                   1
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB       1
# Name: entertainment_&_media, Length: 347, dtype: int64
# ################################################################################

# %%
get_diff_category_column(df["entertainment_&_media"])
# Out:
# {0: 'Bluetooth',
#  1: 'CD player',
#  2: 'Digital radio',
#  3: 'Hands-free equipment',
#  4: 'MP3',
#  5: 'On-board computer',
#  6: 'Radio',
#  7: 'Sound system',
#  8: 'Television',
#  9: 'USB'}

# %%
first_look("extras")
# Out:
# column name :  extras
# ----------------------------------------
# Per_of_Nulls   :  % 18.61
# Number of Nulls  :  2962
# Number of Uniques:  659
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['Alloy wheels,Catalytic Converter,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Voice Control' 'Alloy wheels,Sport seats,Voice Control'
#  'Alloy wheels,Sport package,Sport suspension,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension' 'Alloy wheels'
#  nan 'Alloy wheels,Shift paddles' 'Alloy wheels,Sport seats'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension'
#  'Alloy wheels,Sport package,Sport seats' 'Alloy wheels,Sport package'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Winter tyres' 'Alloy wheels,Catalytic Converter'
#  'Catalytic Converter' 'Alloy wheels,Sport suspension'
#  'Catalytic Converter,Sport suspension,Voice Control'
#  'Alloy wheels,Touch screen,Voice Control'
#  'Catalytic Converter,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Shift paddles,Voice Control'
#  'Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport seats'
#  'Catalytic Converter,Sport seats,Sport suspension'
#  'Alloy wheels,Sport package,Winter tyres'
#  'Alloy wheels,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles'
#  'Alloy wheels,Sport package,Sport suspension'
#  'Alloy wheels,Sport package,Voice Control' 'Sport seats'
#  'Alloy wheels,Cab or rented Car'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport suspension,Voice Control'
#  'Alloy wheels,Voice Control,Winter tyres'
#  'Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats'
#  'Alloy wheels,Sport package,Sport seats,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport seats'
#  'Alloy wheels,Roof rack,Sport seats' 'Voice Control'
#  'Alloy wheels,Sport suspension,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport suspension,Voice Control'
#  'Catalytic Converter,Sport package'
#  'Alloy wheels,Handicapped enabled,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Handicapped enabled,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport package,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Tuned car,Winter tyres'
#  'Winter tyres' 'Ski bag,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport package'
#  'Alloy wheels,Catalytic Converter,Sport seats,Touch screen'
#  'Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Sport suspension,Winter tyres'
#  'Catalytic Converter,Voice Control'
#  'Alloy wheels,Sport suspension,Voice Control'
#  'Alloy wheels,Sport package,Sport suspension,Winter tyres'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Trailer hitch' 'Alloy wheels,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport suspension,Touch screen'
#  'Alloy wheels,Sport suspension,Touch screen,Tuned car'
#  'Roof rack,Sport seats'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Shift paddles,Touch screen'
#  'Alloy wheels,Shift paddles,Sport package,Sport suspension,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Sport seats,Voice Control' 'Alloy wheels,Cab or rented Car,Sport seats'
#  'Cab or rented Car,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport seats,Voice Control'
#  'Catalytic Converter,Sport seats'
#  'Catalytic Converter,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport seats,Voice Control'
#  'Alloy wheels,Cab or rented Car,Sport seats,Sport suspension,Voice Control'
#  'Sport package'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Touch screen'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport suspension,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport package,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Voice Control'
#  'Alloy wheels,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Sport suspension,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport package,Sport suspension'
#  'Alloy wheels,Sport package,Sport seats,Voice Control,Winter tyres'
#  'Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport suspension'
#  'Cab or rented Car,Catalytic Converter,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Touch screen' 'Ski bag'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Voice Control'
#  'Cab or rented Car'
#  'Alloy wheels,Catalytic Converter,Touch screen,Voice Control'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Shift paddles,Sport seats'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Touch screen,Voice Control'
#  'Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Shift paddles,Sport package,Sport seats'
#  'Alloy wheels,Shift paddles,Sport package'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Voice Control'
#  'Cab or rented Car,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Cab or rented Car,Catalytic Converter,Voice Control'
#  'Alloy wheels,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Cab or rented Car,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Sport package,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Sport package,Sport seats'
#  'Alloy wheels,Shift paddles,Sport seats,Touch screen'
#  'Sport package,Sport seats,Sport suspension' 'Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport seats,Touch screen,Voice Control'
#  'Catalytic Converter,Sport package,Sport suspension'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport seats,Touch screen,Voice Control'
#  'Catalytic Converter,Touch screen'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Winter tyres'
#  'Catalytic Converter,Winter tyres'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension'
#  'Alloy wheels,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Shift paddles,Sport package,Voice Control'
#  'Alloy wheels,Roof rack'
#  'Alloy wheels,Roof rack,Sport package,Sport seats'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Winter tyres'
#  'Alloy wheels,Ski bag,Sport seats'
#  'Alloy wheels,Catalytic Converter,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Sport package,Trailer hitch'
#  'Alloy wheels,Roof rack,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Sport package'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Roof rack,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Shift paddles,Ski bag,Sport package,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Voice Control'
#  'Alloy wheels,Roof rack,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Sport seats,Sport suspension,Trailer hitch,Winter tyres'
#  'Roof rack,Shift paddles,Trailer hitch'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Ski bag,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Touch screen,Winter tyres'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Sport package,Sport seats,Touch screen,Voice Control'
#  'Roof rack' 'Alloy wheels,Sport package,Trailer hitch'
#  'Alloy wheels,Sport package,Sport seats,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport seats'
#  'Alloy wheels,Handicapped enabled'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Trailer hitch'
#  'Roof rack,Trailer hitch' 'Roof rack,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Voice Control'
#  'Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Ski bag,Sport package,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Trailer hitch'
#  'Alloy wheels,Sport package,Sport suspension,Trailer hitch'
#  'Alloy wheels,Trailer hitch,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Ski bag,Sport suspension'
#  'Alloy wheels,Touch screen,Trailer hitch'
#  'Alloy wheels,Roof rack,Trailer hitch'
#  'Alloy wheels,Sport package,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Tuned car'
#  'Alloy wheels,Catalytic Converter,Roof rack'
#  'Catalytic Converter,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Sport seats,Trailer hitch'
#  'Alloy wheels,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Tuned car,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Handicapped enabled,Sport package,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Shift paddles,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Ski bag,Sport seats,Voice Control'
#  'Alloy wheels,Shift paddles,Sport seats,Voice Control'
#  'Alloy wheels,Sport package,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Trailer hitch,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport package,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Trailer hitch'
#  'Alloy wheels,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension,Tuned car,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Sliding door,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport package'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Roof rack'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Roof rack,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Roof rack,Sport seats,Trailer hitch'
#  'Alloy wheels,Roof rack,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Ski bag'
#  'Alloy wheels,Roof rack,Shift paddles'
#  'Alloy wheels,Roof rack,Sport package,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Sport package,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport package'
#  'Alloy wheels,Catalytic Converter,Roof rack,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Handicapped enabled,Ski bag,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Sport suspension'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Winter tyres'
#  'Alloy wheels,Ski bag,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Sport suspension'
#  'Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport suspension,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Trailer hitch,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Right hand drive,Ski bag,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport suspension,Voice Control'
#  'Cab or rented Car,Catalytic Converter'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Roof rack,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Ski bag,Voice Control'
#  'Alloy wheels,Ski bag,Sport package,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Sport suspension'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Catalytic Converter,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport suspension,Voice Control,Winter tyres'
#  'Cab or rented Car,Roof rack'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Sport package,Sport seats,Touch screen,Tuned car,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Ski bag,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Trailer hitch'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Voice Control,Winter tyres'
#  'Catalytic Converter,Roof rack,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package'
#  'Shift paddles' 'Roof rack,Sport suspension'
#  'Alloy wheels,Roof rack,Touch screen'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport seats,Sport suspension'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Touch screen'
#  'Alloy wheels,Handicapped enabled,Shift paddles'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats'
#  'Alloy wheels,Ski bag,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport suspension'
#  'Alloy wheels,Handicapped enabled,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension'
#  'Alloy wheels,Roof rack,Touch screen,Trailer hitch,Voice Control'
#  'Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Touch screen,Voice Control'
#  'Roof rack,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Ski bag,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Sport seats,Touch screen'
#  'Roof rack,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Trailer hitch,Winter tyres'
#  'Alloy wheels,Roof rack,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Roof rack,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Touch screen,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Touch screen,Voice Control,Winter tyres'
#  'Catalytic Converter,Roof rack,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Ski bag,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Catalytic Converter,Sport package,Sport seats'
#  'Alloy wheels,Catalytic Converter,Roof rack,Trailer hitch,Voice Control'
#  'Sport seats,Touch screen,Voice Control'
#  'Catalytic Converter,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Touch screen,Winter tyres'
#  'Catalytic Converter,Roof rack,Touch screen'
#  'Alloy wheels,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Handicapped enabled,Touch screen'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Touch screen,Voice Control'
#  'Catalytic Converter,Roof rack,Sport package,Touch screen,Voice Control'
#  'Catalytic Converter,Roof rack' 'Alloy wheels,Touch screen,Winter tyres'
#  'Roof rack,Ski bag,Touch screen,Voice Control'
#  'Catalytic Converter,Roof rack,Voice Control'
#  'Roof rack,Sport seats,Voice Control' 'Ski bag,Touch screen'
#  'Alloy wheels,Right hand drive,Sport package,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Voice Control,Winter tyres'
#  'Roof rack,Touch screen,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport suspension'
#  'Sport seats,Trailer hitch' 'Roof rack,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Trailer hitch,Winter tyres'
#  'Touch screen,Winter tyres'
#  'Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Catalytic Converter,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Trailer hitch'
#  'Touch screen,Voice Control,Winter tyres'
#  'Catalytic Converter,Roof rack,Winter tyres'
#  'Catalytic Converter,Roof rack,Sport seats'
#  'Roof rack,Ski bag,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Handicapped enabled,Touch screen' 'Roof rack,Sport seats,Winter tyres'
#  'Roof rack,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Trailer hitch,Voice Control'
#  'Roof rack,Sport package,Touch screen,Voice Control'
#  'Cab or rented Car,Catalytic Converter,Roof rack'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Sport package,Touch screen,Voice Control'
#  'Catalytic Converter,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Sliding door' 'Sport seats,Touch screen'
#  'Cab or rented Car,Catalytic Converter,Touch screen'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport seats'
#  'Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Sport seats,Touch screen,Trailer hitch'
#  'Alloy wheels,Roof rack,Ski bag,Touch screen'
#  'Alloy wheels,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Sport package,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport package,Sport seats,Touch screen'
#  'Touch screen,Trailer hitch'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport seats,Touch screen'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport package,Sport seats'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport package,Sport seats'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport package,Sport seats'
#  'Alloy wheels,Roof rack,Ski bag,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Cab or rented Car,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Cab or rented Car,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Tuned car' 'Cab or rented Car,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Touch screen'
#  'Cab or rented Car,Voice Control'
#  'Sport suspension,Touch screen,Voice Control'
#  'Catalytic Converter,Sport seats,Touch screen'
#  'Alloy wheels,Cab or rented Car,Touch screen'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Trailer hitch'
#  'Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Cab or rented Car,Catalytic Converter,Sport seats'
#  'Alloy wheels,Catalytic Converter,Sport package,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Touch screen,Voice Control'
#  'Alloy wheels,Sport package,Touch screen,Trailer hitch'
#  'Alloy wheels,Sport package,Touch screen'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Shift paddles,Sport package,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Ski bag,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport suspension,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport seats,Tuned car'
#  'Alloy wheels,Catalytic Converter,Sport seats,Trailer hitch'
#  'Alloy wheels,Sport package,Trailer hitch,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Catalytic Converter,Touch screen,Winter tyres'
#  'Catalytic Converter,Shift paddles,Voice Control'
#  'Catalytic Converter,Handicapped enabled' 'Sport package,Touch screen'
#  'Roof rack,Sport seats,Trailer hitch'
#  'Shift paddles,Sport seats,Voice Control'
#  'Roof rack,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Touch screen,Trailer hitch,Winter tyres'
#  'Alloy wheels,Roof rack,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport suspension,Touch screen,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Roof rack,Touch screen'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Touch screen,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Catalytic Converter,Roof rack,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Voice Control'
#  'Shift paddles,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Touch screen'
#  'Alloy wheels,Roof rack,Ski bag'
#  'Alloy wheels,Shift paddles,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package'
#  'Alloy wheels,Roof rack,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Shift paddles,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Catalytic Converter,Roof rack,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Touch screen,Trailer hitch'
#  'Shift paddles,Sport seats,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Ski bag,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Shift paddles,Touch screen,Voice Control'
#  'Roof rack,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Shift paddles,Touch screen'
#  'Roof rack,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Touch screen'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Roof rack,Sport seats,Trailer hitch,Voice Control'
#  'Roof rack,Sport suspension,Touch screen,Voice Control'
#  'Roof rack,Sport seats,Touch screen,Winter tyres'
#  'Catalytic Converter,Roof rack,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport seats,Touch screen,Winter tyres'
#  'Alloy wheels,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Touch screen,Winter tyres'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Ski bag,Touch screen'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Touch screen,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Trailer hitch'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Shift paddles,Sport seats,Voice Control'
#  'Alloy wheels,Cab or rented Car,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Ski bag,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport suspension'
#  'Roof rack,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport package,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Ski bag'
#  'Alloy wheels,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Right hand drive,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Sport package,Touch screen,Trailer hitch,Voice Control'
#  'Cab or rented Car,Roof rack,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sliding door,Sport seats'
#  'Alloy wheels,Roof rack,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Ski bag,Sport seats'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Shift paddles,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Trailer hitch'
#  'Alloy wheels,Ski bag,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Sport seats'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Sport seats'
#  'Alloy wheels,Cab or rented Car,Roof rack,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Cab or rented Car,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Trailer hitch,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Voice Control'
#  'Alloy wheels,Cab or rented Car,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Touch screen,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Ski bag,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Ski bag,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport seats,Touch screen,Tuned car'
#  'Alloy wheels,Catalytic Converter,Roof rack,Ski bag,Touch screen,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Ski bag,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Roof rack,Ski bag,Sport seats'
#  'Alloy wheels,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Cab or rented Car,Catalytic Converter,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Catalytic Converter,Roof rack,Shift paddles,Touch screen,Trailer hitch'
#  'Alloy wheels,Roof rack,Shift paddles,Voice Control'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Ski bag,Sport package,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport suspension'
#  'Alloy wheels,Sport package,Touch screen,Tuned car,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport seats'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Trailer hitch'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Voice Control'
#  'Alloy wheels,Catalytic Converter,Touch screen,Trailer hitch'
#  'Alloy wheels,Ski bag,Sport seats,Sport suspension'
#  'Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen'
#  'Alloy wheels,Roof rack,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Catalytic Converter,Roof rack,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Sport package,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Shift paddles,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Roof rack,Shift paddles,Sport package,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Winter tyres'
#  'Alloy wheels,Roof rack,Shift paddles,Sport seats,Sport suspension,Touch screen'
#  'Roof rack,Shift paddles,Sport seats,Sport suspension'
#  'Alloy wheels,Shift paddles,Sport package,Touch screen'
#  'Shift paddles,Voice Control'
#  'Alloy wheels,Ski bag,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Catalytic Converter,Roof rack,Shift paddles,Sport package,Touch screen'
#  'Alloy wheels,Catalytic Converter,Sport package,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Handicapped enabled,Roof rack,Sport seats,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Touch screen,Voice Control,Winter tyres'
#  'Roof rack,Ski bag,Touch screen,Trailer hitch'
#  'Roof rack,Sport package,Sport seats' 'Shift paddles,Touch screen'
#  'Catalytic Converter,Roof rack,Voice Control,Winter tyres'
#  'Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Touch screen'
#  'Roof rack,Sport package'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Ski bag,Voice Control'
#  'Alloy wheels,Catalytic Converter,Ski bag,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Catalytic Converter,Shift paddles,Touch screen'
#  'Catalytic Converter,Roof rack,Trailer hitch'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Sport package,Sport seats,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen'
#  'Alloy wheels,Shift paddles,Sport seats,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Tuned car,Voice Control'
#  'Tuned car,Voice Control'
#  'Alloy wheels,Sport package,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Touch screen,Trailer hitch,Voice Control,Winter tyres'
#  'Alloy wheels,Handicapped enabled,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Sport seats,Trailer hitch,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Shift paddles,Sport package,Sport suspension,Touch screen,Voice Control,Winter tyres'
#  'Ski bag,Sport seats,Sport suspension,Voice Control'
#  'Alloy wheels,Sport package,Sport seats,Touch screen,Trailer hitch,Voice Control'
#  'Alloy wheels,Handicapped enabled,Touch screen,Voice Control'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Ski bag,Touch screen,Voice Control'
#  'Alloy wheels,Touch screen,Trailer hitch,Winter tyres'
#  'Alloy wheels,Catalytic Converter,Shift paddles,Ski bag,Sport seats,Touch screen'
#  'Alloy wheels,Handicapped enabled,Shift paddles,Sport seats,Touch screen'
#  'Alloy wheels,Catalytic Converter,Handicapped enabled,Touch screen,Voice Control,Winter tyres'
#  'Alloy wheels,Shift paddles,Ski bag,Sport package,Sport suspension,Touch screen,Voice Control'
#  'Alloy wheels,Handicapped enabled,Roof rack,Touch screen'
#  'Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control']
# ----------------------------------------
# Alloy wheels                                                                                            3245
# Alloy wheels,Cab or rented Car                                                                            32
# Alloy wheels,Cab or rented Car,Catalytic Converter                                                        15
# Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack                                               1
# Alloy wheels,Cab or rented Car,Catalytic Converter,Roof rack,Shift paddles,Sport seats,Voice Control       1
#                                                                                                         ...
# Tuned car,Voice Control                                                                                    1
# Voice Control                                                                                             85
# Voice Control,Winter tyres                                                                                 1
# Winter tyres                                                                                              12
# NaN                                                                                                     2962
# Name: extras, Length: 660, dtype: int64
# ----------------------------------------
# Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control                                          1
# Catalytic Converter,Roof rack,Sport seats,Sport suspension                                                    1
# Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control                    1
# Name: extras, Length: 660, dtype: int64
# ################################################################################

# %%
get_diff_category_column(df["extras"])
# Out:
# {0: 'Alloy wheels',
#  1: 'Cab or rented Car',
#  2: 'Catalytic Converter',
#  3: 'Handicapped enabled',
#  4: 'Right hand drive',
#  5: 'Roof rack',
#  6: 'Shift paddles',
#  7: 'Ski bag',
#  8: 'Sliding door',
#  9: 'Sport package',
#  10: 'Sport seats',
#  11: 'Sport suspension',
#  12: 'Touch screen',
#  13: 'Trailer hitch',
#  14: 'Tuned car',
#  15: 'Voice Control',
#  16: 'Winter tyres'}

# %%
first_look("safety_&_security")
# Out:
# column name :  safety_&_security
# ----------------------------------------
# Per_of_Nulls   :  % 6.17
# Number of Nulls  :  982
# Number of Uniques:  4443
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ['ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights'
#  'ABS,Central door lock,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Head airbag,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights'
#  'ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control'
#  ...
#  'ABS,Blind spot monitor,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition'
#  'ABS,Adaptive headlights,Central door lock,Daytime running lights,Electronic stability control,Fog lights,Power steering,Traction control'
#  'ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition']
# ----------------------------------------
# ABS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        4
# ABS,Adaptive Cruise Control,Adaptive headlights,Alarm system,Blind spot monitor,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Fog lights,Head airbag,Immobilizer,Isofix,Lane departure warning system,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition,Xenon headlights                                                1
# ABS,Adaptive Cruise Control,Adaptive headlights,Alarm system,Blind spot monitor,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition                                                    1
# ABS,Adaptive Cruise Control,Adaptive headlights,Alarm system,Blind spot monitor,Central door lock with remote control,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency system,Fog lights,Head airbag,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition,Xenon headlights                                                                             1
# ABS,Adaptive Cruise Control,Adaptive headlights,Alarm system,Blind spot monitor,Central door lock with remote control,Driver drowsiness detection,Driver-side airbag,Electronic stability control,Emergency brake assistant,Emergency system,Fog lights,Head airbag,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Rear airbag,Side airbag,Tire pressure monitoring system,Traction control,Traffic sign recognition      1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# Power steering                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             6
# Side airbag                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Tire pressure monitoring system                                                                                                                                                                                                                                                                                                                                                                                                                                                                           12
# Xenon headlights                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      982
# Name: safety_&_security, Length: 4444, dtype: int64
# ----------------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                275
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                           272
#                                                                                                                                                                                                                                                                                                                                                                  ...
# ABS,Central door lock,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                              1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                 1
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Power steering,Tire pressure monitoring system,Traction control                                                                                                                                                  1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition      1
# Name: safety_&_security, Length: 4444, dtype: int64
# ################################################################################

# %%
get_diff_category_column(df["safety_&_security"])
# Out:
# {0: 'ABS',
#  1: 'Adaptive Cruise Control',
#  2: 'Adaptive headlights',
#  3: 'Alarm system',
#  4: 'Blind spot monitor',
#  5: 'Central door lock',
#  6: 'Central door lock with remote control',
#  7: 'Daytime running lights',
#  8: 'Driver drowsiness detection',
#  9: 'Driver-side airbag',
#  10: 'Electronic stability control',
#  11: 'Emergency brake assistant',
#  12: 'Emergency system',
#  13: 'Fog lights',
#  14: 'Head airbag',
#  15: 'Immobilizer',
#  16: 'Isofix',
#  17: 'LED Daytime Running Lights',
#  18: 'LED Headlights',
#  19: 'Lane departure warning system',
#  20: 'Night view assist',
#  21: 'Passenger-side airbag',
#  22: 'Power steering',
#  23: 'Rear airbag',
#  24: 'Side airbag',
#  25: 'Tire pressure monitoring system',
#  26: 'Traction control',
#  27: 'Traffic sign recognition',
#  28: 'Xenon headlights'}

# %% [markdown]
# ### emission_label

# %%
first_look("emission_label")
# Out:
# column name :  emission_label
# ----------------------------------------
# Per_of_Nulls   :  % 74.97
# Number of Nulls  :  11934
# Number of Uniques:  6
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '4 (Green)' '1 (No sticker)' '5 (Blue)' '[],[],[]' '3 (Yellow)'
#  '2 (Red)']
# ----------------------------------------
# 1 (No sticker)      381
# 2 (Red)               1
# 3 (Yellow)            2
# 4 (Green)          3553
# 5 (Blue)              8
# [],[],[]             40
# NaN               11934
# Name: emission_label, dtype: int64
# ----------------------------------------
# NaN               11934
# 4 (Green)          3553
# 1 (No sticker)      381
# [],[],[]             40
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
# ################################################################################

# %%
for i in df.select_dtypes(include="O").columns:
    if df[df["emission_label"].isnull()][i].str.contains("4 \(Green\)|1 \(No sticker\)|5 \(Blue\)|3 \(Yellow\)|2 \(Red\)", regex=True).any():
        df.loc[df[df["emission_label"].isnull()][df[df["emission_label"].isnull()][i].str.contains("4 \(Green\)|1 \(No sticker\)|5 \(Blue\)|3 \(Yellow\)|'2 \(Red\)", regex=True) == True].index, "emission_label"] = df[df["emission_label"].isnull()][df[df["emission_label"].isnull()][i].str.contains("4 \(Green\)|1 \(No sticker\)|5 \(Blue\)|3 \(Yellow\)|2 \(Red\)", regex=True) == True][i].str.extract("(\d \(.*\))")[0]

# %%
df["emission_label"] = df["emission_label"].str.extract("(\d)").astype(float)

# %%
first_look("emission_label")
# Out:
# column name :  emission_label
# ----------------------------------------
# Per_of_Nulls   :  % 49.94
# Number of Nulls  :  7950
# Number of Uniques:  5
# Type of columns:  float64
# ----------------------------------------
# Unique values of columns:  [ 4. nan  1.  5.  3.  2.]
# ----------------------------------------
# 1.0     435
# 2.0       1
# 3.0       2
# 4.0    7488
# 5.0      43
# NaN    7950
# Name: emission_label, dtype: int64
# ----------------------------------------
# NaN    7950
# 4.0    7488
# 1.0     435
# 5.0      43
# 3.0       2
# 2.0       1
# Name: emission_label, dtype: int64
# ################################################################################

# %% [markdown]
# ### gears

# %%
first_look("gears")
# Out:
# column name :  gears
# ----------------------------------------
# Per_of_Nulls   :  % 29.6
# Number of Nulls  :  4712
# Number of Uniques:  10
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '7' '6' '5' '8' '1' '2' '50' '9' '3' '4']
# ----------------------------------------
# 1         2
# 2         1
# 3         2
# 4         2
# 5      3239
# 50        1
# 6      5822
# 7      1908
# 8       224
# 9         6
# NaN    4712
# Name: gears, dtype: int64
# ----------------------------------------
# 6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
# ################################################################################

# %%
df["gears"] = df["gears"].astype(float)

# %% [markdown]
# ### country_version

# %%
first_look("country_version")
# Out:
# column name :  country_version
# ----------------------------------------
# Per_of_Nulls   :  % 52.35
# Number of Nulls  :  8333
# Number of Uniques:  23
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan 'Germany' 'Italy' 'Belgium' 'Netherlands' 'Spain' 'European Union'
#  'Switzerland' 'Austria' 'Luxembourg' 'France' 'Denmark' 'Poland'
#  'Romania' 'Slovakia' 'Sweden' 'Czech Republic' 'Hungary' 'Slovenia'
#  'Croatia' 'Egypt' 'Serbia' 'Bulgaria' 'Japan']
# ----------------------------------------
# Austria            208
# Belgium            314
# Bulgaria             2
# Croatia              4
# Czech Republic      52
# Denmark             33
# Egypt                1
# European Union     507
# France              38
# Germany           4502
# Hungary             28
# Italy             1038
# Japan                8
# Luxembourg           1
# Netherlands        464
# Poland              49
# Romania              2
# Serbia               1
# Slovakia             4
# Slovenia             1
# Spain              325
# Sweden               3
# Switzerland          1
# NaN               8333
# Name: country_version, dtype: int64
# ----------------------------------------
# NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
# ################################################################################

# %% [markdown]
# ### electricity_consumption

# %%
first_look("electricity_consumption")
# Out:
# column name :  electricity_consumption
# ----------------------------------------
# Per_of_Nulls   :  % 99.14
# Number of Nulls  :  15782
# Number of Uniques:  1
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '0 kWh/100 km (comb)']
# ----------------------------------------
# 0 kWh/100 km (comb)      137
# NaN                    15782
# Name: electricity_consumption, dtype: int64
# ----------------------------------------
# NaN                    15782
# 0 kWh/100 km (comb)      137
# Name: electricity_consumption, dtype: int64
# ################################################################################

# %%
df[df["electricity_consumption"] == '0 kWh/100 km (comb)']["fuel"].value_counts()
# Out:
# Benzine    105
# Diesel      32
# Name: fuel, dtype: int64

# %%
df.drop(columns="electricity_consumption", inplace = True)

# %% [markdown]
# ### last_service_date

# %%
first_look("last_service_date")
# Out:
# column name :  last_service_date
# ----------------------------------------
# Per_of_Nulls   :  % 96.44
# Number of Nulls  :  15353
# Number of Uniques:  255
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '12/2018Euro 6' '02/2019Euro 6' '06/2018102 g CO2/km (comb)'
#  '03/20195 (Blue)' '06/2017' '03/2019' '02/2019' '06/2019Euro 6'
#  '01/2018114 g CO2/km (comb)' '03/2019Euro 6' '05/2019109 g CO2/km (comb)'
#  '05/2019Euro 6' '05/2019101 g CO2/km (comb)' '02/20194 (Green)' '09/2018'
#  '06/2017102 g CO2/km (comb)' '11/2018Euro 6' '06/201992 g CO2/km (comb)'
#  '04/2019Euro 6' '11/2018' '01/201998 g CO2/km (comb)' '01/2019Euro 6'
#  '03/2016Euro 6' '12/201899 g CO2/km (comb)' '07/201897 g CO2/km (comb)'
#  '06/20194 (Green)' '06/2018Euro 6' '10/2018Euro 6'
#  '10/201894 g CO2/km (comb)' '10/201897 g CO2/km (comb)'
#  '03/201997 g CO2/km (comb)' '04/201990 g CO2/km (comb)' '09/2018Euro 6'
#  '05/2018Euro 6' '07/2018102 g CO2/km (comb)' '09/201897 g CO2/km (comb)'
#  '10/2018124 g CO2/km (comb)' '06/201792 g CO2/km (comb)' '01/2019'
#  '12/201897 g CO2/km (comb)' '05/201993 g CO2/km (comb)'
#  '02/2019102 g CO2/km (comb)' '05/20194 (Green)'
#  '03/201992 g CO2/km (comb)' '06/2019121 g CO2/km (comb)'
#  '05/201989 g CO2/km (comb)' '02/2018128 g CO2/km (comb)'
#  '02/2019128 g CO2/km (comb)' '06/2018149 g CO2/km (comb)'
#  '03/20194.8 l/100 km (comb)5.8 l/100 km (city)4.1 l/100 km (country)'
#  '10/2018149 g CO2/km (comb)' '08/2018Euro 6d-TEMP' '10/2017Euro 6'
#  '03/2019139 g CO2/km (comb)' '04/2018123 g CO2/km (comb)'
#  '04/2018110 g CO2/km (comb)' '05/2018124 g CO2/km (comb)'
#  '04/2019124 g CO2/km (comb)' '03/2019129 g CO2/km (comb)'
#  '01/2019Euro 6d-TEMP' '07/2018Euro 6d-TEMP' '02/2019Euro 6d-TEMP'
#  '12/20185 (Blue)' '11/2017Euro 6d-TEMP' '04/2019107 g CO2/km (comb)'
#  '05/2018Euro 6d-TEMP' '06/2019120 g CO2/km (comb)' '06/2019Euro 6d-TEMP'
#  '03/2019Euro 6d-TEMP' '04/2018124 g CO2/km (comb)'
#  '06/2019110 g CO2/km (comb)' '03/2019110 g CO2/km (comb)'
#  '04/2019112 g CO2/km (comb)' '02/2019110 g CO2/km (comb)'
#  '04/20184 (Green)' '05/2019126 g CO2/km (comb)' '08/20184 (Green)'
#  '05/2019120 g CO2/km (comb)' '05/2019124 g CO2/km (comb)'
#  '03/2019128 g CO2/km (comb)' '06/2018124 g CO2/km (comb)'
#  '05/2018130 g CO2/km (comb)' '06/2019124 g CO2/km (comb)'
#  '02/2019137 g CO2/km (comb)' '06/2018131 g CO2/km (comb)'
#  '05/2019118 g CO2/km (comb)' '03/2019126 g CO2/km (comb)'
#  '04/2019Euro 6d-TEMP' '05/2019Euro 6d-TEMP' '05/2019134 g CO2/km (comb)'
#  '04/20194 (Green)' '06/2019129 g CO2/km (comb)'
#  '05/2019169 g CO2/km (comb)' '06/2016149 g CO2/km (comb)' '02/2019Euro 4'
#  '06/2019134 g CO2/km (comb)' '01/2019119 g CO2/km (comb)'
#  '05/2017118 g CO2/km (comb)' '04/2019109 g CO2/km (comb)'
#  '05/2018104 g CO2/km (comb)' '03/2018114 g CO2/km (comb)'
#  '06/2018109 g CO2/km (comb)' '11/2018104 g CO2/km (comb)'
#  '06/2019104 g CO2/km (comb)' '07/2017Euro 6' '02/2019Euro 6d'
#  '01/2018118 g CO2/km (comb)' '07/2018Euro 6c'
#  '08/2018138 g CO2/km (comb)' '03/2019145 g CO2/km (comb)'
#  '05/2019133 g CO2/km (comb)' '09/2018Euro 6d-TEMP'
#  '01/2019133 g CO2/km (comb)' '04/2018133 g CO2/km (comb)'
#  '03/2019Euro 6c' '06/2019128 g CO2/km (comb)'
#  '10/2019120 g CO2/km (comb)' '01/201992 g CO2/km (comb)'
#  '06/201985 g CO2/km (comb)'
#  '04/20195.6 l/100 km (comb)7.2 l/100 km (city)4.7 l/100 km (country)'
#  '05/201985 g CO2/km (comb)' '05/2019127 g CO2/km (comb)'
#  '02/2019127 g CO2/km (comb)' '02/201992 g CO2/km (comb)'
#  '08/2018127 g CO2/km (comb)' '10/2018127 g CO2/km (comb)'
#  '04/2019135 g CO2/km (comb)' '03/2019135 g CO2/km (comb)'
#  '05/2019135 g CO2/km (comb)' '07/201892 g CO2/km (comb)'
#  '04/201985 g CO2/km (comb)' '09/201892 g CO2/km (comb)' '11/2019Euro 6'
#  '06/2019127 g CO2/km (comb)' '07/2018127 g CO2/km (comb)'
#  '01/2019120 g CO2/km (comb)' '04/2019127 g CO2/km (comb)'
#  '12/2018104 g CO2/km (comb)' '04/201992 g CO2/km (comb)'
#  '01/201985 g CO2/km (comb)' '06/2018135 g CO2/km (comb)'
#  '03/201985 g CO2/km (comb)' '10/2018135 g CO2/km (comb)'
#  '02/2019135 g CO2/km (comb)' '02/2019114 g CO2/km (comb)'
#  '03/2019127 g CO2/km (comb)' '03/2018104 g CO2/km (comb)'
#  '04/2019120 g CO2/km (comb)' '03/2019140 g CO2/km (comb)'
#  '06/2018120 g CO2/km (comb)' '02/2019120 g CO2/km (comb)'
#  '03/2018140 g CO2/km (comb)' '12/2017120 g CO2/km (comb)' '03/2019Euro 5'
#  '07/2017' '07/2019' '11/2017Euro 6' '04/2017120 g CO2/km (comb)'
#  '07/2018Euro 6d' '05/2018116 g CO2/km (comb)' '04/2016Euro 6'
#  '03/2019120 g CO2/km (comb)']
# ----------------------------------------
# 01/2017102 g CO2/km (comb)        1
# 01/2017107 g CO2/km (comb)        1
# 01/201795 g CO2/km (comb)         1
# 01/2018                           1
# 01/2018114 g CO2/km (comb)        1
#                               ...
# 12/20185 (Blue)                   1
# 12/201897 g CO2/km (comb)         1
# 12/201899 g CO2/km (comb)         2
# 12/2018Euro 6                    11
# NaN                           15353
# Name: last_service_date, Length: 256, dtype: int64
# ----------------------------------------
# NaN                           15353
# 02/2019Euro 6                    23
# 05/2019Euro 6                    16
# 01/2018118 g CO2/km (comb)       15
# 03/2019Euro 6                    15
#                               ...
# 01/201795 g CO2/km (comb)         1
# 06/201987 g CO2/km (comb)         1
# 10/2018100 g CO2/km (comb)        1
# 02/201897 g CO2/km (comb)         1
# 03/2019120 g CO2/km (comb)        1
# Name: last_service_date, Length: 256, dtype: int64
# ################################################################################

# %%
df["last_service_time"] = df["last_service_date"].str.extract("(.*/\d\d\d\d)")
df["last_service_time"] = pd.to_datetime(df["last_service_time"])
df["last_service_time"].value_counts()
# Out:
# 2019-05-01    61
# 2019-02-01    55
# 2019-01-01    51
# 2019-06-01    49
# 2019-04-01    48
# 2019-03-01    47
# 2018-12-01    32
# 2018-10-01    24
# 2018-06-01    21
# 2018-05-01    21
# 2018-07-01    21
# 2018-01-01    20
# 2018-09-01    17
# 2018-11-01    17
# 2018-04-01    16
# 2018-08-01    13
# 2018-03-01     9
# 2017-06-01     7
# 2018-02-01     5
# 2017-05-01     3
# 2017-12-01     3
# 2017-02-01     3
# 2017-10-01     3
# 2017-01-01     3
# 2017-11-01     2
# 2016-06-01     2
# 2016-04-01     2
# 2017-07-01     2
# 2019-11-01     1
# 2019-10-01     1
# 2019-07-01     1
# 2016-03-01     1
# 2019-09-01     1
# 2019-08-01     1
# 2017-09-01     1
# 2016-05-01     1
# 2017-04-01     1
# Name: last_service_time, dtype: int64

# %% [markdown]
# ### other_fuel_types

# %%
first_look("other_fuel_types")
# Out:
# column name :  other_fuel_types
# ----------------------------------------
# Per_of_Nulls   :  % 94.47
# Number of Nulls  :  15039
# Number of Uniques:  1
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '[],[],[]']
# ----------------------------------------
# [],[],[]      880
# NaN         15039
# Name: other_fuel_types, dtype: int64
# ----------------------------------------
# NaN         15039
# [],[],[]      880
# Name: other_fuel_types, dtype: int64
# ################################################################################

# %%
df.drop(columns="other_fuel_types", inplace=True)

# %% [markdown]
# ### availability

# %%
first_look("availability")
# Out:
# column name :  availability
# ----------------------------------------
# Per_of_Nulls   :  % 96.01
# Number of Nulls  :  15284
# Number of Uniques:  15
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan 'in 90 days from ordering' 'in 180 days from ordering'
#  'in 150 days from ordering' 'in 14 days from ordering'
#  'in 7 days from ordering' 'in 1 day from ordering'
#  'in 21 days from ordering' 'in 5 days from ordering'
#  'in 60 days from ordering' 'in 120 days from ordering'
#  'in 3 days from ordering' 'in 4 days from ordering'
#  'in 42 days from ordering' 'in 2 days from ordering'
#  'in 6 days from ordering']
# ----------------------------------------
# in 1 day from ordering          51
# in 120 days from ordering      182
# in 14 days from ordering        24
# in 150 days from ordering       18
# in 180 days from ordering       24
# in 2 days from ordering         16
# in 21 days from ordering         8
# in 3 days from ordering         35
# in 4 days from ordering          2
# in 42 days from ordering        10
# in 5 days from ordering         35
# in 6 days from ordering          1
# in 60 days from ordering        13
# in 7 days from ordering         20
# in 90 days from ordering       196
# NaN                          15284
# Name: availability, dtype: int64
# ----------------------------------------
# NaN                          15284
# in 90 days from ordering       196
# in 120 days from ordering      182
# in 1 day from ordering          51
# in 5 days from ordering         35
# in 3 days from ordering         35
# in 180 days from ordering       24
# in 14 days from ordering        24
# in 7 days from ordering         20
# in 150 days from ordering       18
# in 2 days from ordering         16
# in 60 days from ordering        13
# in 42 days from ordering        10
# in 21 days from ordering         8
# in 4 days from ordering          2
# in 6 days from ordering          1
# Name: availability, dtype: int64
# ################################################################################

# %%
df.drop(columns="availability", inplace=True)

# %% [markdown]
# ### last_timing_belt_service_date

# %%
first_look("last_timing_belt_service_date")
# Out:
# column name :  last_timing_belt_service_date
# ----------------------------------------
# Per_of_Nulls   :  % 99.9
# Number of Nulls  :  15903
# Number of Uniques:  15
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '12/1900' '07/2018' '01/1900' '05/2019' '09/2018' '05/2018Euro 6'
#  '06/2017' '01/2019' '02/2019' '02/2018' '04/2016' '06/2019' '01/2018'
#  '04/2019' '01/1970']
# ----------------------------------------
# 01/1900              1
# 01/1970              1
# 01/2018              1
# 01/2019              1
# 02/2018              1
# 02/2019              1
# 04/2016              2
# 04/2019              1
# 05/2018Euro 6        1
# 05/2019              1
# 06/2017              1
# 06/2019              1
# 07/2018              1
# 09/2018              1
# 12/1900              1
# NaN              15903
# Name: last_timing_belt_service_date, dtype: int64
# ----------------------------------------
# NaN              15903
# 04/2016              2
# 12/1900              1
# 07/2018              1
# 01/1900              1
# 05/2019              1
# 09/2018              1
# 05/2018Euro 6        1
# 06/2017              1
# 01/2019              1
# 02/2019              1
# 02/2018              1
# 06/2019              1
# 01/2018              1
# 04/2019              1
# 01/1970              1
# Name: last_timing_belt_service_date, dtype: int64
# ################################################################################

# %%
df.drop(columns="last_timing_belt_service_date", inplace=True)

# %% [markdown]
# ### available_from

# %%
first_look("available_from")
# Out:
# column name :  available_from
# ----------------------------------------
# Per_of_Nulls   :  % 98.29
# Number of Nulls  :  15647
# Number of Uniques:  46
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  [nan '29/06/19' '27/06/19' '29/07/19' '31/10/19' '18/07/19' '06/12/19'
#  '03/12/19' '05/12/19' '10/11/19' '01/07/19' '30/07/19' '10/12/19'
#  '08/07/19' '05/08/19' '01/08/19' '26/06/19' '31/08/19' '01/09/19'
#  '28/06/19' '30/06/19' '05/07/19' '11/08/19' '25/10/19' '15/07/19'
#  '20/07/19' '16/07/19' '10/09/19' '10/10/19' '24/08/19' '17/08/19'
#  '14/09/19' '24/09/19' '16/08/19' '15/08/19' '27/07/19' '18/08/19'
#  '29/09/19' '24/07/19' '10/07/19' '02/07/19' '04/07/19' '19/08/19'
#  '30/09/19' '19/07/19' '16/09/19' '03/08/19']
# ----------------------------------------
# 01/07/19       11
# 01/08/19        3
# 01/09/19        1
# 02/07/19        1
# 03/08/19        1
# 03/12/19        1
# 04/07/19        2
# 05/07/19        2
# 05/08/19        2
# 05/12/19        1
# 06/12/19        1
# 08/07/19        4
# 10/07/19        1
# 10/09/19        6
# 10/10/19        1
# 10/11/19        5
# 10/12/19        1
# 11/08/19        1
# 14/09/19        1
# 15/07/19        3
# 15/08/19       24
# 16/07/19        2
# 16/08/19        1
# 16/09/19       14
# 17/08/19        1
# 18/07/19        1
# 18/08/19        1
# 19/07/19        1
# 19/08/19        7
# 20/07/19        2
# 24/07/19        1
# 24/08/19        2
# 24/09/19        1
# 25/10/19        3
# 26/06/19        5
# 27/06/19        5
# 27/07/19        1
# 28/06/19       10
# 29/06/19       12
# 29/07/19        1
# 29/09/19        1
# 30/06/19        2
# 30/07/19       25
# 30/09/19        1
# 31/08/19       98
# 31/10/19        1
# NaN         15647
# Name: available_from, dtype: int64
# ----------------------------------------
# NaN         15647
# 31/08/19       98
# 30/07/19       25
# 15/08/19       24
# 16/09/19       14
# 29/06/19       12
# 01/07/19       11
# 28/06/19       10
# 19/08/19        7
# 10/09/19        6
# 26/06/19        5
# 27/06/19        5
# 10/11/19        5
# 08/07/19        4
# 15/07/19        3
# 25/10/19        3
# 01/08/19        3
# 04/07/19        2
# 05/08/19        2
# 24/08/19        2
# 16/07/19        2
# 20/07/19        2
# 05/07/19        2
# 30/06/19        2
# 30/09/19        1
# 31/10/19        1
# 27/07/19        1
# 02/07/19        1
# 10/07/19        1
# 19/07/19        1
# 24/07/19        1
# 29/07/19        1
# 29/09/19        1
# 18/08/19        1
# 14/09/19        1
# 18/07/19        1
# 16/08/19        1
# 24/09/19        1
# 17/08/19        1
# 10/10/19        1
# 06/12/19        1
# 03/12/19        1
# 05/12/19        1
# 11/08/19        1
# 10/12/19        1
# 01/09/19        1
# 03/08/19        1
# Name: available_from, dtype: int64
# ################################################################################

# %%
df.drop(columns="available_from", inplace=True)

# %% [markdown]
# ### consumption

# %%
first_look("consumption")
# Out:
# column name :  consumption
# ----------------------------------------
# Per_of_Nulls   :  % 11.97
# Number of Nulls  :  1906
# Number of Uniques:  881
# Type of columns:  object
# ----------------------------------------
# Unique values of columns:  ["['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']"
#  nan
#  "['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['3.8 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['3 l/100 km (comb)'],['3 l/100 km (city)'],['3 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3 l/100 km (comb)'],['4 l/100 km (city)'],['3 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']"
#  '4.4 l/100 km (comb),5.2 l/100 km (city),3.9 l/100 km (country),'
#  "['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '5 l/100 km (comb),6.2 l/100 km (city),4.3 l/100 km (country),'
#  '4.9 l/100 km (comb),6.2 l/100 km (city),4.2 l/100 km (country),'
#  "['3.8 l/100 km (comb)'],[],[]"
#  "['5.8 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.9 l/100 km (country)']"
#  '4.4 l/100 km (comb),5.4 l/100 km (city),3.8 l/100 km (country),'
#  "['4.7 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '4.6 l/100 km (comb),5.6 l/100 km (city),4 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '5.2 l/100 km (comb),6.7 l/100 km (city),4.4 l/100 km (country),'
#  '4.7 l/100 km (comb),5.8 l/100 km (city),4.1 l/100 km (country),'
#  "['4.4 l/100 km (comb)'],[],[]"
#  "['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],[],[]"
#  "['4.9 l/100 km (comb)'],[],['4.2 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['3.7 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],[],[]"
#  "['4.3 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['43 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],[],[]"
#  "['13.8 l/100 km (comb)'],['19.9 l/100 km (city)'],['10.3 l/100 km (country)']"
#  '4.2 l/100 km (comb),5 l/100 km (city),3.7 l/100 km (country),'
#  "['3.7 l/100 km (comb)'],[],['3.4 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.4 l/100 km (comb)'],[],[]"
#  "['4.9 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "[],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['5 l/100 km (city)'],['3 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['8.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],[],[]"
#  "['4.2 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6 l/100 km (city)'],['3 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.4 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '5.6 l/100 km (comb),7.1 l/100 km (city),4.7 l/100 km (country),'
#  "['4.9 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.5 l/100 km (country)']"
#  '4.5 l/100 km (comb),5.5 l/100 km (city),3.9 l/100 km (country),'
#  "['4 l/100 km (comb)'],['4 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],[],[]"
#  '3.9 l/100 km (comb),4.7 l/100 km (city),3.3 l/100 km (country),'
#  "['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.7 l/100 km (country)']"
#  '4.9 l/100 km (comb),5.9 l/100 km (city),4.3 l/100 km (country),'
#  "['4.9 l/100 km (comb)'],['6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],[],[]"
#  "['4.7 l/100 km (comb)'],['5.9 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['4.4 l/100 km (city)'],['6.7 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.5 l/100 km (country)']"
#  '5.1 l/100 km (comb),6.3 l/100 km (city),4.4 l/100 km (country),'
#  "['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['6.3 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['8.2 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['8 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '6 l/100 km (comb),8.2 l/100 km (city),4.8 l/100 km (country),'
#  "['5.1 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '4.8 l/100 km (comb),5.9 l/100 km (city),4.2 l/100 km (country),'
#  "['4.6 l/100 km (comb)'],['5.8 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],[],[]"
#  "['51 l/100 km (comb)'],['62 l/100 km (city)'],['44 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.9 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['6 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],[],[]"
#  "['5.3 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '4.7 l/100 km (comb),5.9 l/100 km (city),4 l/100 km (country),'
#  "['5.6 l/100 km (comb)'],['6.3 l/100 km (city)'],['5.4 l/100 km (country)']"
#  '4.8 l/100 km (comb),5.9 l/100 km (city),4.1 l/100 km (country),'
#  "['4.9 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5 l/100 km (comb)'],[],[]"
#  '6 l/100 km (comb),8.2 l/100 km (city),4.7 l/100 km (country),'
#  "['5 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '4.9 l/100 km (comb),6 l/100 km (city),4.2 l/100 km (country),'
#  "['5.8 l/100 km (comb)'],[],[]"
#  '4.6 l/100 km (comb),5.8 l/100 km (city),3.9 l/100 km (country),'
#  "['4.9 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "[],['3.5 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.3 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "[],['3.4 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['5 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.4 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.5 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.3 kg/100 km (comb)'],['6.5 kg/100 km (city)'],['4.6 kg/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['3.4 kg/100 km (comb)'],['4.3 kg/100 km (city)'],['2.9 kg/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.8 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],[],[]"
#  "['4.9 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['10 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],[],[]"
#  "['4.9 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],[],['3.6 l/100 km (country)']"
#  "['3.3 kg/100 km (comb)'],['4.3 kg/100 km (city)'],['2.8 kg/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.9 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "[],['4.5 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.9 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['4 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.5 l/100 km (city)'],[]"
#  "['3.8 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['3.6 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.6 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['4.9 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4 l/100 km (city)'],['3 l/100 km (country)']"
#  "['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.5 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['3.2 l/100 km (comb)'],['3.8 l/100 km (city)'],['3 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.7 l/100 km (city)'],['4 l/100 km (country)']"
#  "['3.5 kg/100 km (comb)'],['4.5 kg/100 km (city)'],['2.9 kg/100 km (country)']"
#  "['6.6 l/100 km (comb)'],['8.2 l/100 km (city)'],['5.6 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],[],['4.7 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['8.3 l/100 km (comb)'],['11.3 l/100 km (city)'],['6.6 l/100 km (country)']"
#  "['6.5 l/100 km (comb)'],[],[]"
#  "['7.1 l/100 km (comb)'],['9 l/100 km (city)'],['6 l/100 km (country)']"
#  "['8.3 l/100 km (comb)'],['11.3 l/100 km (city)'],['6.5 l/100 km (country)']"
#  "['8.1 l/100 km (comb)'],['11.2 l/100 km (city)'],['6.3 l/100 km (country)']"
#  '1.6 l/100 km (comb),'
#  "['5.4 kg/100 km (comb)'],['6.8 kg/100 km (city)'],['4.5 kg/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.2 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['6 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.4 l/100 km (city)'],['4 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.7 l/100 km (country)']"
#  '4.5 l/100 km (comb),5.4 l/100 km (city),4 l/100 km (country),'
#  "['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['4 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5.3 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['5 l/100 km (comb)'],[],['4.3 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],[],[]"
#  "['5.2 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['4 l/100 km (comb)'],[],[]"
#  "['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],[],['4.4 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['40 l/100 km (comb)'],['45 l/100 km (city)'],['37 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],[],['4.2 l/100 km (country)']"
#  '4.7 l/100 km (comb),5.7 l/100 km (city),4.1 l/100 km (country),'
#  "['4.6 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.9 l/100 km (country)']"
#  '4.4 l/100 km (comb),5.5 l/100 km (city),3.8 l/100 km (country),'
#  "['3.5 l/100 km (comb)'],['4.6 l/100 km (city)'],['2.9 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],[],[]"
#  "['5.2 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],[],[]"
#  '4.7 l/100 km (comb),5.6 l/100 km (city),4.2 l/100 km (country),'
#  "['4.4 l/100 km (comb)'],['5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['38 l/100 km (comb)'],['43 l/100 km (city)'],['35 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '4.6 l/100 km (comb),5.5 l/100 km (city),4.1 l/100 km (country),'
#  "['5 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.8 l/100 km (country)']"
#  '5 l/100 km (comb),5.8 l/100 km (city),4.5 l/100 km (country),'
#  "['5.1 l/100 km (comb)'],['6 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['5 l/100 km (city)'],['7 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['6.4 l/100 km (comb)'],['8.3 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['4 l/100 km (comb)'],[],['3.8 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6 l/100 km (city)'],['4.8 l/100 km (country)']"
#  '5.1 l/100 km (comb),6.4 l/100 km (city),4.4 l/100 km (country),'
#  '5.2 l/100 km (comb),6.4 l/100 km (city),4.4 l/100 km (country),'
#  "['4.5 l/100 km (comb)'],['5.2 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['5.5 l/100 km (city)'],['4.1 l/100 km (country)']"
#  '5.2 l/100 km (comb),6 l/100 km (city),4.8 l/100 km (country),'
#  "['5.1 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],[],['4.9 l/100 km (country)']"
#  '5.2 l/100 km (comb),5.8 l/100 km (city),4.8 l/100 km (country),'
#  "['8.3 kg/100 km (comb)'],['10.5 kg/100 km (city)'],['6.9 kg/100 km (country)']"
#  "['5.1 kg/100 km (comb)'],['5.8 kg/100 km (city)'],['4.7 kg/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.6 l/100 km (country)']"
#  '5.1 l/100 km (comb),6.1 l/100 km (city),4.6 l/100 km (country),'
#  "['5 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']"
#  '5 l/100 km (comb),5.5 l/100 km (city),3.9 l/100 km (country),'
#  '5.3 l/100 km (comb),6.8 l/100 km (city),4.5 l/100 km (country),'
#  '5.5 l/100 km (comb),6.9 l/100 km (city),4.6 l/100 km (country),'
#  "['5.3 l/100 km (comb)'],[],[]"
#  "['4.1 l/100 km (comb)'],['0 l/100 km (city)'],['0 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '5.4 l/100 km (comb),7.1 l/100 km (city),4.4 l/100 km (country),'
#  "['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.3 l/100 km (country)']"
#  '4.5 l/100 km (comb),5.7 l/100 km (city),3.8 l/100 km (country),'
#  '5.1 l/100 km (comb),6.3 l/100 km (city),4.3 l/100 km (country),'
#  '5.4 l/100 km (comb),'
#  "['5.5 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.5 l/100 km (country)']"
#  '5.6 l/100 km (comb),7.3 l/100 km (city),4.5 l/100 km (country),'
#  "['4.4 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['6.7 l/100 km (comb)'],['8.5 l/100 km (city)'],['5.7 l/100 km (country)']"
#  "['6.4 l/100 km (comb)'],[],[]"
#  "['6.2 l/100 km (comb)'],['7.7 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['7.3 l/100 km (comb)'],['9.9 l/100 km (city)'],['5.8 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.7 l/100 km (country)']"
#  '6.6 l/100 km (comb),8.5 l/100 km (city),5.4 l/100 km (country),'
#  '4.7 l/100 km (comb),5.5 l/100 km (city),4.1 l/100 km (country),'
#  '4.3 l/100 km (comb),5.1 l/100 km (city),3.8 l/100 km (country),'
#  "['4.8 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.1 l/100 km (country)']"
#  '6.4 l/100 km (comb),8.3 l/100 km (city),5.3 l/100 km (country),'
#  "['4.7 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.7 l/100 km (country)']"
#  '5.5 l/100 km (comb),7.2 l/100 km (city),4.5 l/100 km (country),'
#  "['7.1 l/100 km (comb)'],['9.9 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['6.3 l/100 km (comb)'],[],[]"
#  "['3.3 l/100 km (comb)'],['3.8 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['6.6 l/100 km (comb)'],['8.5 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.9 l/100 km (country)']"
#  '4.4 l/100 km (comb),5.4 l/100 km (city),3.9 l/100 km (country),'
#  "['6.7 l/100 km (comb)'],['8.9 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['6.3 l/100 km (comb)'],['8.3 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['7.8 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['3 l/100 km (comb)'],[],[]"
#  "['4.4 l/100 km (comb)'],['4.8 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['8.2 l/100 km (city)'],['5 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['8.4 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "[],['4 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['3 l/100 km (comb)'],[],['4 l/100 km (country)']"
#  "['6.7 l/100 km (comb)'],['8.9 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['3.4 l/100 km (comb)'],['3.8 l/100 km (city)'],['3.1 l/100 km (country)']"
#  '5.6 l/100 km (comb),7.3 l/100 km (city),4.6 l/100 km (country),'
#  "[],['5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.3 l/100 km (country)']"
#  '6.4 l/100 km (comb),8.4 l/100 km (city),5.2 l/100 km (country),'
#  '6.3 l/100 km (comb),8.3 l/100 km (city),5.1 l/100 km (country),'
#  "['3.7 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['5 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']"
#  '4.3 l/100 km (comb),5.2 l/100 km (city),3.8 l/100 km (country),'
#  "['5.7 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['4.3 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.5 l/100 km (city)'],['4.1 l/100 km (country)']"
#  '6.3 l/100 km (comb),8.6 l/100 km (city),5 l/100 km (country),'
#  '5.7 l/100 km (comb),7.3 l/100 km (city),4.7 l/100 km (country),'
#  '5.9 l/100 km (comb),7.4 l/100 km (city),5 l/100 km (country),'
#  "['4.4 l/100 km (comb)'],[],['3.9 l/100 km (country)']"
#  '5.4 l/100 km (comb),7.3 l/100 km (city),4.2 l/100 km (country),'
#  "['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['6 l/100 km (city)'],['6 l/100 km (country)']"
#  "['6.3 l/100 km (comb)'],['8.2 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['3.6 l/100 km (city)'],['4 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['7 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.4 l/100 km (city)'],['5 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],[],[]"
#  "['5 l/100 km (comb)'],['5.9 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '4.7 l/100 km (comb),5.4 l/100 km (city),4.2 l/100 km (country),'
#  "['4.7 l/100 km (comb)'],['5.4 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],['7.7 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],[],[]"
#  '5.2 l/100 km (comb),6.6 l/100 km (city),4.4 l/100 km (country),'
#  "['4.5 l/100 km (comb)'],['5.3 l/100 km (city)'],['4 l/100 km (country)']"
#  '5.5 l/100 km (comb),7.3 l/100 km (city),4.5 l/100 km (country),'
#  "['6 l/100 km (comb)'],['7.9 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']"
#  "['6.8 l/100 km (comb)'],['8.6 l/100 km (city)'],['5.8 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.7 l/100 km (city)'],['4.8 l/100 km (country)']"
#  '4.3 l/100 km (comb),5.2 l/100 km (city),3.9 l/100 km (country),'
#  '4.4 l/100 km (comb),5.7 l/100 km (city),3.7 l/100 km (country),'
#  "['4.6 l/100 km (comb)'],['5.5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],[],['3.1 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.5 l/100 km (country)']"
#  '5 l/100 km (comb),5.9 l/100 km (city),4.5 l/100 km (country),'
#  "['5.5 l/100 km (comb)'],['7 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['7.5 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['6.6 l/100 km (comb)'],['8.5 l/100 km (city)'],['5.5 l/100 km (country)']"
#  '6.7 l/100 km (comb),8.7 l/100 km (city),5.6 l/100 km (country),'
#  "['6.6 l/100 km (comb)'],['8.6 l/100 km (city)'],['5.5 l/100 km (country)']"
#  '6.6 l/100 km (comb),8.5 l/100 km (city),5.5 l/100 km (country),'
#  "['6.1 l/100 km (comb)'],['7.8 l/100 km (city)'],['5.2 l/100 km (country)']"
#  '6 l/100 km (comb),7.5 l/100 km (city),5.2 l/100 km (country),'
#  '6.5 l/100 km (comb),8.5 l/100 km (city),5.4 l/100 km (country),'
#  '5.8 l/100 km (comb),7.4 l/100 km (city),4.9 l/100 km (country),'
#  "['6 l/100 km (comb)'],['7.5 l/100 km (city)'],['5.2 l/100 km (country)']"
#  '6.1 l/100 km (comb),7.5 l/100 km (city),5.2 l/100 km (country),'
#  '6.6 l/100 km (comb),8.6 l/100 km (city),5.5 l/100 km (country),'
#  "['6.7 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']"
#  "['6.5 l/100 km (comb)'],['8.5 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['6.3 l/100 km (comb)'],['8.5 l/100 km (city)'],['5 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.8 l/100 km (city)'],['6 l/100 km (country)']"
#  "['7.5 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['8 l/100 km (city)'],['5 l/100 km (country)']"
#  "['7.4 l/100 km (comb)'],['10.4 l/100 km (city)'],['6.4 l/100 km (country)']"
#  '5.4 l/100 km (comb),7 l/100 km (city),4.5 l/100 km (country),'
#  "['6.1 l/100 km (comb)'],['7.5 l/100 km (city)'],['5 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['6.3 l/100 km (comb)'],['8.5 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "
l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '6.3 l/100 km (comb),7.8 l/100 km (city),5.4 l/100 km (country),'
#  "['7.8 l/100 km (comb)'],[],[]"
#  "['5.9 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.7 l/100 km (country)']"
#  '5.9 l/100 km (comb),7.9 l/100 km (city),4.8 l/100 km (country),'
#  "['5.7 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['7.7 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['7.4 l/100 km (city)'],['5.1 l/100 km (country)']"
#  '6.6 l/100 km (comb),8.2 l/100 km (city),5.7 l/100 km (country),'
#  "['6.4 l/100 km (comb)'],['8.1 l/100 km (city)'],['5.6 l/100 km (country)']"
#  '5.9 l/100 km (comb),7.5 l/100 km (city),5 l/100 km (country),'
#  '6.6 l/100 km (comb),8.2 l/100 km (city),5.6 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '4.8 l/100 km (comb),5.8 l/100 km (city),4.1 l/100 km (country),'
#  "['5.6 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['7.5 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['6 l/100 km (comb)'],[],[]"
#  '4.9 l/100 km (comb),6.2 l/100 km (city),4.1 l/100 km (country),'
#  "['3.4 l/100 km (comb)'],['4 l/100 km (city)'],['3.1 l/100 km (country)']"
#  '4.9 l/100 km (comb),'
#  "['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.1 l/100 km (country)']"
#  '6.2 l/100 km (comb),7.7 l/100 km (city),5.4 l/100 km (country),'
#  '6 l/100 km (comb),8 l/100 km (city),4.9 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.2 l/100 km (country)']"
#  '5.9 l/100 km (comb),'
#  "['5.6 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['3.1 l/100 km (comb)'],['3.4 l/100 km (city)'],['3 l/100 km (country)']"
#  '4.7 l/100 km (comb),'
#  "['3.2 l/100 km (comb)'],['3.4 l/100 km (city)'],['3 l/100 km (country)']"
#  '5.9 l/100 km (comb),7.8 l/100 km (city),4.7 l/100 km (country),'
#  "['4.8 l/100 km (comb)'],['5.3 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['3.8 l/100 km (city)'],['3 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.5 l/100 km (country)']"
#  '5.8 l/100 km (comb),7.3 l/100 km (city),4.9 l/100 km (country),'
#  '5.4 l/100 km (comb),6.7 l/100 km (city),4.6 l/100 km (country),'
#  "['5 l/100 km (comb)'],['5 l/100 km (city)'],['5 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "[],[],['5.6 l/100 km (country)']" "[],[],['5.7 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  '5.6 l/100 km (comb),7.3 l/100 km (city),4.7 l/100 km (country),'
#  "['5.6 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.7 l/100 km (country)']"
#  '6.3 l/100 km (comb),'
#  "['4.6 l/100 km (comb)'],['5.4 l/100 km (city)'],['6.7 l/100 km (country)']"
#  '5.1 l/100 km (comb),6.4 l/100 km (city),4.3 l/100 km (country),'
#  "['4.2 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['3.9 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.4 l/100 km (country)']"
#  '5.6 l/100 km (comb),7.2 l/100 km (city),4.8 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['6.8 l/100 km (comb)'],['8.2 l/100 km (city)'],['5.8 l/100 km (country)']"
#  "['3.8 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "
l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.5 l/100 km (city)'],['5 l/100 km (country)']"
#  '5.6 l/100 km (comb),7 l/100 km (city),4.8 l/100 km (country),'
#  "['6.9 l/100 km (comb)'],['7.1 l/100 km (city)'],['5.6 l/100 km (country)']"
#  '6.6 l/100 km (comb),8.1 l/100 km (city),5.7 l/100 km (country),'
#  "['7 l/100 km (comb)'],['9.8 l/100 km (city)'],['5.9 l/100 km (country)']"
#  "['6.6 l/100 km (comb)'],[],[]"
#  "['5.7 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.8 l/100 km (country)']"
#  '5.7 l/100 km (comb),7.3 l/100 km (city),4.8 l/100 km (country),'
#  '5.6 l/100 km (comb),7.2 l/100 km (city),4.7 l/100 km (country),'
#  "['5.8 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],[],[]"
#  "['3 l/100 km (comb)'],['1 l/100 km (city)'],['2 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],[],[]"
#  "['5.7 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['6.9 l/100 km (comb)'],['7.4 l/100 km (city)'],['5 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6.4 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.7 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.8 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['7.2 l/100 km (comb)'],['9.8 l/100 km (city)'],['5.8 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4.8 l/100 km (comb)'],['6.2 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['5.8 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['4.9 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['6.5 l/100 km (comb)'],['8.1 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['8 l/100 km (comb)'],['11 l/100 km (city)'],['6.3 l/100 km (country)']"
#  "['6.7 l/100 km (comb)'],['0 l/100 km (city)'],['0 l/100 km (country)']"
#  "['6.4 l/100 km (comb)'],['8.7 l/100 km (city)'],['5 l/100 km (country)']"
#  "['7 l/100 km (comb)'],['0 l/100 km (city)'],['0 l/100 km (country)']"
#  "['11 l/100 km (comb)'],['16.1 l/100 km (city)'],['8 l/100 km (country)']"
#  "['8.3 l/100 km (comb)'],['11.5 l/100 km (city)'],['6.4 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['0 l/100 km (city)'],['0 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['8.5 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.6 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6.3 l/100 km (city)'],['4 l/100 km (country)']"
#  '6.2 l/100 km (comb),7.7 l/100 km (city),5.3 l/100 km (country),'
#  "['5 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['8 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['6.6 l/100 km (comb)'],['8.9 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['7 l/100 km (comb)'],[],[]" "['8 l/100 km (comb)'],[],[]"
#  "['6.4 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['0 l/100 km (comb)'],['0 l/100 km (city)'],['0 l/100 km (country)']"
#  "['7 l/100 km (comb)'],['9.5 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['6.6 l/100 km (comb)'],['9.2 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['7.6 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['8 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['8 l/100 km (city)'],['4 l/100 km (country)']"
#  "['7 l/100 km (comb)'],['9.6 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['8.6 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "[],['7.1 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['6.4 l/100 km (comb)'],['8.6 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['6.7 l/100 km (comb)'],['9.4 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],['6.6 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.7 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],[],['8.6 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],[],['7.8 l/100 km (country)']"
#  "['9.1 l/100 km (comb)'],['11.3 l/100 km (city)'],['7.8 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['8.1 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "['8.6 l/100 km (comb)'],['11.2 l/100 km (city)'],[]"
#  "['3.6 l/100 km (comb)'],['5 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['8.7 l/100 km (comb)'],['6.4 l/100 km (city)'],['5 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['7.4 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['6 l/100 km (city)'],['4 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['7 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.7 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.1 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.8 l/100 km (country)']"
#  '5.5 l/100 km (comb),7 l/100 km (city),4.6 l/100 km (country),'
#  "['5.6 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.9 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.5 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['6.9 l/100 km (city)'],['4.8 l/100 km (country)']"
#  '6 l/100 km (comb),8 l/100 km (city),5 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['6.7 l/100 km (city)'],['3.8 l/100 km (country)']"
#  '5.3 l/100 km (comb),7 l/100 km (city),4.3 l/100 km (country),'
#  '5.6 l/100 km (comb),7.6 l/100 km (city),4.4 l/100 km (country),'
#  "['5.6 l/100 km (comb)'],['7.6 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['7.9 l/100 km (comb)'],['10.8 l/100 km (city)'],['6.3 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.6 l/100 km (country)']"
#  "[],['4.6 l/100 km (city)'],['5.7 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['7.3 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['7.6 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['6.4 l/100 km (comb)'],['8.1 l/100 km (city)'],['5.4 l/100 km (country)']"
#  '7 l/100 km (comb),9.5 l/100 km (city),5.5 l/100 km (country),'
#  "['6.2 l/100 km (comb)'],['7.2 l/100 km (city)'],['5.4 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],['7.2 l/100 km (city)'],['5.2 l/100 km (country)']"
#  '6 l/100 km (comb),7.3 l/100 km (city),5.2 l/100 km (country),'
# ...
#  "['6 l/100 km (comb)'],['7.7 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.9 l/100 km (country)']"
#  '6.5 l/100 km (comb),8.1 l/100 km (city),5.5 l/100 km (country),'
#  "['4.3 l/100 km (comb)'],['5 l/100 km (city)'],['3.8 l/100 km (country)']"
#  '5.9 l/100 km (comb),7.5 l/100 km (city),4.9 l/100 km (country),'
#  '5.9 l/100 km (comb),7.7 l/100 km (city),4.9 l/100 km (country),'
#  "['6 l/100 km (comb)'],['7.6 l/100 km (city)'],['5 l/100 km (country)']"
#  '6.1 l/100 km (comb),7.7 l/100 km (city),5.2 l/100 km (country),'
#  "['5.5 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.6 l/100 km (country)']"
#  '6.2 l/100 km (comb),7.6 l/100 km (city),5.4 l/100 km (country),'
#  "['5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.6 l/100 km (country)']"
#  '5.8 l/100 km (comb),'
#  "['6.1 l/100 km (comb)'],['7.8 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['55 l/100 km (comb)'],['7.3 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['6.1 l/100 km (comb)'],['7.6 l/100 km (city)'],['5.2 l/100 km (country)']"
#  "['5.8 l/100 km (comb)'],
l/100 km (comb)'],['4.3 l/100 km (city)'],['3.9 l/100 km (country)']"
#  '5.5 l/100 km (comb),7 l/100 km (city),4.7 l/100 km (country),'
#  "['5.2 l/100 km (comb)'],['4.4 l/100 km (city)'],['6.6 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.6 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['54 l/100 km (comb)'],[],[]"
#  "['5.2 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],['7.9 l/100 km (city)'],['5.1 l/100 km (country)']"
#  "[],['3.3 l/100 km (city)'],['3.5 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['3.7 l/100 km (city)'],['3.1 l/100 km (country)']"
#  '5.4 l/100 km (comb),6.8 l/100 km (city),4.5 l/100 km (country),'
#  "['3.5 l/100 km (comb)'],['3.7 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['3.3 l/100 km (comb)'],['3.5 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.2 l/100 km (comb)'],['3.4 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['3.6 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['3.2 l/100 km (comb)'],['3.3 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "[],[],['5.1 l/100 km (country)']" "['3.2 l/100 km (comb)'],[],[]"
#  "['5.5 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5.5 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.5 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['3.3 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['4.3 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.7 l/100 km (country)']"
#  "['1.2 l/100 km (comb)'],[],[]"
#  "['3.1 l/100 km (comb)'],[],['3.5 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['5.9 l/100 km (comb)'],[],[]"
#  "['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.6 l/100 km (country)']"
#  "['3.4 l/100 km (comb)'],['4 l/100 km (city)'],['3.2 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['6.2 l/100 km (city)'],['3.9 l/100 km (country)']"
#  '5.7 l/100 km (comb),7.2 l/100 km (city),4.9 l/100 km (country),'
#  "['10 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['3.5 l/100 km (comb)'],['3.8 l/100 km (city)'],['3.3 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['7.5 l/100 km (city)'],['5 l/100 km (country)']"
#  '5.9 l/100 km (comb),7.6 l/100 km (city),5.1 l/100 km (country),'
#  "['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['32 l/100 km (comb)'],[],[]"
#  "['3.2 l/100 km (comb)'],['3.5 l/100 km (city)'],['3.1 l/100 km (country)']"
#  "['6 l/100 km (comb)'],['7.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6 l/100 km (city)'],['4.1 l/100 km (country)']"
#  "['4.9 l/100 km (comb)'],['5.9 l/100 km (city)'],['5.5 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['33 l/100 km (comb)'],[],[]"
#  "['4.1 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.8 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6 l/100 km (city)'],['4.3 l/100 km (country)']"
#  "['50 l/100 km (comb)'],['64 l/100 km (city)'],['42 l/100 km (country)']"
#  "['4.2 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['5 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['5.2 l/100 km (comb)'],['6 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4 l/100 km (comb)'],['6.5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  '5 l/100 km (comb),6.4 l/100 km (city),4.2 l/100 km (country),'
#  "['10 l/100 km (comb)'],[],['10 l/100 km (country)']"
#  "['10 l/100 km (comb)'],['10 l/100 km (city)'],['10 l/100 km (country)']"
#  "['1 l/100 km (comb)'],['1 l/100 km (city)'],['1 l/100 km (country)']"
#  "['4.6 l/100 km (comb)'],['5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['4.6 l/100 km (city)'],[]"
#  "['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']"
#  "['6.2 l/100 km (comb)'],['7.8 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['0 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],[]"
#  "[],['5 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['46 l/100 km (comb)'],[],[]"
#  '6.2 l/100 km (comb),7.8 l/100 km (city),5.3 l/100 km (country),'
#  "['4.6 l/100 km (comb)'],[],['4.4 l/100 km (country)']"
#  "['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']"
#  "['4.5 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.2 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],['5.1 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.4 l/100 km (comb)'],[],['4 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.9 l/100 km (country)']"
#  "['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']"
#  "['5.6 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']"
#  "['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']"
#  '6.8 l/100 km (comb),8.7 l/100 km (city),5.7 l/100 km (country),'
#  "['5 l/100 km (comb)'],['5 l/100 km (city)'],['4 l/100 km (country)']"
#  "['4.7 l/100 km (comb)'],['5.3 l/100 km (city)'],['4.4 l/100 km (country)']"
#  "['6.8 l/100 km (comb)'],[],[]"
#  "['5.3 l/100 km (comb)'],['7.8 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']"
#  "['7.6 l/100 km (comb)'],['9.6 l/100 km (city)'],['6.4 l/100 km (country)']"
#  "['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']"
#  "['7.4 l/100 km (comb)'],[],[]"
#  '7.4 l/100 km (comb),9.2 l/100 km (city),6.3 l/100 km (country),'
#  "['7.4 l/100 km (comb)'],['9.7 l/100 km (city)'],['6.3 l/100 km (country)']"
#  "['7.6 l/100 km (comb)'],[],[]"
#  "['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.8 l/100 km (country)']"
#  "['5.4 l/100 km (comb)'],['6.1 l/100 km (city)'],['5 l/100 km (country)']"
#  "['5.3 l/100 km (comb)'],['6 l/100 km (city)'],['5 l/100 km (country)']"
#  '7.4 l/100 km (comb),9.6 l/100 km (city),6 l/100 km (country),']
# ----------------------------------------
# 1.6 l/100 km (comb),                                                  3
# 3.9 l/100 km (comb),4.7 l/100 km (city),3.3 l/100 km (country),       1
# 4 l/100 km (comb),3.8 l/100 km (city),4.4 l/100 km (country),         1
# 4.1 l/100 km (comb),7.5 l/100 km (city),5.2 l/100 km (country),       1
# 4.2 l/100 km (comb),5 l/100 km (city),3.7 l/100 km (country),        27
#                                                                    ...
# [],[],['5.1 l/100 km (country)']                                      4
# [],[],['5.6 l/100 km (country)']                                      1
# [],[],['5.7 l/100 km (country)']                                     13
# [],[],['5.8 l/100 km (country)']                                      1
# NaN                                                                1906
# Name: consumption, Length: 882, dtype: int64
# ----------------------------------------
# NaN                                                                           1906
# ['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.7 l/100 km (country)']     304
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']       276
# ['5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']     257
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']     253
#                                                                               ...
# ['4.2 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.6 l/100 km (country)']       1
# 5.1 l/100 km (comb),6.4 l/100 km (city),4.3 l/100 km (country),                  1
# ['4.6 l/100 km (comb)'],['5.4 l/100 km (city)'],['6.7 l/100 km (country)']       1
# 6.3 l/100 km (comb),                                                             1
# 7.4 l/100 km (comb),9.6 l/100 km (city),6 l/100 km (country),                    1
# Name: consumption, Length: 882, dtype: int64
# ################################################################################

# %%
# Consumption column is already divided into 3 three column

# %%
#looking for the null values of consumption_comb in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["consumption_comb"].isnull()][i].str.contains("100 km \(comb\)", regex=True).any():
        print(i)

# %%
#looking for the null values of consumption_city in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["consumption_city"].isnull()][i].str.contains("100 km \(city\)", regex=True).any():
        print(i)

# %%
#looking for the null values of consumption_country in all columns
for i in df.select_dtypes(include="O").columns:
    if df[df["consumption_country"].isnull()][i].str.contains("100 km \(country\)", regex=True).any():
        print(i)

# %% [markdown]
# ### price

# %%
first_look("price")
# Out:
# column name :  price
# ----------------------------------------
# Per_of_Nulls   :  % 0.0
# Number of Nulls  :  0
# Number of Uniques:  2956
# Type of columns:  int64
# ----------------------------------------
# Unique values of columns:  [15770 14500 14640 ... 41390 39885 39875]
# ----------------------------------------
# 13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ----------------------------------------
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
# ################################################################################

# %%
df["price"] = df["price"].astype(float)

# %% [markdown]
# # END OF THE DATA CLEANING

# %%
df.head().T
# Out:
#                                                                        0  \
# url                    https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                       Audi A1
# short_description            Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                         Sedans
# price                                                            15770.0
# vat                                                       VAT deductible
# km                                                               56013.0
# registration                                         2016-01-01 00:00:00
# prev_owner                                                           2.0
# type                                                                Used
# previous_owners                                                        2
# next_inspection                                06/202199 g CO2/km (comb)
# inspection_new                                                 YesEuro 6
# warranty                                                       4 (Green)
# full_service
# non_smoking_vehicle
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          5.0
# nr_of_seats                                                          5.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                            1220.0
# drive_chain                                                        front
# fuel                                                              Diesel
# consumption            ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# co_2_emission                                         99 g CO2/km (comb)
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                    Alloy wheels,Catalytic Converter,Voice Control
# safety_&_security      ABS,Central door lock,Daytime running lights,D...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                      NaN
# last_service_date                                                    NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.3
# consumption_country                                                  3.5
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                      2021-06-01 00:00:00
# inspection_situation                                                   1
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1422.0
# last_service_time                                                    NaT
#
#                                                                        1  \
# url                    https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                       Audi A1
# short_description                                         1.8 TFSI sport
# body_type                                                         Sedans
# price                                                            14500.0
# vat                                                     Price negotiable
# km                                                               80000.0
# registration                                         2017-03-01 00:00:00
# prev_owner                                                           NaN
# type                                                                Used
# previous_owners                                                      NaN
# next_inspection                                                      NaN
# inspection_new                                                       NaN
# warranty                                                             NaN
# full_service                                                         NaN
# non_smoking_vehicle                                                  NaN
# body_color                                                           Red
# paint_type                                                           NaN
# nr_of_doors                                                          3.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            4.0
# weight                                                            1255.0
# drive_chain                                                        front
# fuel                                                             Benzine
# consumption            ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'...
# co_2_emission                                        129 g CO2/km (comb)
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Automatic climate control,Hil...
# entertainment_&_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                 Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_&_security      ABS,Central door lock,Central door lock with r...
# emission_label                                                       4.0
# gears                                                                7.0
# country_version                                                      NaN
# last_service_date                                                    NaN
# consumption_comb                                                     5.6
# consumption_city                                                     7.1
# consumption_country                                                  4.7
# hp_kw                                                              141.0
# Particulate_Filter                                                     0
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                    129.0
# upholstery_type                                                    Cloth
# upholstery_color                                                    Grey
# engine_size                                                       1798.0
# last_service_time                                                    NaT
#
#                                                                        2  \
# url                    https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                       Audi A1
# short_description      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# body_type                                                         Sedans
# price                                                            14640.0
# vat                                                       VAT deductible
# km                                                               83450.0
# registration                                         2016-02-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# previous_owners                                                        1
# next_inspection                                                      NaN
# inspection_new                                                       NaN
# warranty                                              99 g CO2/km (comb)
# full_service                                                         NaN
# non_smoking_vehicle                                                  NaN
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          4.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            NaN
# weight                                                               NaN
# drive_chain                                                        front
# fuel                                                              Diesel
# consumption            ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'...
# co_2_emission                                         99 g CO2/km (comb)
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_&_media                              MP3,On-board computer
# extras                                        Alloy wheels,Voice Control
# safety_&_security      ABS,Central door lock,Daytime running lights,D...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                      NaN
# last_service_date                                                    NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.4
# consumption_country                                                  3.4
# hp_kw                                                               85.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1598.0
# last_service_time                                                    NaT
#
#                                                                        3  \
# url                    https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                       Audi A1
# short_description                                1.4 TDi Design S tronic
# body_type                                                         Sedans
# price                                                            14500.0
# vat                                                                 None
# km                                                               73000.0
# registration                                         2016-08-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# previous_owners                                                        1
# next_inspection                                                      NaN
# inspection_new                                                       NaN
# warranty                                                             NaN
# full_service                                          99 g CO2/km (comb)
# non_smoking_vehicle                                               Euro 6
# body_color                                                         Brown
# paint_type                                                      Metallic
# nr_of_doors                                                          3.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                            1195.0
# drive_chain                                                          NaN
# fuel                                                              Diesel
# consumption            ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# co_2_emission                                         99 g CO2/km (comb)
# emission_class                                                    Euro 6
# comfort_&_convenience  Air suspension,Armrest,Auxiliary heating,Elect...
# entertainment_&_media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                            Alloy wheels,Sport seats,Voice Control
# safety_&_security      ABS,Alarm system,Central door lock with remote...
# emission_label                                                       NaN
# gears                                                                6.0
# country_version                                                      NaN
# last_service_date                                                    NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.3
# consumption_country                                                  3.5
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                      NaN
# upholstery_color                                                     NaN
# engine_size                                                       1422.0
# last_service_time                                                    NaT
#
#                                                                        4
# url                    https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                       Audi A1
# short_description      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# body_type                                                         Sedans
# price                                                            16790.0
# vat                                                                 None
# km                                                               16200.0
# registration                                         2016-05-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# previous_owners                                                        1
# next_inspection                                                      NaN
# inspection_new                                    Yes109 g CO2/km (comb)
# warranty                                                          Euro 6
# full_service                                                   4 (Green)
# non_smoking_vehicle
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          5.0
# nr_of_seats                                                          5.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                               NaN
# drive_chain                                                        front
# fuel                                                              Diesel
# consumption            ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'...
# co_2_emission                                        109 g CO2/km (comb)
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                 Alloy wheels,Sport package,Sport suspension,Vo...
# safety_&_security      ABS,Central door lock,Driver-side airbag,Elect...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                  Germany
# last_service_date                                                    NaN
# consumption_comb                                                     4.1
# consumption_city                                                     4.6
# consumption_country                                                  3.8
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   1
# warranty_month                                                       NaN
# co2_emission_gr                                                    109.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1422.0
# last_service_time                                                    NaT

# %%
df.drop(columns=["url","short_description","previous_owners","next_inspection","inspection_new","warranty","full_service"
                ,"non_smoking_vehicle","consumption","co_2_emission","last_service_date"], inplace=True)

# %%
df.head().T
# Out:
#                                                                        0  \
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                            15770.0
# vat                                                       VAT deductible
# km                                                               56013.0
# registration                                         2016-01-01 00:00:00
# prev_owner                                                           2.0
# type                                                                Used
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          5.0
# nr_of_seats                                                          5.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                            1220.0
# drive_chain                                                        front
# fuel                                                              Diesel
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                    Alloy wheels,Catalytic Converter,Voice Control
# safety_&_security      ABS,Central door lock,Daytime running lights,D...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                      NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.3
# consumption_country                                                  3.5
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                      2021-06-01 00:00:00
# inspection_situation                                                   1
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1422.0
# last_service_time                                                    NaT
#
#                                                                        1  \
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                            14500.0
# vat                                                     Price negotiable
# km                                                               80000.0
# registration                                         2017-03-01 00:00:00
# prev_owner                                                           NaN
# type                                                                Used
# body_color                                                           Red
# paint_type                                                           NaN
# nr_of_doors                                                          3.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            4.0
# weight                                                            1255.0
# drive_chain                                                        front
# fuel                                                             Benzine
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Automatic climate control,Hil...
# entertainment_&_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                 Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_&_security      ABS,Central door lock,Central door lock with r...
# emission_label                                                       4.0
# gears                                                                7.0
# country_version                                                      NaN
# consumption_comb                                                     5.6
# consumption_city                                                     7.1
# consumption_country                                                  4.7
# hp_kw                                                              141.0
# Particulate_Filter                                                     0
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                    129.0
# upholstery_type                                                    Cloth
# upholstery_color                                                    Grey
# engine_size                                                       1798.0
# last_service_time                                                    NaT
#
#                                                                        2  \
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                            14640.0
# vat                                                       VAT deductible
# km                                                               83450.0
# registration                                         2016-02-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          4.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            NaN
# weight                                                               NaN
# drive_chain                                                        front
# fuel                                                              Diesel
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_&_media                              MP3,On-board computer
# extras                                        Alloy wheels,Voice Control
# safety_&_security      ABS,Central door lock,Daytime running lights,D...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                      NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.4
# consumption_country                                                  3.4
# hp_kw                                                               85.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1598.0
# last_service_time                                                    NaT
#
#                                                                        3  \
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                            14500.0
# vat                                                                 None
# km                                                               73000.0
# registration                                         2016-08-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# body_color                                                         Brown
# paint_type                                                      Metallic
# nr_of_doors                                                          3.0
# nr_of_seats                                                          4.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                            1195.0
# drive_chain                                                          NaN
# fuel                                                              Diesel
# emission_class                                                    Euro 6
# comfort_&_convenience  Air suspension,Armrest,Auxiliary heating,Elect...
# entertainment_&_media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                            Alloy wheels,Sport seats,Voice Control
# safety_&_security      ABS,Alarm system,Central door lock with remote...
# emission_label                                                       NaN
# gears                                                                6.0
# country_version                                                      NaN
# consumption_comb                                                     3.8
# consumption_city                                                     4.3
# consumption_country                                                  3.5
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   0
# warranty_month                                                       NaN
# co2_emission_gr                                                     99.0
# upholstery_type                                                      NaN
# upholstery_color                                                     NaN
# engine_size                                                       1422.0
# last_service_time                                                    NaT
#
#                                                                        4
# make_model                                                       Audi A1
# body_type                                                         Sedans
# price                                                            16790.0
# vat                                                                 None
# km                                                               16200.0
# registration                                         2016-05-01 00:00:00
# prev_owner                                                           1.0
# type                                                                Used
# body_color                                                         Black
# paint_type                                                      Metallic
# nr_of_doors                                                          5.0
# nr_of_seats                                                          5.0
# gearing_type                                                   Automatic
# cylinders                                                            3.0
# weight                                                               NaN
# drive_chain                                                        front
# fuel                                                              Diesel
# emission_class                                                    Euro 6
# comfort_&_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_&_media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# extras                 Alloy wheels,Sport package,Sport suspension,Vo...
# safety_&_security      ABS,Central door lock,Driver-side airbag,Elect...
# emission_label                                                       4.0
# gears                                                                NaN
# country_version                                                  Germany
# consumption_comb                                                     4.1
# consumption_city                                                     4.6
# consumption_country                                                  3.8
# hp_kw                                                               66.0
# Particulate_Filter                                                     1
# inspection_time                                                      NaT
# inspection_situation                                                   1
# warranty_month                                                       NaN
# co2_emission_gr                                                    109.0
# upholstery_type                                                    Cloth
# upholstery_color                                                   Black
# engine_size                                                       1422.0
# last_service_time                                                    NaT

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'vat', 'km', 'registration',
#        'prev_owner', 'type', 'body_color', 'paint_type', 'nr_of_doors',
#        'nr_of_seats', 'gearing_type', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security',
#        'emission_label', 'gears', 'country_version', 'consumption_comb',
#        'consumption_city', 'consumption_country', 'hp_kw',
#        'Particulate_Filter', 'inspection_time', 'inspection_situation',
#        'warranty_month', 'co2_emission_gr', 'upholstery_type',
#        'upholstery_color', 'engine_size', 'last_service_time'],
#       dtype='object')

# %%
df.columns = ['Model', 'Body_Type', 'Price', 'Vat', 'Km', 'Registration_Date',
       'Prev_Owner', 'Type', 'Body_Color', 'Paint_Type', 'Door_Total',
       'Seat_Total', 'Gear_Type', 'Cylinders', 'Weight', 'Drive_Chain',
       'Fuel', 'Emission_Class', 'Comfort_Convenience',
       'Entertainment_Media', 'Extras', 'Safety_Security',
       'Emission_Label', 'Gears', 'Country', 'Consumption_Comb', 'Consumption_City', 'Consumption_Country', 'Hp',
       'Particulate_Filter', 'Inspection_Time', 'Inspection_Situation',
       'Warranty', 'Emission', 'Upholstery_Type',
       'Upholstery_Color', 'Engine_Size', 'LastServiceTime']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 15919 non-null  object
#  1   Body_Type             15860 non-null  object
#  2   Price                 15919 non-null  float64
#  3   Vat                   11406 non-null  object
#  4   Km                    14895 non-null  float64
#  5   Registration_Date     14322 non-null  datetime64[ns]
#  6   Prev_Owner            9279 non-null   float64
#  7   Type                  15917 non-null  object
#  8   Body_Color            15338 non-null  object
#  9   Paint_Type            10147 non-null  object
#  10  Door_Total            15707 non-null  float64
#  11  Seat_Total            14942 non-null  float64
#  12  Gear_Type             15919 non-null  object
#  13  Cylinders             10239 non-null  float64
#  14  Weight                8945 non-null   float64
#  15  Drive_Chain           9061 non-null   object
#  16  Fuel                  15919 non-null  object
#  17  Emission_Class        12999 non-null  object
#  18  Comfort_Convenience   14999 non-null  object
#  19  Entertainment_Media   14545 non-null  object
#  20  Extras                12957 non-null  object
#  21  Safety_Security       14937 non-null  object
#  22  Emission_Label        7969 non-null   float64
#  23  Gears                 11207 non-null  float64
#  24  Country               7586 non-null   object
#  25  Consumption_Comb      13886 non-null  object
#  26  Consumption_City      13483 non-null  object
#  27  Consumption_Country   13543 non-null  object
#  28  Hp                    15833 non-null  float64
#  29  Particulate_Filter    15919 non-null  int64
#  30  Inspection_Time       3469 non-null   datetime64[ns]
#  31  Inspection_Situation  15919 non-null  int64
#  32  Warranty              4853 non-null   float64
#  33  Emission              13484 non-null  float64
#  34  Upholstery_Type       11416 non-null  object
#  35  Upholstery_Color      10841 non-null  object
#  36  Engine_Size           15743 non-null  float64
#  37  LastServiceTime       566 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), float64(13), int64(2), object(20)
# memory usage: 4.6+ MB

# %%
df.to_csv("AutoScout_Cleaned")
